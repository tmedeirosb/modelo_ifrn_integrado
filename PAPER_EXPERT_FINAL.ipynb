# %% [markdown]
# <a href="https://colab.research.google.com/github/tmedeirosb/modelo_ifrn_integrado/blob/master/PAPER_EXPERT_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Paper: XXXX
# # Journal: Expert System with Application
#
# ## Abstract: XXXX
#
# O objetivo deste notebook é mostrar que o uso de técnicas de imbalanced learning pode melhorar a acurácia de modelos preditivos de evasão.
#
# Na primeira parte do paper serão feitos dois modelos: xxx.
#
# Na segunda parte será utilizada a técnica Balanced Bagging (https://imbalanced-learn.readthedocs.io/en/stable/generated/imblearn.ensemble.BalancedBaggingClassifier.html) com o core DT.
#
# Para cada modelo serão gerados as métricas: precision, accuracy, recall, ROC, confusion matrix e G-mean. Este último será utilizado para comparação entre modelos como indicado para problemas de dados desbalanceados (https://sci2s.ugr.es/keel/pdf/algorithm/congreso/kubat97addressing.pdf).
#
# Ao fim é feito o teste de p-value para confirmar se houve diferença estatística entre o desempenho dos modelos

# %%
# !pip install -U Skater
# Out:
# Requirement already up-to-date: Skater in /usr/local/lib/python3.6/dist-packages/skater-1.1.2-py3.6.egg (1.1.2)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.18 in /usr/local/lib/python3.6/dist-packages (from Skater) (0.21.2)
# Requirement already satisfied, skipping upgrade: scikit-image==0.14 in /usr/local/lib/python3.6/dist-packages (from Skater) (0.14.0)
# Requirement already satisfied, skipping upgrade: pandas>=0.22.0 in /usr/local/lib/python3.6/dist-packages (from Skater) (0.24.2)
# Requirement already satisfied, skipping upgrade: ds-lime>=0.1.1.21 in /usr/local/lib/python3.6/dist-packages (from Skater) (0.1.1.27)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from Skater) (2.21.0)
# Requirement already satisfied, skipping upgrade: multiprocess in /usr/local/lib/python3.6/dist-packages (from Skater) (0.70.8)
# Requirement already satisfied, skipping upgrade: dill>=0.2.6 in /usr/local/lib/python3.6/dist-packages (from Skater) (0.3.0)
# Requirement already satisfied, skipping upgrade: wordcloud==1.3.1 in /usr/local/lib/python3.6/dist-packages (from Skater) (1.3.1)
# Requirement already satisfied, skipping upgrade: joblib==0.11 in /usr/local/lib/python3.6/dist-packages (from Skater) (0.11)
# Requirement already satisfied, skipping upgrade: Jinja2==2.10 in /usr/local/lib/python3.6/dist-packages (from Skater) (2.10)
# Requirement already satisfied, skipping upgrade: pydotplus==2.0.2 in /usr/local/lib/python3.6/dist-packages (from Skater) (2.0.2)
# Requirement already satisfied, skipping upgrade: bs4 in /usr/local/lib/python3.6/dist-packages (from Skater) (0.0.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18->Skater) (1.3.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18->Skater) (1.16.4)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.14->Skater) (1.0.3)
# Requirement already satisfied, skipping upgrade: dask[array]>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.14->Skater) (1.1.5)
# Requirement already satisfied, skipping upgrade: networkx>=1.8 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.14->Skater) (2.3)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.14->Skater) (1.12.0)
# Requirement already satisfied, skipping upgrade: cloudpickle>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.14->Skater) (0.6.1)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.14->Skater) (3.0.3)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.14->Skater) (4.3.0)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.22.0->Skater) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.22.0->Skater) (2.5.3)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->Skater) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->Skater) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->Skater) (2019.6.16)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->Skater) (2.8)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2==2.10->Skater) (1.1.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from pydotplus==2.0.2->Skater) (2.4.0)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from bs4->Skater) (4.6.3)
# Requirement already satisfied, skipping upgrade: toolz>=0.7.3; extra == "array" in /usr/local/lib/python3.6/dist-packages (from dask[array]>=0.9.0->scikit-image==0.14->Skater) (0.9.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=1.8->scikit-image==0.14->Skater) (4.4.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.0.0->scikit-image==0.14->Skater) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.0.0->scikit-image==0.14->Skater) (1.1.0)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.3.0->scikit-image==0.14->Skater) (0.46)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib>=2.0.0->scikit-image==0.14->Skater) (41.0.1)

# %% [markdown]
# Import packages

# %%
#import packages

#graphs
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns; sns.set()

#google drive
import os
from google.colab import drive

#data crawling
import numpy as np
import pandas as pd

#evalueting models
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_predict 
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer
from sklearn import model_selection
from sklearn.metrics import matthews_corrcoef

#selecionando atributos 
from sklearn.feature_selection import RFECV

#classic models
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import BernoulliNB

#imbalanced
from imblearn.ensemble import BalancedBaggingClassifier
from sklearn.model_selection import cross_validate
from sklearn.base import BaseEstimator
from sklearn.base import ClassifierMixin
from imblearn.ensemble import BalanceCascade
import operator
from sklearn.base import clone
from imblearn.metrics import geometric_mean_score
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.under_sampling import CondensedNearestNeighbour
from imblearn.combine import SMOTETomek
from imblearn.combine import SMOTEENN

from imblearn.pipeline import make_pipeline as make_imb_pipeline

import collections
from collections import Counter 
from collections import OrderedDict

#show graphs in notebook
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# Import database. The construct the database is available in https://github.com/tmedeirosb/modelo_ifrn_integrado/blob/master/versao_2/workflow_criando_base.ipynb

# %%
#impor database
drive.mount('/content/drive')
dados_tunning = pd.read_json('/content/drive/My Drive/Colab Notebooks/dados/dados_workflow_ivan.json')
dados = dados_tunning.copy()
dados.shape
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (8908, 33)

# %% [markdown]
# Functions to pre-process data (remove NaN, dummies transform),  and evaluate the model

# %%
#config enviroment
#show all columns
pd.set_option('display.max_columns', None)

#clean the NaN
def preparing_data(dados):
    print(dados.shape)
    dados = dados.dropna()
    print(dados.shape)
    
    #configura os dados de entrada e saída
    y = dados.classe
    X = dados

    del X['classe']
    X.shape    
    
    #binazira os dados devido aos atributos categoricos 
    dados_dummies = pd.get_dummies(X, drop_first=True)
    dados_dummies.shape

    #remove atributos inconistentes
    dados_clean = dados_dummies.replace([np.inf, -np.inf], np.nan)
    dados_clean = dados_clean.dropna(axis=1, how='all')
    #print(dados_clean.info())
    
    return (dados_clean, y)

# %% [markdown]
# Define os atributos da base de dados e, caso ainda tenha valores NAN, substituti por -1

# %%
#select attributes
atributos = [
       'LnguaPortuguesaeLiteraturaI90H',
       'LnguaPortuguesaeLiteraturaI90H_dependencia',
       'LnguaPortuguesaeLiteraturaI90H_freq', 'MatemticaI120H',
       'MatemticaI120H_dependencia', 'MatemticaI120H_freq', 'acompanhamento',
       'aluno_exclusivo_rede_publica', 'artificial', 'classe', 'conceito',
       'conceito_freq', 'descricao_area_residencial',
       'descricao_companhia_domiciliar', 'descricao_estado_civil',
       'descricao_historico', 'descricao_imovel', 'descricao_mae_escolaridade',
       'descricao_pai_escolaridade', 'descricao_raca',
       'descricao_responsavel_escolaridade',
       'descricao_responsavel_financeiro', 'descricao_trabalho', 'idade',
       'pessoa_fisica__sexo', 'possui_necessidade_especial', 'qnt_pc',
       'qnt_salarios', 'qtd_pessoas_domicilio', 'sigla',
       'tempo_entre_conclusao_ingresso'    
]

dados = dados[atributos]

#fill NAN
dados['LnguaPortuguesaeLiteraturaI90H'].fillna(-1, inplace=True)
dados['LnguaPortuguesaeLiteraturaI90H_dependencia'].fillna(-1, inplace=True)
dados['LnguaPortuguesaeLiteraturaI90H_freq'].fillna(-1, inplace=True)

dados['MatemticaI120H'].fillna(-1, inplace=True)
dados['MatemticaI120H_dependencia'].fillna(-1, inplace=True)
dados['MatemticaI120H_freq'].fillna(-1, inplace=True)

#use original data
dados = dados[dados.artificial == 0]

print(dados.classe.value_counts())

dados.head(2)
# Out:
# 1    7369
# 0     349
# Name: classe, dtype: int64
#     LnguaPortuguesaeLiteraturaI90H  \
# 0                             68.0
# 10                            61.0
#
#     LnguaPortuguesaeLiteraturaI90H_dependencia  \
# 0                                            0
# 10                                           0
#
#     LnguaPortuguesaeLiteraturaI90H_freq  MatemticaI120H  \
# 0                                 100.0            66.0
# 10                                100.0            60.0
#
#     MatemticaI120H_dependencia  MatemticaI120H_freq  acompanhamento  \
# 0                            0                100.0               0
# 10                           0                100.0               0
#
#     aluno_exclusivo_rede_publica  artificial  classe conceito conceito_freq  \
# 0                          False           0       1        B             A
# 10                         False           0       1        B             A
#
#    descricao_area_residencial descricao_companhia_domiciliar  \
# 0                      Urbana                            Mãe
# 10                     Urbana                           Pais
#
#    descricao_estado_civil                    descricao_historico  \
# 0             Solteiro(a)  Técnico de Nivel Médio em Informática
# 10            Solteiro(a)  Técnico de Nivel Médio em Informática
#
#    descricao_imovel     descricao_mae_escolaridade  \
# 0           Alugado  Ensino fundamental incompleto
# 10          Alugado          Ensino médio completo
#
#        descricao_pai_escolaridade descricao_raca  \
# 0   Ensino fundamental incompleto         Branca
# 10          Ensino médio completo          Parda
#
#    descricao_responsavel_escolaridade descricao_responsavel_financeiro  \
# 0       Ensino fundamental incompleto                              Mãe
# 10              Ensino médio completo                              Mãe
#
#    descricao_trabalho  idade pessoa_fisica__sexo  possui_necessidade_especial  \
# 0       Não informado     15                   F                        False
# 10      Não informado     15                   M                         True
#
#     qnt_pc  qnt_salarios  qtd_pessoas_domicilio sigla  \
# 0        0             1                      2   LAJ
# 10       0             2                      5  CANG
#
#     tempo_entre_conclusao_ingresso
# 0                                1
# 10                               2

# %% [markdown]
# Separa os dados em 25% de teste e 75% de treino. Os dois folds são estratificados de acordo com o balanceamento da classe de evasão, a fim de manter a proporção dos dados do conjunto original.
#
# Esse conjunto de dados será utilizado em todos os modelos

# %%
#split data test and training. Stratify like imbalanced classes
X, y = preparing_data(dados)
print(X.shape)

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=42, stratify = y)
# Out:
# (7718, 31)
# (7718, 31)
# (7718, 151)

# %%
#visualizando distribuicao de dados 
plt.figure()
#sns.distplot(ytrain)
ytrain.plot.hist()
print(len(ytrain))

plt.figure()
#sns.distplot(ytest)
ytest.plot.hist()
print(len(ytest))
# Out:
# 5788
# 1930

# %%
class ModelML:
  def __init__(self, model, hyperparameters=None, balance=""):
        self.base = model
        self.name = model.__class__.__name__+" "+balance        
        self.hyperparameters = hyperparameters
        self.best_attr = []
        self.balance = balance
        self.best_params = None
        self.best_score = None
        self.best_model = None
        
#cria lista de modelos que serao utilizados no trabalho
def make_list_model(balance=""):
  #DEFINICAO DOS MODELOS A SEREM TREINADOS
  par_DT = {
            "criterion": ["gini", "entropy"],
            "max_depth": [None, 3, 5],
            "max_leaf_nodes": [None, 5, 10, 20]
            }

  par_SVC = {
              "kernel": ['rbf'],  
              "C": [0.001, 0.01, 0.1, 1, 10],
            }

  par_LR = {
              "solver": ["newton-cg", "lbfgs", "liblinear"]
            }

  par_MLP = {
                  'solver': ['lbfgs'], 
                  'max_iter': [200],
                  'alpha': 10.0 ** -np.arange(1, 4), 
                  'hidden_layer_sizes':np.arange(5, 20, 3), 
                  'random_state':[0]
              }

  par_RF = {
                "max_features": ["auto"],
                'n_estimators': [10, 30, 100, 200, 300]
            }

  par_NB = {
              'alpha':np.linspace(0.1,1,10)
           }

  models = [ModelML(DecisionTreeClassifier(), par_DT, balance), #RFEC OK
            #ModelML(SVC(probability=True, gamma='auto'), par_SVC), #RFEC NO
            ModelML(LogisticRegression(solver="lbfgs"), par_LR, balance), #RFEC OK
            #ModelML(MLPClassifier(), par_MLP), #RFEC NO
            ModelML(RandomForestClassifier(n_estimators=10), par_RF, balance), #RFEC OK
            ModelML(BernoulliNB(), par_NB, balance) #RFEC OK
           ]
  
  return models
        
        
#seleciona os melhores atributos para cada modelo
def select_attr(models, Xtrain, ytrain, columns):
  #seleciona os melhores atributos por modelo
  for model in models:

      #if model.name in ['SVC', 'MLPClassifier']:
      #    continue

      print(model.name)
      print('-'*len(model.name))

      #seleciona os melhores atributos para cada modelo
      selector = RFECV(clone(model.base), cv=10, n_jobs=-1, scoring=make_scorer(geometric_mean_score))
      selector.fit(Xtrain, ytrain)

      best_columns = list(columns[selector.support_])
      #print("Best Columns \n{}\n".format(best_columns))    

      #salva os melhores atributos para o modelo
      model.best_attr = best_columns   

#ranking dos atributos pela frequencia que ocorreu para cada modelo
def show_ranking_attr(models):

  ranking_attr = []
  tmp = []

  #para cada modelo, recupera os melhores atributos
  for model in models:
    #print(model.best_attr)
    tmp.append(model.best_attr)

  #print(tmp)
  #ranking das features
  x = sum(tmp, [])
  counter = collections.Counter(x)
  sorted_dict = OrderedDict(sorted(counter.items(), key=lambda t: t[1], reverse=True))
  
  #cnt = 0
  #for k, v in sorted_dict.items():
  #    print(cnt, k, v)
  #    cnt = cnt + 1
      
  return sorted_dict

#seleciona o melhor conjunto de atributos (freq > 1)
def select_best_attr_comite(sorted_under, models):
  #selecionando os melhores atributos do comite

  #deve ter sido selecionado ao menos por duas tecnicas
  attr_2 = [k for k, v in sorted_under.items() if v > 1]
  print(attr_2)

  #max_freq = (max(sorted_under.values()))
  #attr_max = [k for k, v in sorted_under.items() if v == max_freq]
  #print(attr_max)

  #atualiza os melhores atributos
  for model in models:
    model.best_attr = attr_2
    

#treina cada modelo de acordo com os melhores atributos
def select_model_tun(Xtrain, Xtest, ytrain, ytest, models):    
    #treina o modelo de acordo com os atributos selecionados
    for model in models:    
        #se o modelo nao houve selecao de atributos, considera todos
        if len(model.best_attr) == 0:
          model.best_attr = Xtrain.columns            
                
        Xtrain_2 = Xtrain[model.best_attr]
        Xtest_2  = Xtest[model.best_attr]
        
        print(model.name)
        #print(model.best_attr)
        print('-'*len(model.name))         
        
        grid = GridSearchCV(model.base,
                            param_grid=model.hyperparameters,
                            cv=10, 
                            scoring=make_scorer(geometric_mean_score))
        
        grid.fit(Xtrain_2, ytrain)
        model.best_params = grid.best_params_
        model.best_score = grid.best_score_
        model.best_model = grid.best_estimator_
                
        print("Best Score: {}".format(model.best_score))
        print("Best Parameters: {}".format(model.best_params))        
          
def plot_comp_models(models):  
  results = []
  names = []
  
  for model in models:      
    results.append(model.cv_results)
    names.append(model.name)

  fig = plt.figure()
  fig.suptitle('Algorithm Comparison')
  fig.set_size_inches(11.7, 8.27)
  ax = fig.add_subplot(111)
  plt.boxplot( results )
  ax.set_xticklabels( names )
  plt.xticks(rotation=90)
  plt.show()
  
#plot roc curve
def plot_roc_curve(fpr, tpr, label=None):    
    plt.plot(fpr, tpr, linewidth=2, label=label)    
    plt.plot([0, 1], [0, 1], 'k--')    
    plt.axis([0, 1, 0, 1])   
    plt.xlabel('False Positive Rate')    
    plt.ylabel('True Positive Rate')


def evaluating_models(models, Xtest, ytest, results):
  #avaliacao individual por modelo
  for model in models:        
      print('\n\n'+model.name)
      print('-'*len(model.name))

      print("Melhor Modelo")
      print(len(model.best_attr))
      print(model.best_model)
      
      #sim
      ypred = model.best_model.predict(Xtest[model.best_attr])
      
      #matriz de confusao (AP: atual positivo, AN: atual negativo, PP: pred. positivo, PN: pred. negativo)
      #     AN | AP 
      # --------------
      # PN: TN | FN
      # PP: FP | TP

      #Text summary of the precision, recall, F1 score for each class
      #precision = TP/(TP+FP); TN/(TN+FN) 
      #recall    = TP/(TP+FN); TN/(TN+FP)
      class_report = classification_report(ytest, ypred, output_dict=True)
      #print(class_report.report)

      #matriz
      mat = confusion_matrix(ytest, ypred)
      sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
      plt.xlabel('true label')
      plt.ylabel('predicted label');

      #tn, fp, fn, tp = confusion_matrix(ytest, ypred).ravel()    
      #print(tp)
      #print(tn)
      #print(fn)
      #print(fp)
      #print( tn/(tn+fp) )

      #CURVA ROC
      fig = plt.figure()
      y_probas = cross_val_predict(model.best_model, Xtest, ytest, cv=10, method="predict_proba") 

      #TODO COLOCAR DA CLASSE NEGATIVA
      y_scores = y_probas[:, 1]   # score = proba of positive class 
      fpr, tpr, thresholds = roc_curve(ytest, y_scores)

      #plot_roc_curve(fpr, tpr) 
      #plt.show()
      auc = roc_auc_score(ytest, y_scores)
      #print("AUC: %f" % auc)            

      #GMEAN
      #print("G-MEAN: %f" % geometric_mean_score(ytest, ypred))            
      g = geometric_mean_score(ytest, ypred)
            
      #atualiza o frame de results
      results = results.append( pd.DataFrame({'name' : [model.name], 
                                    'precision' : [class_report["1"]["precision"]], 
                                    'recall' : [class_report["1"]["recall"]], 
                                    'f1' : [class_report["1"]["f1-score"]], 
                                    'auc' : [auc], 
                                    'g-mean' : [g]
                                    }
                              ), ignore_index=True
                                  
                    )      
      
  # boxplot algorithm comparison
  #plot_comp_models(models)
  
  #return(results, names)
  print(results)
  return results

# %%
#modelo sem balanceamento e com todos os atributos 
models_sem = make_list_model()

#seleciona o melhor modelo
select_model_tun(Xtrain, Xtest, ytrain, ytest, models_sem)

#avaliacao dos modelos 
results = pd.DataFrame({'name' : [], 'precision' : [], 'recall' : [], 'f1' : [], 'auc' : [], 'g-mean' : []})
results = evaluating_models(models_sem, Xtest, ytest, results)
# Out:
# DecisionTreeClassifier
# -----------------------
# Best Score: 0.6593752707599174
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20}
# LogisticRegression
# -------------------
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# Best Score: 0.5368841192922973
# Best Parameters: {'solver': 'newton-cg'}
# RandomForestClassifier
# -----------------------
# Best Score: 0.5873185789918564
# Best Parameters: {'max_features': 'auto', 'n_estimators': 10}
# BernoulliNB
# ------------
# Best Score: 0.6766361737031936
# Best Parameters: {'alpha': 0.8}
#
#
# DecisionTreeClassifier
# -----------------------
# Melhor Modelo
# 151
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=20,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
# LogisticRegression
# -------------------
# Melhor Modelo
# 151
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='newton-cg', tol=0.0001, verbose=0,
#                    warm_start=False)
# RandomForestClassifier
# -----------------------
# Melhor Modelo
# 151
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# BernoulliNB
# ------------
# Melhor Modelo
# 151
# BernoulliNB(alpha=0.8, binarize=0.0, class_prior=None, fit_prior=True)
#                       name  precision    recall        f1       auc    g-mean
# 0  DecisionTreeClassifier    0.977480  0.989148  0.983279  0.793652  0.715282
# 1      LogisticRegression    0.971338  0.992946  0.982023  0.928215  0.613706
# 2  RandomForestClassifier    0.972384  0.993489  0.982823  0.857669  0.632202
# 3             BernoulliNB    0.976014  0.927292  0.951029  0.857647  0.692556

# %%
#modelo sem balanceamento e com selecao de atributos
models_SF = make_list_model("FS - NO BAL")

#seleciona os melhores atributos
select_attr(models_SF, Xtrain, ytrain, Xtrain.columns)

#ranking dos melhores atributos
sorted_SF = show_ranking_attr(models_SF)

#selecionando os melhores atributos
select_best_attr_comite(sorted_SF, models_SF)

#treina o modelo com os melhores atributos
select_model_tun(Xtrain, Xtest, ytrain, ytest, models_SF)

# %%
#sorted_SF
print(len(models_SF[0].best_attr))

#avalia os modelos
#results = pd.DataFrame({'name' : [], 'precision' : [], 'recall' : [], 'f1' : [], 'auc' : [], 'g-mean' : []})
results = evaluating_models(models_SF, Xtest, ytest, results)
results
# Out:
# 117
#
#
# DecisionTreeClassifier FS - NO BAL
# ----------------------------------
# Melhor Modelo
# 117
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
# LogisticRegression FS - NO BAL
# ------------------------------
# Melhor Modelo
# 117
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='newton-cg', tol=0.0001, verbose=0,
#                    warm_start=False)
# RandomForestClassifier FS - NO BAL
# ----------------------------------
# Melhor Modelo
# 117
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
# BernoulliNB FS - NO BAL
# -----------------------
# Melhor Modelo
# 117
# BernoulliNB(alpha=0.30000000000000004, binarize=0.0, class_prior=None,
#             fit_prior=True)
#                                  name  precision    recall        f1  \
# 0             DecisionTreeClassifier    0.977480  0.989148  0.983279
# 1                 LogisticRegression    0.971338  0.992946  0.982023
# 2             RandomForestClassifier    0.972384  0.993489  0.982823
# 3                        BernoulliNB    0.976014  0.927292  0.951029
# 4  DecisionTreeClassifier FS - NO BAL   0.977620  0.971785  0.974694
# 5      LogisticRegression FS - NO BAL   0.970807  0.992404  0.981486
# 6  RandomForestClassifier FS - NO BAL   0.976471  0.990776  0.983571
# 7             BernoulliNB FS - NO BAL   0.977891  0.935974  0.956474
#
#         auc    g-mean
# 0  0.793652  0.715282
# 1  0.928215  0.613706
# 2  0.857669  0.632202
# 3  0.857647  0.692556
# 4  0.734918  0.716811
# 5  0.928215  0.604171
# 6  0.879950  0.699781
# 7  0.855851  0.718609
#                                  name  precision    recall        f1  \
# 0             DecisionTreeClassifier    0.977480  0.989148  0.983279
# 1                 LogisticRegression    0.971338  0.992946  0.982023
# 2             RandomForestClassifier    0.972384  0.993489  0.982823
# 3                        BernoulliNB    0.976014  0.927292  0.951029
# 4  DecisionTreeClassifier FS - NO BAL   0.977620  0.971785  0.974694
# 5      LogisticRegression FS - NO BAL   0.970807  0.992404  0.981486
# 6  RandomForestClassifier FS - NO BAL   0.976471  0.990776  0.983571
# 7             BernoulliNB FS - NO BAL   0.977891  0.935974  0.956474
#
#         auc    g-mean
# 0  0.793652  0.715282
# 1  0.928215  0.613706
# 2  0.857669  0.632202
# 3  0.857647  0.692556
# 4  0.734918  0.716811
# 5  0.928215  0.604171
# 6  0.879950  0.699781
# 7  0.855851  0.718609

# %%
#SELECIONA OS MELHORES ATRIBUTOS PARA O UNDER SAMPLE
models_under = make_list_model("UNDER")

#balanceamento de dados
rus = RandomUnderSampler(random_state=42)
X_under, y_under = rus.fit_resample(Xtrain, ytrain)

#mantem em formato de dataframe
X_under = pd.DataFrame(X_under)
X_under.columns = Xtrain.columns

#seleciona os melhores atributos
select_attr(models_under, X_under, y_under, Xtrain.columns)

#ranking dos melhores atributos
sorted_under = show_ranking_attr(models_under)

#selecionando os melhores atributos
select_best_attr_comite(sorted_under, models_under)

#seleciona melhor modelo com os atributos selecionados
select_model_tun(X_under, Xtest, y_under, ytest, models_under)

#avalia modelos
results = evaluating_models(models_under, Xtest, ytest, results)

# %%
results2 = pd.DataFrame({'name' : [], 'precision' : [], 'recall' : [], 'f1' : [], 'auc' : [], 'g-mean' : []})
results2 = evaluating_models(models_under, Xtest, ytest, results2)
# Out:
# DecisionTreeClassifier UNDER
# ----------------------------
# Melhor Modelo
# 101
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#                        max_features=None, max_leaf_nodes=10,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
#
#
# LogisticRegression UNDER
# ------------------------
# Melhor Modelo
# 101
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# RandomForestClassifier UNDER
# ----------------------------
# Melhor Modelo
# 101
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
# BernoulliNB UNDER
# -----------------
# Melhor Modelo
# 101
# BernoulliNB(alpha=0.4, binarize=0.0, class_prior=None, fit_prior=True)
#                            name  precision    recall        f1       auc  \
# 0  DecisionTreeClassifier UNDER   0.994382  0.864352  0.924819  0.924106
# 1      LogisticRegression UNDER   0.995053  0.873033  0.930058  0.928590
# 2  RandomForestClassifier UNDER   0.993218  0.874118  0.929870  0.936747
# 3             BernoulliNB UNDER   0.989474  0.765057  0.862913  0.856880
#
#      g-mean
# 0  0.880304
# 1  0.890367
# 2  0.873841
# 3  0.795708

# %%
#SELECIONA OS MELHORES ATRIBUTOS PARA O SMOTE SAMPLE
models_smote = make_list_model("SMOTE")

#balanceamento de dados
rsm = SMOTE(random_state=42)
X_smote, y_smote = rsm.fit_resample(Xtrain, ytrain)

#mantem em formato de dataframe
X_smote = pd.DataFrame(X_smote)
X_smote.columns = Xtrain.columns

#seleciona os melhores atributos
select_attr(models_smote, X_smote, y_smote, Xtrain.columns)

#ranking dos melhores atributos
sorted_smote = show_ranking_attr(models_smote)

#selecionando os melhores atributos
select_best_attr_comite(sorted_smote, models_smote)

#treina o modelo com os melhores atributos
select_model_tun(X_smote, Xtest, y_smote, ytest, models_smote)

#avalia os modelos
results = evaluating_models(models_smote, Xtest, ytest, results)

# %%
results2 = pd.DataFrame({'name' : [], 'precision' : [], 'recall' : [], 'f1' : [], 'auc' : [], 'g-mean' : []})
results2 = evaluating_models(models_smote, Xtest, ytest, results2)
# Out:
# DecisionTreeClassifier SMOTE
# ----------------------------
# Melhor Modelo
# 115
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
#
#
# LogisticRegression SMOTE
# ------------------------
# Melhor Modelo
# 115
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='newton-cg', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# RandomForestClassifier SMOTE
# ----------------------------
# Melhor Modelo
# 115
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
# BernoulliNB SMOTE
# -----------------
# Melhor Modelo
# 115
# BernoulliNB(alpha=0.1, binarize=0.0, class_prior=None, fit_prior=True)
#                            name  precision    recall        f1       auc  \
# 0  DecisionTreeClassifier SMOTE   0.976061  0.973413  0.974735  0.754601
# 1      LogisticRegression SMOTE   0.992049  0.880087  0.932720  0.928215
# 2  RandomForestClassifier SMOTE   0.972887  0.992946  0.982814  0.886679
# 3             BernoulliNB SMOTE   0.979045  0.912642  0.944678  0.850668
#
#      g-mean
# 0  0.693622
# 1  0.865205
# 2  0.640995
# 3  0.731435

# %%
#comparando todos os modelos
#all_models = models_sem + models_under + models_smote
#plot_comp_models(all_models)

my_colors = ['g', 'b']*5 # <-- this concatenates the list to itself 5 times.
my_colors = [(0.5,0.4,0.5), (0.75, 0.75, 0.25)]*5 # <-- make two custom RGBs and repeat/alternate them over all the bar elements.
my_colors = [(x/20.0, x/40.0, 0.75) for x in range(len(results))] # <-

#results.plot.bar(x='name', y='g-mean', rot=90, color=my_colors)
results.plot.bar(x='name', y='g-mean', rot=90, color=np.where(results["g-mean"]>0.8, 'g', 'r'), legend=False)
#results.plot.bar(x='name', y='auc', rot=90, color=my_colors)
results.plot.bar(x='name', y='auc', rot=90, color=np.where(results["auc"]>0.8, 'g', 'r'), legend=False)

results
# Out:
#                                   name  precision    recall        f1  \
# 0              DecisionTreeClassifier    0.977480  0.989148  0.983279
# 1                  LogisticRegression    0.971338  0.992946  0.982023
# 2              RandomForestClassifier    0.972384  0.993489  0.982823
# 3                         BernoulliNB    0.976014  0.927292  0.951029
# 4   DecisionTreeClassifier FS - NO BAL   0.977620  0.971785  0.974694
# 5       LogisticRegression FS - NO BAL   0.970807  0.992404  0.981486
# 6   RandomForestClassifier FS - NO BAL   0.976471  0.990776  0.983571
# 7              BernoulliNB FS - NO BAL   0.977891  0.935974  0.956474
# 8         DecisionTreeClassifier UNDER   0.994382  0.864352  0.924819
# 9             LogisticRegression UNDER   0.995053  0.873033  0.930058
# 10        RandomForestClassifier UNDER   0.993218  0.874118  0.929870
# 11                   BernoulliNB UNDER   0.989474  0.765057  0.862913
# 12        DecisionTreeClassifier SMOTE   0.976061  0.973413  0.974735
# 13            LogisticRegression SMOTE   0.992049  0.880087  0.932720
# 14        RandomForestClassifier SMOTE   0.972887  0.992946  0.982814
# 15                   BernoulliNB SMOTE   0.979045  0.912642  0.944678
#
#          auc    g-mean
# 0   0.793652  0.715282
# 1   0.928215  0.613706
# 2   0.857669  0.632202
# 3   0.857647  0.692556
# 4   0.734918  0.716811
# 5   0.928215  0.604171
# 6   0.879950  0.699781
# 7   0.855851  0.718609
# 8   0.915044  0.880304
# 9   0.928590  0.890367
# 10  0.940533  0.873841
# 11  0.856880  0.795708
# 12  0.740665  0.693622
# 13  0.928215  0.865205
# 14  0.872416  0.640995
# 15  0.850668  0.731435

# %%
print(results[['name', 'precision', 'recall', 'auc', 'g-mean']].to_latex())
# Out:
# \begin{tabular}{llrrrr}
# \toprule
# {} &                                name &  precision &    recall &       auc &    g-mean \\
# \midrule
# 0  &             DecisionTreeClassifier  &   0.977480 &  0.989148 &  0.793652 &  0.715282 \\
# 1  &                 LogisticRegression  &   0.971338 &  0.992946 &  0.928215 &  0.613706 \\
# 2  &             RandomForestClassifier  &   0.972384 &  0.993489 &  0.857669 &  0.632202 \\
# 3  &                        BernoulliNB  &   0.976014 &  0.927292 &  0.857647 &  0.692556 \\
# 4  &  DecisionTreeClassifier FS - NO BAL &   0.977620 &  0.971785 &  0.734918 &  0.716811 \\
# 5  &      LogisticRegression FS - NO BAL &   0.970807 &  0.992404 &  0.928215 &  0.604171 \\
# 6  &  RandomForestClassifier FS - NO BAL &   0.976471 &  0.990776 &  0.879950 &  0.699781 \\
# 7  &             BernoulliNB FS - NO BAL &   0.977891 &  0.935974 &  0.855851 &  0.718609 \\
# 8  &        DecisionTreeClassifier UNDER &   0.994382 &  0.864352 &  0.915044 &  0.880304 \\
# 9  &            LogisticRegression UNDER &   0.995053 &  0.873033 &  0.928590 &  0.890367 \\
# 10 &        RandomForestClassifier UNDER &   0.993218 &  0.874118 &  0.940533 &  0.873841 \\
# 11 &                   BernoulliNB UNDER &   0.989474 &  0.765057 &  0.856880 &  0.795708 \\
# 12 &        DecisionTreeClassifier SMOTE &   0.976061 &  0.973413 &  0.740665 &  0.693622 \\
# 13 &            LogisticRegression SMOTE &   0.992049 &  0.880087 &  0.928215 &  0.865205 \\
# 14 &        RandomForestClassifier SMOTE &   0.972887 &  0.992946 &  0.872416 &  0.640995 \\
# 15 &                   BernoulliNB SMOTE &   0.979045 &  0.912642 &  0.850668 &  0.731435 \\
# \bottomrule
# \end{tabular}

# %%
#otimizacao de quantidade de atributos

un = len(models_under[0].best_attr)
sm = len(models_smote[0].best_attr)
no = len(models_sem[0].best_attr)

print(un)
print(sm)
print(no)

print(1-un/no)
print(1-sm/no)
print(1-un/sm)
# Out:
# 101
# 115
# 151
# 0.33112582781456956
# 0.23841059602649006
# 0.12173913043478257

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from sklearn.datasets import load_wine
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

graph = Source(tree.export_graphviz(models_under[0].best_model, out_file=None
   , feature_names=models_under[0].best_attr
   , filled = True
   , rounded=True))
               
display(SVG(graph.pipe(format='svg')))

# %%
graph = Source(tree.export_graphviz(models_smote[0].best_model, out_file=None
   , feature_names=models_smote[0].best_attr
   , filled = True
   , rounded=True))
               
display(SVG(graph.pipe(format='svg')))

# %%
#TESTE PARA FEATURES IMPORTANCE LOGISTIC

m = models_under[1]

#mean
importances = m.best_model.coef_[0]*-1

#indices
indices = np.argsort(importances)[::-1]

print("Feature COEF:")

# Plot the feature importances of the forest
fig = plt.figure()
fig.set_size_inches(25.0, 8.27)
plt.title("Feature Coeficient")
plt.bar(range(Xtest[m.best_attr].shape[1]), importances[indices], color="r", align="center")
#plt.xticks(range(Xtest.shape[1]), indices)
plt.xticks(range(Xtest[m.best_attr].shape[1]), Xtest[m.best_attr].columns[indices])
#ax.set_xticklabels( names )
plt.xticks(rotation=90)
plt.xlim([-1, Xtest[m.best_attr].shape[1]])
plt.show()
# Out:
# Feature COEF:

# %%
from skater.core.explanations import Interpretation
from skater.model import InMemoryModel

# Ensemble Classifier does not have feature importance enabled by default
f, axes = plt.subplots(4, 1, figsize = (10, 80))

#f.bar(width=.9)

ax_dict = {
    'DecisionTreeClassifier UNDER':axes[0],
    'LogisticRegression UNDER':axes[1],
    'RandomForestClassifier UNDER':axes[2],
    'BernoulliNB UNDER':axes[3]
}	

interpreter = Interpretation(Xtest[m.best_attr], feature_names=m.best_attr)

for model in models_under:
    pyint_model = InMemoryModel(model.best_model.predict_proba, examples=Xtest[model.best_attr])
    ax = ax_dict[model.name]
    #ax.axes.barWidth = 1.2
    interpreter.feature_importance.plot_feature_importance(pyint_model, ascending=True, ax=ax)
    ax.set_title(model.name)
# Out:
# 2019-07-16 22:23:27,825 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progress_bar=False
# [101/101] features ████████████████████ Time elapsed: 41 seconds
# 2019-07-16 22:24:09,579 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progress_bar=False
# [101/101] features ████████████████████ Time elapsed: 43 seconds
# 2019-07-16 22:24:53,703 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progress_bar=False
# [101/101] features ████████████████████ Time elapsed: 50 seconds
# 2019-07-16 22:25:44,958 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progress_bar=False
# [101/101] features ████████████████████ Time elapsed: 42 seconds

# %%
sorted_under
# Out:
# OrderedDict([('conceito_I', 4),
#              ('conceito_R', 4),
#              ('conceito_freq_R', 4),
#              ('descricao_pai_escolaridade_Não conhece', 4),
#              ('conceito_O', 3),
#              ('descricao_companhia_domiciliar_Pai', 3),
#              ('descricao_companhia_domiciliar_Parente(s) ou amigo(s)', 3),
#              ('descricao_historico_Técnico de Nível Médio em Administração',
#               3),
#              ('descricao_historico_Técnico de Nível Médio em Mecatrônica', 3),
#              ('descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros',
#               3),
#              ('descricao_mae_escolaridade_Ensino superior incompleto', 3),
#              ('descricao_pai_escolaridade_Ensino médio incompleto', 3),
#              ('descricao_responsavel_escolaridade_Ensino superior incompleto',
#               3),
#              ('descricao_responsavel_financeiro_Irmão(ã)', 3),
#              ('sigla_LAJ', 3),
#              ('sigla_SC', 3),
#              ('descricao_historico_Técnico de Nível Médio em Edificações', 3),
#              ('LnguaPortuguesaeLiteraturaI90H', 2),
#              ('LnguaPortuguesaeLiteraturaI90H_dependencia', 2),
#              ('LnguaPortuguesaeLiteraturaI90H_freq', 2),
#              ('MatemticaI120H', 2),
#              ('MatemticaI120H_dependencia', 2),
#              ('MatemticaI120H_freq', 2),
#              ('acompanhamento', 2),
#              ('aluno_exclusivo_rede_publica', 2),
#              ('artificial', 2),
#              ('idade', 2),
#              ('possui_necessidade_especial', 2),
#              ('qnt_pc', 2),
#              ('qnt_salarios', 2),
#              ('qtd_pessoas_domicilio', 2),
#              ('tempo_entre_conclusao_ingresso', 2),
#              ('conceito_freq_I', 2),
#              ('descricao_area_residencial_Comunidade Quilombola', 2),
#              ('descricao_area_residencial_Não informado', 2),
#              ('descricao_area_residencial_Rural', 2),
#              ('descricao_area_residencial_Urbana', 2),
#              ('descricao_companhia_domiciliar_Mãe', 2),
#              ('descricao_companhia_domiciliar_Não informado', 2),
#              ('descricao_companhia_domiciliar_Outros', 2),
#              ('descricao_companhia_domiciliar_Pais', 2),
#              ('descricao_companhia_domiciliar_Sozinho(a)', 2),
#              ('descricao_estado_civil_Divorciado(a)', 2),
#              ('descricao_estado_civil_Não declarado', 2),
#              ('descricao_estado_civil_União Estável', 2),
#              ('descricao_historico_Técnico de Nivel Médio em Equipamentos Biomédicos',
#               2),
#              ('descricao_historico_Técnico de Nível Médio em Controle Ambiental',
#               2),
#              ('descricao_historico_Técnico de Nível Médio em Eletrotécnica',
#               2),
#              ('descricao_historico_Técnico de Nível Médio em Informática para Internet',
#               2),
#              ('descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática',
#               2),
#              ('descricao_historico_Técnico de Nível Médio em Mecânica', 2),
#              ('descricao_historico_Técnico de Nível Médio em Meio Ambiente',
#               2),
#              ('descricao_historico_Técnico em Programação de Jogos Digitais',
#               2),
#              ('descricao_mae_escolaridade_Ensino fundamental incompleto', 2),
#              ('descricao_mae_escolaridade_Ensino médio completo', 2),
#              ('descricao_pai_escolaridade_Ensino superior completo', 2),
#              ('descricao_pai_escolaridade_Ensino superior incompleto', 2),
#              ('descricao_pai_escolaridade_Não estudou', 2),
#              ('descricao_pai_escolaridade_Pós graduação completo', 2),
#              ('descricao_pai_escolaridade_Pós graduação incompleto', 2),
#              ('descricao_raca_Branca', 2),
#              ('descricao_raca_Indígena', 2),
#              ('descricao_raca_Não declarado', 2),
#              ('descricao_raca_Parda', 2),
#              ('descricao_raca_Preta', 2),
#              ('descricao_responsavel_escolaridade_Ensino fundamental completo',
#               2),
#              ('descricao_responsavel_escolaridade_Ensino fundamental incompleto',
#               2),
#              ('descricao_responsavel_escolaridade_Ensino médio completo', 2),
#              ('descricao_responsavel_escolaridade_Ensino médio incompleto', 2),
#              ('descricao_responsavel_escolaridade_Não conhece', 2),
#              ('descricao_responsavel_escolaridade_Não estudou', 2),
#              ('descricao_responsavel_escolaridade_Pós graduação completo', 2),
#              ('descricao_responsavel_escolaridade_Pós graduação incompleto',
#               2),
#              ('descricao_responsavel_financeiro_Cônjuge', 2),
#              ('descricao_responsavel_financeiro_Mãe', 2),
#              ('descricao_responsavel_financeiro_Não informado', 2),
#              ('descricao_responsavel_financeiro_O próprio aluno', 2),
#              ('descricao_responsavel_financeiro_Outros', 2),
#              ('descricao_responsavel_financeiro_Pai', 2),
#              ('descricao_responsavel_financeiro_Parentes', 2),
#              ('descricao_trabalho_Autônomo', 2),
#              ('descricao_trabalho_Beneficiário ou Pensionista do INSS', 2),
#              ('descricao_trabalho_Estágio ou bolsa', 2),
#              ('descricao_trabalho_Nunca trabalhou', 2),
#              ('descricao_trabalho_Não informado', 2),
#              ('descricao_trabalho_Pescador', 2),
#              ('descricao_trabalho_Serviço público', 2),
#              ('descricao_trabalho_Trabalhador rural/Agricultor', 2),
#              ('sigla_CA', 2),
#              ('sigla_CAL', 2),
#              ('sigla_CN', 2),
#              ('sigla_CNAT', 2),
#              ('sigla_MC', 2),
#              ('sigla_MO', 2),
#              ('sigla_NC', 2),
#              ('sigla_PAAS', 2),
#              ('sigla_PAR', 2),
#              ('sigla_PF', 2),
#              ('sigla_SGA', 2),
#              ('descricao_pai_escolaridade_Ensino fundamental completo', 2),
#              ('sigla_SPP', 2),
#              ('conceito_S', 1),
#              ('conceito_freq_S', 1),
#              ('descricao_estado_civil_Solteiro(a)', 1),
#              ('descricao_responsavel_escolaridade_Ensino superior completo',
#               1),
#              ('descricao_historico_Técnico de Nivel Médio em Informática', 1),
#              ('descricao_imovel_Próprio', 1),
#              ('descricao_pai_escolaridade_Ensino fundamental incompleto', 1),
#              ('descricao_pai_escolaridade_Ensino médio completo', 1),
#              ('descricao_trabalho_Não está trabalhando', 1),
#              ('pessoa_fisica__sexo_M', 1),
#              ('descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada',
#               1),
#              ('descricao_historico_Técnico de Nivel Médio em Biocombustíveis',
#               1),
#              ('descricao_historico_Técnico de Nível Médio em Agroecologia', 1),
#              ('descricao_historico_Técnico de Nível Médio em Alimentos', 1),
#              ('descricao_historico_Técnico de Nível Médio em Apicultura', 1),
#              ('descricao_historico_Técnico de Nível Médio em Comércio', 1),
#              ('descricao_historico_Técnico de Nível Médio em Eletromecânica',
#               1),
#              ('descricao_historico_Técnico de Nível Médio em Eletrônica', 1),
#              ('descricao_historico_Técnico de Nível Médio em Eventos', 1),
#              ('descricao_historico_Técnico de Nível Médio em Geologia', 1),
#              ('descricao_historico_Técnico de Nível Médio em Informática', 1),
#              ('descricao_historico_Técnico de Nível Médio em Lazer', 1),
#              ('descricao_historico_Técnico de Nível Médio em Logística', 1),
#              ('descricao_historico_Técnico de Nível Médio em Mineração', 1),
#              ('descricao_historico_Técnico de Nível Médio em Multimídia', 1),
#              ('descricao_historico_Técnico de Nível Médio em Química', 1),
#              ('descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado',
#               1),
#              ('descricao_historico_Técnico de Nível Médio em Refrigeração e Climatização',
#               1),
#              ('descricao_historico_Técnico de Nível Médio em Têxtil', 1),
#              ('descricao_historico_Técnico de Nível Médio em Vestuário', 1),
#              ('descricao_imovel_Cedido ou Emprestado', 1),
#              ('descricao_imovel_Financiado', 1),
#              ('descricao_imovel_Não informado', 1),
#              ('descricao_imovel_Outro', 1),
#              ('descricao_imovel_Pensionato ou Alojamento', 1),
#              ('descricao_mae_escolaridade_Ensino fundamental completo', 1),
#              ('descricao_mae_escolaridade_Ensino médio incompleto', 1),
#              ('descricao_mae_escolaridade_Ensino superior completo', 1),
#              ('descricao_mae_escolaridade_Não conhece', 1),
#              ('descricao_mae_escolaridade_Não estudou', 1),
#              ('descricao_mae_escolaridade_Pós graduação completo', 1),
#              ('descricao_mae_escolaridade_Pós graduação incompleto', 1),
#              ('descricao_responsavel_financeiro_Tio(a)', 1),
#              ('descricao_trabalho_Empresa privada', 1),
#              ('descricao_trabalho_Trabalha com vínculo empregatício', 1),
#              ('sigla_CANG', 1),
#              ('sigla_CM', 1),
#              ('sigla_IP', 1),
#              ('sigla_JC', 1),
#              ('sigla_ZN', 1)])

# %%
"""
#TEST FEATURE IMPORTANCE LOGISTIC

#indices
sorted_coef = importances[indices]

my_list = [i for i in indices if importances[i] > 0]
#print(my_list)
#print(Xtest.iloc[:, my_list])

print("Feature COEF:")

# Plot the feature importances of the forest
fig = plt.figure()
fig.set_size_inches(20.0, 8.27)
plt.title("Feature Coeficient")
plt.bar(range(Xtest.iloc[:, my_list].shape[1]), importances[my_list], color="r", align="center")
#plt.xticks(range(Xtest.shape[1]), indices)
plt.xticks(range(Xtest.iloc[:, my_list].shape[1]), Xtest.columns[my_list])
#ax.set_xticklabels( names )
plt.xticks(rotation=90)
plt.xlim([-1, Xtest.iloc[:, my_list].shape[1]])
plt.show()
"""
# Out:
# '\n#TEST FEATURE IMPORTANCE LOGISTIC\n\n#indices\nsorted_coef = importances[indices]\n\nmy_list = [i for i in indices if importances[i] > 0]\n#print(my_list)\n#print(Xtest.iloc[:, my_list])\n\nprint("Feature COEF:")\n\n# Plot the feature importances of the forest\nfig = plt.figure()\nfig.set_size_inches(20.0, 8.27)\nplt.title("Feature Coeficient")\nplt.bar(range(Xtest.iloc[:, my_list].shape[1]), importances[my_list], color="r", align="center")\n#plt.xticks(range(Xtest.shape[1]), indices)\nplt.xticks(range(Xtest.iloc[:, my_list].shape[1]), Xtest.columns[my_list])\n#ax.set_xticklabels( names )\nplt.xticks(rotation=90)\nplt.xlim([-1, Xtest.iloc[:, my_list].shape[1]])\nplt.show()\n'

# %%
"""
#FEATURE IMPORTANCE 

#g = sns.distplot(importances[indices], hist_kws=dict(cumulative=True),
#             kde_kws=dict(cumulative=True))
#g.set(xticklabels=Xtest.columns[indices])

arr_cum = []
cum = 0
for f in range(Xtest.iloc[:, my_list].shape[1]):
  cum = cum + importances[my_list[f]]
  arr_cum.append(cum)
  #print("%d. feature [%s] (%f) - Cumulative: %f" % (f + 1, Xtest.columns[indices[f]], importances[indices[f]], cum))
  

print(importances[my_list])
print(len(importances[my_list]))
print(len(arr_cum))
  

fig, ax = plt.subplots()
fig.set_size_inches(25.0, 8.27)
plt.title("Feature importances cumulative")

#plt.xticks(range(Xtest.shape[1]), Xtest.columns[indices])
plt.xticks(rotation=90)
plt.xticks(range(Xtest.iloc[:, my_list].shape[1]), Xtest.columns[my_list])
#plt.bar(range(Xtest.iloc[:, my_list].shape[1]), importances[my_list], color="r", align="center")
plt.bar(range(Xtest.iloc[:, my_list].shape[1]), arr_cum, color="r", align="center")
"""
# Out:
# '\n#FEATURE IMPORTANCE \n\n#g = sns.distplot(importances[indices], hist_kws=dict(cumulative=True),\n#             kde_kws=dict(cumulative=True))\n#g.set(xticklabels=Xtest.columns[indices])\n\narr_cum = []\ncum = 0\nfor f in range(Xtest.iloc[:, my_list].shape[1]):\n  cum = cum + importances[my_list[f]]\n  arr_cum.append(cum)\n  #print("%d. feature [%s] (%f) - Cumulative: %f" % (f + 1, Xtest.columns[indices[f]], importances[indices[f]], cum))\n  \n\nprint(importances[my_list])\nprint(len(importances[my_list]))\nprint(len(arr_cum))\n  \n\nfig, ax = plt.subplots()\nfig.set_size_inches(25.0, 8.27)\nplt.title("Feature importances cumulative")\n\n#plt.xticks(range(Xtest.shape[1]), Xtest.columns[indices])\nplt.xticks(rotation=90)\nplt.xticks(range(Xtest.iloc[:, my_list].shape[1]), Xtest.columns[my_list])\n#plt.bar(range(Xtest.iloc[:, my_list].shape[1]), importances[my_list], color="r", align="center")\nplt.bar(range(Xtest.iloc[:, my_list].shape[1]), arr_cum, color="r", align="center")\n'

# %% [markdown]
# ##Utilizando técnicas robustas ao desbalanceamento

# %%
"""
#BalancedBaggingClassifier

#classificador base DT
tree = DecisionTreeClassifier(max_features='auto')

#otimiza parâmetros
parameters = {'n_estimators': (10, 30, 100, 200, 300)}

grid = GridSearchCV(BalancedBaggingClassifier(base_estimator=tree),
                    param_grid=parameters,
                    cv=10, 
                    verbose=1,
                    n_jobs = -1,
                    scoring=make_scorer(geometric_mean_score))

#treina
grid.fit(Xtrain, ytrain)

#exibe melhor modelo
print(grid.best_params_)
print(grid.best_score_)
ensemble = grid.best_estimator_

#predicao
ypred_ensemble = ensemble.predict(Xtest)

#avaliacao
evaluating(ensemble, ytest, ypred_ensemble, Xtest)

cv_results = model_selection.cross_val_score(ensemble, Xtest, ypred_ensemble, 
                                             cv=model_selection.KFold(
                                                 n_splits=10, random_state=42),
                                                 scoring=make_scorer(geometric_mean_score))
                                             #scoring='recall_macro')
                                             #scoring='accuracy')

results.append(cv_results)
names.append('Balanced Bagging')

msg = "Score do conjunto de testes: %f (%f) \n" % (cv_results.mean(), cv_results.std())
print(msg)

# boxplot algorithm comparison
plot_alg_comp(results, names)
"""
# Out:
# '\n#BalancedBaggingClassifier\n\n#classificador base DT\ntree = DecisionTreeClassifier(max_features=\'auto\')\n\n#otimiza parâmetros\nparameters = {\'n_estimators\': (10, 30, 100, 200, 300)}\n\ngrid = GridSearchCV(BalancedBaggingClassifier(base_estimator=tree),\n                    param_grid=parameters,\n                    cv=10, \n                    verbose=1,\n                    n_jobs = -1,\n                    scoring=make_scorer(geometric_mean_score))\n\n#treina\ngrid.fit(Xtrain, ytrain)\n\n#exibe melhor modelo\nprint(grid.best_params_)\nprint(grid.best_score_)\nensemble = grid.best_estimator_\n\n#predicao\nypred_ensemble = ensemble.predict(Xtest)\n\n#avaliacao\nevaluating(ensemble, ytest, ypred_ensemble, Xtest)\n\ncv_results = model_selection.cross_val_score(ensemble, Xtest, ypred_ensemble, \n                                             cv=model_selection.KFold(\n                                                 n_splits=10, random_state=42),\n                                                 scoring=make_scorer(geometric_mean_score))\n                                             #scoring=\'recall_macro\')\n                                             #scoring=\'accuracy\')\n\nresults.append(cv_results)\nnames.append(\'Balanced Bagging\')\n\nmsg = "Score do conjunto de testes: %f (%f) \n" % (cv_results.mean(), cv_results.std())\nprint(msg)\n\n# boxplot algorithm comparison\nplot_alg_comp(results, names)\n'

# %%
#erro min exp 01
print(1-(45+33+35+45)/(4*87))

#erro min exp 02
print(1-(46+32+43+48)/(4*87))

#erro min exp 03
print(1-(78+79+76+72)/(4*87))

#erro min exp 04
print(1-(43+74+36+51)/(4*87))
# Out:
# 0.5459770114942528
# 0.514367816091954
# 0.12356321839080464
# 0.4137931034482759

# %%
#erro min exp 01
print((20+13+12+134)/(4*1843))

#erro min exp 02
#print(1-(46+32+43+48)/(4*87))

#erro min exp 03
print((250+234+232+433)/(4*1843))

#erro min exp 04
#print(1-(43+74+36+51)/(4*87))
# Out:
# 0.024281063483450896
# 0.15586001085187196

# %%
#erro auc exp 01
print(results["auc"][0:4].mean())

#erro auc exp 02
print(results["auc"][4:8].mean())

#erro auc exp 03
print(results["auc"][8:12].mean())

#erro auc exp 04
print(results["auc"][12:16].mean())
# Out:
# 0.8592959692156092
# 0.8497335366500146
# 0.9102615675341929
# 0.8479911563480333

# %%
#erro auc exp 01
print(results["g-mean"][0:4].mean())

#erro auc exp 02
print(results["g-mean"][4:8].mean())

#erro auc exp 03
print(results["g-mean"][8:12].mean())

#erro auc exp 04
print(results["g-mean"][12:16].mean())
# Out:
# 0.6634364999040518
# 0.6848429464446311
# 0.8600550525616475
# 0.7328143225060915

# %%
#erro auc exp 01
print(results["recall"][0:4].mean())

#erro auc exp 03
print(results["recall"][8:12].mean())
# Out:
# 0.9757189365165491
# 0.844139989148128
