# %% [markdown]
# # Análise de alunos do integrado do IFRN
#
# a base de dados consiste em dados socioeconômicos e as notas finais de português e matemática do 1º e 2º ano. Essas disciplinas foram selecionadas devido a certeza delas estarem presente em todos os cursos de integrado ofertados no IFRN

# %%
#import os pacotes utilizados
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

#ESCALONAMENTO DE DADOS
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler

#SELECIONANDO MELHOR MODELO
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from scipy.stats import randint as sp_randint
from sklearn.cross_validation import train_test_split

#Evaluating
import seaborn as sns; sns.set()

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import f1_score

#EXPORTAR ARVORE
from sklearn.tree import export_graphviz
import os

#CURVA ROC
# %matplotlib inline
from sklearn.metrics import roc_curve
from sklearn.model_selection import cross_val_predict 
from sklearn.metrics import roc_auc_score

#REDUÇÃO DE DIMENSIONALIDADE
from sklearn.decomposition import PCA

# %matplotlib inline

#exibindo todas as colunas
pd.set_option('display.max_columns', None)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#definicao de funcoes que serao utilizadas

# Utility function to report best scores
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")
            
def plot_roc_curve(fpr, tpr, label=None):    
    plt.plot(fpr, tpr, linewidth=2, label=label)    
    plt.plot([0, 1], [0, 1], 'k--')    
    plt.axis([0, 1, 0, 1])   
    plt.xlabel('False Positive Rate')    
    plt.ylabel('True Positive Rate')

# %%
#importando base já tratada
dados = pd.read_json('dados_notas_col.json')
print(dados.id.nunique())
print(dados.shape)
dados.head(3)
# Out:
# 6395
# (6395, 34)
#         LnguaPortuguesaeLiteraturaI90H  LnguaPortuguesaeLiteraturaII90H  \
# 0                                   86                               -1
# 100002                              69                               -1
# 100021                              83                               -1
#
#         MatemticaI120H  MatemticaII90H  ano_letivo__ano  \
# 0                   87              -1             2016
# 100002               5              -1             2015
# 100021              77              -1             2016
#
#         ano_letivo__ano_matricula_periodo        cep  classe        data  \
# 0                                    2016  59067-400       1  05/05/2017
# 100002                               2016  59795-000       1        None
# 100021                               2016  59200-000       1        None
#
#           descricao descricao_area_residencial descricao_companhia_domiciliar  \
# 0       Matriculado                     Urbana                           Pais
# 100002  Matriculado                     Urbana                            Mãe
# 100021  Matriculado                     Urbana                           Pais
#
#         descricao_encaminhamento  \
# 0       Diálogo com professor(a)
# 100002                      None
# 100021                      None
#
#                                       descricao_historico  \
# 0                   Técnico de Nível Médio em Edificações
# 100002  Técnico de Nivel Médio em Agropecuária, na For...
# 100021                 Técnico de Nivel Médio Informática
#
#                descricao_historico_disciplina descricao_imovel  \
# 0       Língua Portuguesa e Literatura I(90H)       Financiado
# 100002  Língua Portuguesa e Literatura I(90H)          Alugado
# 100021  Língua Portuguesa e Literatura I(90H)          Alugado
#
#            descricao_mae_escolaridade descricao_pai_escolaridade  \
# 0            Pós graduação incompleto     Pós graduação completo
# 100002  Ensino fundamental incompleto      Ensino médio completo
# 100021          Ensino médio completo    Ensino médio incompleto
#
#        descricao_raca descricao_responsavel_escolaridade  \
# 0               Parda             Pós graduação completo
# 100002         Branca              Ensino médio completo
# 100021         Branca              Ensino médio completo
#
#        descricao_responsavel_financeiro descricao_situacao_matricula_periodo  \
# 0                                   Pai                             Aprovado
# 100002                              Pai                          Dependência
# 100021                              Pai                             Aprovado
#
#        descricao_trabalho_responsavel            id  media_final  \
# 0                     Serviço público  496915657473           86
# 100002                       Autônomo  458905053917           69
# 100021                       Autônomo  496533683389           83
#
#             nome_escola_ensino_fundamental  percentual_frequencia  \
# 0       Complexo Educacional Contemporâneo                   85.0
# 100002   Escola Estadual António Francisco                   92.0
# 100021                                IESC                   99.0
#
#        pessoa_fisica__nascimento_data pessoa_fisica__sexo         professores  \
# 0                          06/12/2001                   M              [1521]
# 100002                     16/12/1999                   M  [2688, 3538, 1222]
# 100021                     01/06/2000                   F        [1592, 3388]
#
#         qnt_pc  qtd_pessoas_domicilio  renda_bruta_familiar sigla
# 0          NaN                      4                9000.0  CNAT
# 100002     0.0                      3                 500.0    AP
# 100021     0.0                      7                2500.0    SC

# %%
#removendo colunas que explodem a quantidade de atributos quando binarizados
del dados['descricao_historico_disciplina']
del dados['professores']
del dados['id']
del dados['media_final']
del dados['percentual_frequencia']
del dados['nome_escola_ensino_fundamental']
del dados['qnt_pc']

#tentar colocar novamente
del dados['cep']
del dados['data']
del dados['pessoa_fisica__nascimento_data']

#sintetizar descricao_encaminhamento apenas se foi encaminhado ou nao
 
#dados que fazem a indicação se o aluno teve evasão
del dados['descricao']
del dados['descricao_situacao_matricula_periodo']

# %%
#configura os dados de entrada e saída
y = dados.classe
X = dados

del X['classe']
X.shape
# Out:
# (6395, 21)

# %%
#visualizacao hist da classe
y.plot.hist()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#binazira os dados devido aos atributos categoricos 
dados_dummies = pd.get_dummies(X, drop_first=False)
dados_dummies.shape
# Out:
# (6395, 161)

# %%
dados_dummies.hist(figsize=(20, 15))
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#remove atributos inconistentes
dados_clean = dados_dummies.replace([np.inf, -np.inf], np.nan)
dados_clean = dados_clean.dropna(axis=1, how='all')
dados_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6395 entries, 0 to 99974
# Columns: 161 entries, LnguaPortuguesaeLiteraturaI90H to sigla_ZN
# dtypes: float64(1), int64(7), uint8(153)
# memory usage: 1.4 MB

# %%
#ESCALONAMENTO DE DADOS

#nao houve diferenças visivelmente

#dados_clean = StandardScaler().fit_transform(dados_clean) 
#dados_clean = MinMaxScaler().fit_transform(dados_clean) 
#dados_clean = RobustScaler(quantile_range=(25, 75)).fit_transform(dados_clean)

# %%
#SELECIONANDO MELHOR MODEL RF

"""
param_grid = [    {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},    
                  {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},  ]

param_grid = { 
    'n_estimators': [200, 700],
    'max_features': ['auto', 'sqrt', 'log2']
}

forest_reg = RandomForestClassifier()

grid_search = GridSearchCV(forest_reg, param_grid, cv=5,                           
                           scoring='neg_mean_squared_error')
"""

#cria a randomforest 
forest_clf = RandomForestClassifier(oob_score=True, n_jobs=-1) 

param_grid_forest = {'max_depth': [3, 5, None],
              'max_features': ['auto', 'sqrt', 'log2'],
              'n_estimators': [10, 30, 60, 100, 200, 500, 1000],
              #'bootstrap': [True, False], #oob_score=True bootstrap só funciona com oob=true
              'criterion': ["gini", "entropy"]}

#dividir os dados para treino e teste. default é 25% p teste
Xtrain, Xtest, ytrain, ytest = train_test_split(dados_clean, y, random_state=0)

#caso queira estratificar os dados
#StratifiedShuffleSplit

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_forest = GridSearchCV(estimator=forest_clf, param_grid=param_grid_forest)
grid_search_forest.fit(Xtrain, ytrain)
print(grid_search_forest.best_params_)
print(grid_search_forest.best_estimator_)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=200, n_jobs=-1, oob_score=True, random_state=None,
#             verbose=0, warm_start=False)

# %%
#cvres = grid_search.cv_results_ 
#for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]): 
#    print(np.sqrt(-mean_score), params) 
               
report(grid_search_forest.cv_results_, 5)
# Out:
# Model with rank: 1
# Mean validation score: 0.922 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.921 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
#
# Model with rank: 3
# Mean validation score: 0.921 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 100}
#
# Model with rank: 4
# Mean validation score: 0.921 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 60}
#
# Model with rank: 4
# Mean validation score: 0.921 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 200}
#
# Model with rank: 4
# Mean validation score: 0.921 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
#
# Model with rank: 4
# Mean validation score: 0.921 (std: 0.002)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 500}
#
# Model with rank: 4
# Mean validation score: 0.921 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 1000}

# %%
#RANDOM FOREST
"""
from sklearn.cross_validation import train_test_split

#cria e treina o modelo
Xtrain, Xtest, ytrain, ytest = train_test_split(dados_clean, y, random_state=0)
model = RandomForestClassifier(n_estimators=30, random_state=42)
model.fit(Xtrain, ytrain)
ypred = model.predict(Xtest)
"""

model_forest = grid_search_forest.best_estimator_
ypred_forest = model_forest.predict(Xtest)

# %%
#Evaluating
mat = confusion_matrix(ytest, ypred_forest)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))
print(f1_score(ytest, ypred_forest))

#qnt de evadidos 
print(sum(ytest==0))
# Out:
# 0.940820443847
# 0.983134223472
# 0.940820443847
# 0.983134223472
# 0.961512027491
# 176
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#CURVA ROC

y_probas_forest = cross_val_predict(model_forest, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_forest = y_probas_forest[:, 1]   # score = proba of positive class 
fpr_forest, tpr_forest, thresholds_forest = roc_curve(ytest, y_scores_forest)

plot_roc_curve(fpr_forest, tpr_forest) 
plt.show()
print(roc_auc_score(ytest, y_scores_forest))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.906347824698

# %%
#FEATURES IMPORTANCE
"""
cont = 0
for name, score in zip(dados_clean.columns, model.feature_importances_):     
    print(name, score) 
    if cont > 10:
        break
    cont = cont + 1
"""

#fazer a qnt de importancia dos atributos
#print(cumsum(model.feature_importances_))

importances = model_forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in model_forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(Xtest.shape[1]):
    print("%d. feature %d [%s] (%f)" % (f + 1, indices[f], dados_clean.columns[indices[f]],importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(Xtest.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(Xtest.shape[1]), indices)
plt.xlim([-1, Xtest.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 0 [LnguaPortuguesaeLiteraturaI90H] (0.173667)
# 2. feature 2 [MatemticaI120H] (0.102645)
# 3. feature 1 [LnguaPortuguesaeLiteraturaII90H] (0.059924)
# 4. feature 3 [MatemticaII90H] (0.047747)
# 5. feature 7 [renda_bruta_familiar] (0.047400)
# 6. feature 5 [ano_letivo__ano_matricula_periodo] (0.034352)
# 7. feature 4 [ano_letivo__ano] (0.026766)
# 8. feature 6 [qtd_pessoas_domicilio] (0.026445)
# 9. feature 10 [descricao_area_residencial_Não informado] (0.017957)
# 10. feature 12 [descricao_area_residencial_Urbana] (0.009865)
# 11. feature 101 [descricao_raca_Branca] (0.009410)
# 12. feature 151 [sigla_MC] (0.009370)
# 13. feature 140 [pessoa_fisica__sexo_M] (0.008728)
# 14. feature 104 [descricao_raca_Parda] (0.008534)
# 15. feature 139 [pessoa_fisica__sexo_F] (0.008420)
# 16. feature 41 [descricao_historico_Técnico de Nivel Médio em Informática] (0.008246)
# 17. feature 91 [descricao_pai_escolaridade_Ensino fundamental incompleto] (0.008214)
# 18. feature 18 [descricao_companhia_domiciliar_Pais] (0.008169)
# 19. feature 130 [descricao_trabalho_responsavel_Empresa privada] (0.008067)
# 20. feature 77 [descricao_imovel_Próprio] (0.007922)
# 21. feature 136 [descricao_trabalho_responsavel_Serviço público] (0.007531)
# 22. feature 120 [descricao_responsavel_financeiro_Mãe] (0.007522)
# 23. feature 128 [descricao_trabalho_responsavel_Autônomo] (0.007444)
# 24. feature 81 [descricao_mae_escolaridade_Ensino médio completo] (0.007367)
# 25. feature 124 [descricao_responsavel_financeiro_Pai] (0.007155)
# 26. feature 24 [descricao_encaminhamento_Diálogo com o(s) aluno(s)] (0.006917)
# 27. feature 14 [descricao_companhia_domiciliar_Mãe] (0.006730)
# 28. feature 109 [descricao_responsavel_escolaridade_Ensino médio completo] (0.006715)
# 29. feature 70 [descricao_historico_Técnico em Programação de Jogos Digitais] (0.006417)
# 30. feature 80 [descricao_mae_escolaridade_Ensino fundamental incompleto] (0.006134)
# 31. feature 71 [descricao_imovel_Alugado] (0.006019)
# 32. feature 145 [sigla_CM] (0.005948)
# 33. feature 108 [descricao_responsavel_escolaridade_Ensino fundamental incompleto] (0.005925)
# 34. feature 92 [descricao_pai_escolaridade_Ensino médio completo] (0.005858)
# 35. feature 11 [descricao_area_residencial_Rural] (0.005661)
# 36. feature 82 [descricao_mae_escolaridade_Ensino médio incompleto] (0.005429)
# 37. feature 48 [descricao_historico_Técnico de Nível Médio em Edificações] (0.005080)
# 38. feature 147 [sigla_CNAT] (0.005026)
# 39. feature 19 [descricao_companhia_domiciliar_Parente(s) ou amigo(s)] (0.004913)
# 40. feature 66 [descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros] (0.004906)
# 41. feature 83 [descricao_mae_escolaridade_Ensino superior completo] (0.004867)
# 42. feature 105 [descricao_raca_Preta] (0.004645)
# 43. feature 133 [descricao_trabalho_responsavel_Não está trabalhando] (0.004616)
# 44. feature 157 [sigla_SC] (0.004578)
# 45. feature 127 [descricao_trabalho_responsavel_Aposentado] (0.004422)
# 46. feature 149 [sigla_JC] (0.004389)
# 47. feature 42 [descricao_historico_Técnico de Nível Médio em Administração] (0.004279)
# 48. feature 93 [descricao_pai_escolaridade_Ensino médio incompleto] (0.004220)
# 49. feature 87 [descricao_mae_escolaridade_Pós graduação completo] (0.004205)
# 50. feature 159 [sigla_SPP] (0.004193)
# 51. feature 111 [descricao_responsavel_escolaridade_Ensino superior completo] (0.004113)
# 52. feature 154 [sigla_PAAS] (0.003997)
# 53. feature 110 [descricao_responsavel_escolaridade_Ensino médio incompleto] (0.003984)
# 54. feature 134 [descricao_trabalho_responsavel_Não informado] (0.003910)
# 55. feature 142 [sigla_CA] (0.003831)
# 56. feature 22 [descricao_encaminhamento_Contato telefônico com os pais ou responsáveis] (0.003804)
# 57. feature 79 [descricao_mae_escolaridade_Ensino fundamental completo] (0.003683)
# 58. feature 37 [descricao_historico_Técnico de Nivel Médio Informática] (0.003677)
# 59. feature 138 [descricao_trabalho_responsavel_Trabalhador rural/Agricultor] (0.003621)
# 60. feature 150 [sigla_LAJ] (0.003514)
# 61. feature 84 [descricao_mae_escolaridade_Ensino superior incompleto] (0.003434)
# 62. feature 94 [descricao_pai_escolaridade_Ensino superior completo] (0.003433)
# 63. feature 153 [sigla_NC] (0.003419)
# 64. feature 160 [sigla_ZN] (0.003397)
# 65. feature 54 [descricao_historico_Técnico de Nível Médio em Informática] (0.003317)
# 66. feature 90 [descricao_pai_escolaridade_Ensino fundamental completo] (0.003304)
# 67. feature 115 [descricao_responsavel_escolaridade_Pós graduação completo] (0.003288)
# 68. feature 73 [descricao_imovel_Financiado] (0.003174)
# 69. feature 117 [descricao_responsavel_financeiro_Avô(ó)] (0.003116)
# 70. feature 96 [descricao_pai_escolaridade_Não conhece] (0.003095)
# 71. feature 61 [descricao_historico_Técnico de Nível Médio em Meio Ambiente] (0.003080)
# 72. feature 97 [descricao_pai_escolaridade_Não estudou] (0.003050)
# 73. feature 75 [descricao_imovel_Outro] (0.003028)
# 74. feature 89 [descricao_pai_escolaridade_Alfabetizado] (0.003026)
# 75. feature 50 [descricao_historico_Técnico de Nível Médio em Eletrotécnica] (0.003011)
# 76. feature 146 [sigla_CN] (0.002981)
# 77. feature 107 [descricao_responsavel_escolaridade_Ensino fundamental completo] (0.002949)
# 78. feature 16 [descricao_companhia_domiciliar_Outros] (0.002912)
# 79. feature 98 [descricao_pai_escolaridade_Pós graduação completo] (0.002864)
# 80. feature 51 [descricao_historico_Técnico de Nível Médio em Eletrônica] (0.002683)
# 81. feature 106 [descricao_responsavel_escolaridade_Alfabetizado] (0.002677)
# 82. feature 60 [descricao_historico_Técnico de Nível Médio em Mecânica] (0.002589)
# 83. feature 29 [descricao_encaminhamento_Orientação para cancelamento de matrícula​] (0.002539)
# 84. feature 141 [sigla_AP] (0.002510)
# 85. feature 112 [descricao_responsavel_escolaridade_Ensino superior incompleto] (0.002463)
# 86. feature 58 [descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática] (0.002439)
# 87. feature 155 [sigla_PAR] (0.002415)
# 88. feature 55 [descricao_historico_Técnico de Nível Médio em Informática para Internet] (0.002413)
# 89. feature 144 [sigla_CANG] (0.002371)
# 90. feature 13 [descricao_companhia_domiciliar_Cônjuge] (0.002364)
# 91. feature 31 [descricao_encaminhamento_Orientação para transferência de Curso/Campus] (0.002341)
# 92. feature 78 [descricao_mae_escolaridade_Alfabetizado] (0.002337)
# 93. feature 68 [descricao_historico_Técnico de Nível Médio em Têxtil] (0.002318)
# 94. feature 158 [sigla_SGA] (0.002317)
# 95. feature 114 [descricao_responsavel_escolaridade_Não estudou] (0.002296)
# 96. feature 17 [descricao_companhia_domiciliar_Pai] (0.002222)
# 97. feature 62 [descricao_historico_Técnico de Nível Médio em Mineração] (0.002196)
# 98. feature 72 [descricao_imovel_Cedido ou Emprestado] (0.002145)
# 99. feature 156 [sigla_PF] (0.002048)
# 100. feature 59 [descricao_historico_Técnico de Nível Médio em Mecatrônica] (0.001921)
# 101. feature 148 [sigla_IP] (0.001809)
# 102. feature 86 [descricao_mae_escolaridade_Não estudou] (0.001776)
# 103. feature 129 [descricao_trabalho_responsavel_Beneficiário ou Pensionista do INSS] (0.001715)
# 104. feature 123 [descricao_responsavel_financeiro_Outros] (0.001709)
# 105. feature 100 [descricao_raca_Amarela] (0.001694)
# 106. feature 64 [descricao_historico_Técnico de Nível Médio em Química] (0.001692)
# 107. feature 95 [descricao_pai_escolaridade_Ensino superior incompleto] (0.001691)
# 108. feature 38 [descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada] (0.001654)
# 109. feature 46 [descricao_historico_Técnico de Nível Médio em Comércio] (0.001626)
# 110. feature 152 [sigla_MO] (0.001622)
# 111. feature 25 [descricao_encaminhamento_Diálogo com pais ou responsáveis] (0.001550)
# 112. feature 137 [descricao_trabalho_responsavel_Trabalha com vínculo empregatício] (0.001491)
# 113. feature 119 [descricao_responsavel_financeiro_Irmão(ã)] (0.001471)
# 114. feature 49 [descricao_historico_Técnico de Nível Médio em Eletromecânica] (0.001391)
# 115. feature 143 [sigla_CAL] (0.001373)
# 116. feature 47 [descricao_historico_Técnico de Nível Médio em Controle Ambiental] (0.001351)
# 117. feature 44 [descricao_historico_Técnico de Nível Médio em Alimentos] (0.001275)
# 118. feature 74 [descricao_imovel_Não informado] (0.001248)
# 119. feature 126 [descricao_responsavel_financeiro_Tio(a)] (0.001244)
# 120. feature 118 [descricao_responsavel_financeiro_Cônjuge] (0.001218)
# 121. feature 65 [descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado] (0.001211)
# 122. feature 23 [descricao_encaminhamento_Diálogo com aluno(a) e professor(a)] (0.001148)
# 123. feature 67 [descricao_historico_Técnico de Nível Médio em Refrigeração e Climatização] (0.001143)
# 124. feature 122 [descricao_responsavel_financeiro_O próprio aluno] (0.001123)
# 125. feature 63 [descricao_historico_Técnico de Nível Médio em Multimídia] (0.001089)
# 126. feature 103 [descricao_raca_Não declarado] (0.001010)
# 127. feature 39 [descricao_historico_Técnico de Nivel Médio em Biocombustíveis] (0.000867)
# 128. feature 88 [descricao_mae_escolaridade_Pós graduação incompleto] (0.000801)
# 129. feature 45 [descricao_historico_Técnico de Nível Médio em Apicultura] (0.000774)
# 130. feature 34 [descricao_encaminhamento_Solicitação de atendimento da Psicologia] (0.000773)
# 131. feature 40 [descricao_historico_Técnico de Nivel Médio em Equipamentos Biomédicos] (0.000763)
# 132. feature 57 [descricao_historico_Técnico de Nível Médio em Logística] (0.000748)
# 133. feature 52 [descricao_historico_Técnico de Nível Médio em Eventos] (0.000748)
# 134. feature 135 [descricao_trabalho_responsavel_Pescador] (0.000688)
# 135. feature 69 [descricao_historico_Técnico de Nível Médio em Vestuário] (0.000662)
# 136. feature 113 [descricao_responsavel_escolaridade_Não conhece] (0.000631)
# 137. feature 36 [descricao_encaminhamento_Solicitação de comparecimento dos pais ou responsáveis à escola] (0.000552)
# 138. feature 53 [descricao_historico_Técnico de Nível Médio em Geologia] (0.000550)
# 139. feature 56 [descricao_historico_Técnico de Nível Médio em Lazer] (0.000538)
# 140. feature 116 [descricao_responsavel_escolaridade_Pós graduação incompleto] (0.000528)
# 141. feature 99 [descricao_pai_escolaridade_Pós graduação incompleto] (0.000476)
# 142. feature 26 [descricao_encaminhamento_Diálogo com professor(a)] (0.000375)
# 143. feature 32 [descricao_encaminhamento_Solicitação de Aplicação/Registro de medida disciplinar] (0.000342)
# 144. feature 28 [descricao_encaminhamento_Envio de Telegrama ou e-mail aos pais ou responsáveis] (0.000341)
# 145. feature 85 [descricao_mae_escolaridade_Não conhece] (0.000331)
# 146. feature 43 [descricao_historico_Técnico de Nível Médio em Agroecologia] (0.000328)
# 147. feature 35 [descricao_encaminhamento_Solicitação de atendimento do Setor de saúde] (0.000281)
# 148. feature 125 [descricao_responsavel_financeiro_Parentes] (0.000278)
# 149. feature 132 [descricao_trabalho_responsavel_Nunca trabalhou] (0.000257)
# 150. feature 27 [descricao_encaminhamento_Elaboração de rotina de estudos] (0.000249)
# 151. feature 15 [descricao_companhia_domiciliar_Não informado] (0.000205)
# 152. feature 33 [descricao_encaminhamento_Solicitação de atendimento da Assistência Social] (0.000186)
# 153. feature 21 [descricao_encaminhamento_Atendimento domiciliar] (0.000173)
# 154. feature 102 [descricao_raca_Indígena] (0.000143)
# 155. feature 131 [descricao_trabalho_responsavel_Estágio ou bolsa] (0.000139)
# 156. feature 76 [descricao_imovel_Pensionato ou Alojamento] (0.000127)
# 157. feature 20 [descricao_companhia_domiciliar_Sozinho(a)] (0.000123)
# 158. feature 121 [descricao_responsavel_financeiro_Não informado] (0.000114)
# 159. feature 8 [descricao_area_residencial_Comunidade Indígena] (0.000012)
# 160. feature 9 [descricao_area_residencial_Comunidade Quilombola] (0.000000)
# 161. feature 30 [descricao_encaminhamento_Orientação para trancamento compulsório de matrícula] (0.000000)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#FIM RANDOM FOREST

# %%
#DECISION TREE

tree_clf = DecisionTreeClassifier() 

param_grid_tree = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_tree = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree)
grid_search_tree.fit(Xtrain, ytrain)
print(grid_search_tree.best_params_)
print(grid_search_tree.best_estimator_)
# Out:
# {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=20, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
report(grid_search_tree.cv_results_, 5)

model_tree = grid_search_tree.best_estimator_
ypred_tree = model_tree.predict(Xtest)
# Out:
# Model with rank: 1
# Mean validation score: 0.921 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.921 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.921 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.921 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.921 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.921 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.921 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}

# %%
#DECISION TREE
#from sklearn.tree import DecisionTreeClassifier
#Xtrain, Xtest, ytrain, ytest = train_test_split(dados_clean, y, random_state=0)
#tree_clf = DecisionTreeClassifier(max_depth=3) 
#tree_clf.fit(Xtrain, ytrain)
#ypred = tree_clf.predict(Xtest)

# %%
#porcentagem de predicao correta
n_correct = sum(ypred_tree == ytest)    
print(n_correct / len(ypred_tree)) 

#evaluating
mat = confusion_matrix(ytest, ypred_tree)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_tree))
print(recall_score(ytest, ypred_tree))
print(f1_score(ytest, ypred_tree))
# Out:
# 0.925578486554
# 0.954038997214
# 0.9627547435
# 0.958377054914
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
export_graphviz(model_tree,
                feature_names=dados_clean.columns,
                filled=True,
                rounded=True, 
                out_file='tree.dot')

os.system('dot -Tpng tree.dot -o tree.png')
# Out:
# 0

# %%
y_probas_tree = cross_val_predict(model_tree, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_tree = y_probas_tree[:, 1]   # score = proba of positive class 
fpr_tree, tpr_tree, thresholds_tree = roc_curve(ytest, y_scores_tree)

plot_roc_curve(fpr_tree, tpr_tree) 
plt.show()
print(roc_auc_score(ytest, y_scores_tree))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.822703714943

# %%
#FIM DT

# %%
#PLOTAR DUAS CURVAS ROC (DT e RF)
plt.plot(fpr_tree, tpr_tree, "b:", label="DT") 
plot_roc_curve(fpr_forest, tpr_forest, "Random Forest") 
plt.legend(loc="bottom right") 
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:326: UserWarning: Unrecognized location "bottom right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   six.iterkeys(self.codes))))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#FIM COMPARACAO

# %%
#REDUÇÃO DE DIMENSIONALIDADE

#pca = PCA(n_components=0.95) 
pca = PCA(n_components=2) 
X_reduced = pca.fit_transform(dados_clean) 

print(pca.explained_variance_ratio_) 
print(X_reduced.shape)

pca = PCA() 
pca.fit(dados_clean) 
cumsum = np.cumsum(pca.explained_variance_ratio_) 
d = np.argmax(cumsum >= 0.95) + 1
plt.plot(cumsum)
# Out:
# [  9.99994133e-01   4.19365608e-06]
# (6395, 2)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#X_reduced.shape

colors = ['red','blue']
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y, cmap=matplotlib.colors.ListedColormap(colors))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#cria a randomforest 
#forest_pca = RandomForestClassifier(n_estimators=50, oob_score=True) 
forest_pca = RandomForestClassifier() 

param_grid_pca = {'max_depth': [3, 5, None],
              'max_features': ['auto', 'sqrt', 'log2'],
              'n_estimators': [10, 30, 60, 100, 200, 500, 1000],
              
              'criterion': ["gini", "entropy"]}


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_pca, Xtest_pca, ytrain_pca, ytest_pca = train_test_split(X_reduced, y, random_state=0)

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_pca = GridSearchCV(estimator=forest_pca, param_grid=param_grid_pca, cv = 5)
grid_search_pca.fit(Xtrain_pca, ytrain_pca)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'max_depth': [3, 5, None], 'max_features': ['auto', 'sqrt', 'log2'], 'n_estimators': [10, 30, 60, 100, 200, 500, 1000], 'criterion': ['gini', 'entropy']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
print(grid_search_pca.best_params_)
print(grid_search_pca.best_estimator_)

#exibir melhor modelo
report(grid_search_pca.cv_results_, 5)

#seleciona o melhor modelo
model_pca = grid_search_pca.best_estimator_
ypred_pca = model_pca.predict(Xtest_pca)
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 10}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# Model with rank: 1
# Mean validation score: 0.908 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.907 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 30}
#
# Model with rank: 4
# Mean validation score: 0.907 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 60}
#
# Model with rank: 5
# Mean validation score: 0.907 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 60}
#
# Model with rank: 5
# Mean validation score: 0.907 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 500}
#
# Model with rank: 5
# Mean validation score: 0.907 (std: 0.004)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 60}

# %%
#Evaluating
mat = confusion_matrix(ytest_pca, ypred_pca)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_pca, ypred_pca))
print(recall_score(ytest_pca, ypred_pca))

#evaluating
print(precision_score(ytest_pca, ypred_pca))
print(recall_score(ytest_pca, ypred_pca))
print(f1_score(ytest_pca, ypred_pca))
# Out:
# 0.927090301003
# 0.973998594519
# 0.927090301003
# 0.973998594519
# 0.949965729952
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#CURVA ROC
y_probas_pca = cross_val_predict(model_pca, Xtest_pca, ytest_pca, cv=3, method="predict_proba") 

y_scores_pca = y_probas_pca[:, 1]   # score = proba of positive class 
fpr_pca, tpr_pca, thresholds_pca = roc_curve(ytest_pca, y_scores_pca)

plot_roc_curve(fpr_pca, tpr_pca) 
plt.show()
print(roc_auc_score(ytest_pca, y_scores_pca))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.816608637322

# %%
#FIM PCA

# %%
#BASE APENAS COM ALGUNS DADOS IMPORTANTES DA RF
"""
1. feature 0 [LnguaPortuguesaeLiteraturaI90H] (0.167594)
2. feature 2 [MatemticaI120H] (0.107503)
3. feature 1 [LnguaPortuguesaeLiteraturaII90H] (0.072414)
4. feature 3 [MatemticaII90H] (0.059724)
5. feature 7 [renda_bruta_familiar] (0.047050)
6. feature 5 [ano_letivo__ano_matricula_periodo] (0.032807)
7. feature 4 [ano_letivo__ano] (0.030889)
8. feature 6 [qtd_pessoas_domicilio] (0.024958)

dados_reduzido = dados_clean[['LnguaPortuguesaeLiteraturaI90H', 'MatemticaI120H', 
                              'LnguaPortuguesaeLiteraturaII90H', 'MatemticaII90H', 
                              'renda_bruta_familiar', 'ano_letivo__ano_matricula_periodo', 
                              'ano_letivo__ano', 'qtd_pessoas_domicilio']]
"""
dados_reduzido = dados_clean[['LnguaPortuguesaeLiteraturaI90H', 'MatemticaI120H', 
                              'LnguaPortuguesaeLiteraturaII90H', 'MatemticaII90H', 
                              'renda_bruta_familiar']]


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_red, Xtest_red, ytrain_red, ytest_red = train_test_split(dados_reduzido, y, random_state=0)

# %%
tree_clf = DecisionTreeClassifier() 

param_grid_tree_red = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_red = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree_red)
grid_search_red.fit(Xtrain_red, ytrain_red)
print(grid_search_red.best_params_)
print(grid_search_red.best_estimator_)
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=20, min_impurity_split=1e-07,
#             min_samples_leaf=10, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
report(grid_search_red.cv_results_, 5)

model_red = grid_search_red.best_estimator_
ypred_red = model_red.predict(Xtest_red)
# Out:
# Model with rank: 1
# Mean validation score: 0.911 (std: 0.008)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.911 (std: 0.008)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.911 (std: 0.008)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 4
# Mean validation score: 0.910 (std: 0.007)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 4
# Mean validation score: 0.910 (std: 0.007)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 4
# Mean validation score: 0.910 (std: 0.007)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}

# %%
n_correct = sum(ypred_red == ytest_red)    
print(n_correct / len(ypred_red)) 

#evaluating
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(ytest_red, ypred_red)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_red, ypred_red))
print(recall_score(ytest_red, ypred_red))
print(f1_score(ytest_red, ypred_red))
# Out:
# 0.913070669168
# 0.937329700272
# 0.966971187632
# 0.951919750951
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
export_graphviz(model_red,
                feature_names=dados_reduzido.columns,
                filled=True,
                rounded=True, 
                out_file='tree_red.dot')

os.system('dot -Tpng tree_red.dot -o tree_red.png')
# Out:
# 0

# %%
y_probas_tree_red = cross_val_predict(model_red, Xtest_red, ytest_red, cv=3, method="predict_proba") 

y_scores_tree_red = y_probas_tree_red[:, 1]   # score = proba of positive class 
fpr_tree_red, tpr_tree_red, thresholds_tree_red = roc_curve(ytest_red, y_scores_tree_red)

plot_roc_curve(fpr_tree_red, tpr_tree_red) 
plt.show()
print(roc_auc_score(ytest_red, y_scores_tree_red))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.797980019805

# %%
dados_reduzido = dados_clean[['LnguaPortuguesaeLiteraturaI90H', 'MatemticaI120H', 
                              'LnguaPortuguesaeLiteraturaII90H', 'MatemticaII90H']]


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_red, Xtest_red, ytrain_red, ytest_red = train_test_split(dados_reduzido, y, random_state=0)

tree_clf = DecisionTreeClassifier() 

param_grid_tree_red = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_red = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree_red)
grid_search_red.fit(Xtrain_red, ytrain_red)
print(grid_search_red.best_params_)
print(grid_search_red.best_estimator_)

#mostra os melhores 5 modelos
report(grid_search_red.cv_results_, 5)

#realiza predicao
model_red = grid_search_red.best_estimator_
ypred_red = model_red.predict(Xtest_red)

#avalia modelo
n_correct = sum(ypred_red == ytest_red)    
print(n_correct / len(ypred_red)) 

#evaluating
mat = confusion_matrix(ytest_red, ypred_red)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_red, ypred_red))
print(recall_score(ytest_red, ypred_red))
print(f1_score(ytest_red, ypred_red))

#curva ROC
y_probas_tree_red = cross_val_predict(model_red, Xtest_red, ytest_red, cv=3, method="predict_proba") 

y_scores_tree_red = y_probas_tree_red[:, 1]   # score = proba of positive class 
fpr_tree_red, tpr_tree_red, thresholds_tree_red = roc_curve(ytest_red, y_scores_tree_red)

fig = plt.figure()

plot_roc_curve(fpr_tree_red, tpr_tree_red) 
plt.show()
print(roc_auc_score(ytest_red, y_scores_tree_red))
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=20, min_impurity_split=1e-07,
#             min_samples_leaf=10, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# Model with rank: 1
# Mean validation score: 0.910 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.910 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.910 (std: 0.006)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 4
# Mean validation score: 0.910 (std: 0.007)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 4
# Mean validation score: 0.910 (std: 0.007)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 4
# Mean validation score: 0.910 (std: 0.007)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# 0.909318323952
# 0.952549575071
# 0.945186226283
# 0.94885361552
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.801910975532

# %%
#PLOTAR DUAS CURVAS ROC (DT e RF)
plt.plot(fpr_tree_red, tpr_tree_red, "b:", label="DT-RED") 
plot_roc_curve(fpr_forest, tpr_forest, "Random Forest") 
plt.legend(loc="bottom right") 
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:326: UserWarning: Unrecognized location "bottom right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   six.iterkeys(self.codes))))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#FIM DT REDUZIDA

# %%
dados_reduzido.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff6f19abd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff6efaebfd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff6efb16550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff6ef34c6a0>]], dtype=object)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#UTILIZANDO AS MÉDIAS DE CADA ANO

nota_1 = dados_clean[['LnguaPortuguesaeLiteraturaI90H', 'MatemticaI120H']].mean(axis=1)
nota_2 = dados_clean[['LnguaPortuguesaeLiteraturaII90H', 'MatemticaII90H']].mean(axis=1)

dados_reduzido = pd.DataFrame()
dados_reduzido['1_ano'] = nota_1
dados_reduzido['2_ano'] = nota_2


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_red, Xtest_red, ytrain_red, ytest_red = train_test_split(dados_reduzido, y, random_state=0)

tree_clf = DecisionTreeClassifier() 

param_grid_tree_red = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_red = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree_red)
grid_search_red.fit(Xtrain_red, ytrain_red)
print(grid_search_red.best_params_)
print(grid_search_red.best_estimator_)

#mostra os melhores 5 modelos
report(grid_search_red.cv_results_, 5)

#realiza predicao
model_red = grid_search_red.best_estimator_
ypred_red = model_red.predict(Xtest_red)

#avalia modelo
n_correct = sum(ypred_red == ytest_red)    
print(n_correct / len(ypred_red)) 

#evaluating
mat = confusion_matrix(ytest_red, ypred_red)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_red, ypred_red))
print(recall_score(ytest_red, ypred_red))
print(f1_score(ytest_red, ypred_red))

#curva ROC
y_probas_tree_red = cross_val_predict(model_red, Xtest_red, ytest_red, cv=3, method="predict_proba") 

y_scores_tree_red = y_probas_tree_red[:, 1]   # score = proba of positive class 
fpr_tree_red, tpr_tree_red, thresholds_tree_red = roc_curve(ytest_red, y_scores_tree_red)

fig = plt.figure()

plot_roc_curve(fpr_tree_red, tpr_tree_red) 
plt.show()
print(roc_auc_score(ytest_red, y_scores_tree_red))
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.906 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# 0.907442151345
# 0.949260042283
# 0.94659170766
# 0.947923997185
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.784987302753

# %%
#UTILIZANDO AS MÉDIAS POR DISCIPLINA

nota_1 = dados_clean[['LnguaPortuguesaeLiteraturaI90H', 'LnguaPortuguesaeLiteraturaII90H']].mean(axis=1)
nota_2 = dados_clean[['MatemticaI120H', 'MatemticaII90H']].mean(axis=1)

dados_reduzido = pd.DataFrame()
dados_reduzido['1_ano'] = nota_1
dados_reduzido['2_ano'] = nota_2

#dividir os dados para treino e teste. default é 25% p teste
Xtrain_red, Xtest_red, ytrain_red, ytest_red = train_test_split(dados_reduzido, y, random_state=0)

tree_clf = DecisionTreeClassifier() 

param_grid_tree_red = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_red = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree_red)
grid_search_red.fit(Xtrain_red, ytrain_red)
print(grid_search_red.best_params_)
print(grid_search_red.best_estimator_)

#mostra os melhores 5 modelos
report(grid_search_red.cv_results_, 5)

#realiza predicao
model_red = grid_search_red.best_estimator_
ypred_red = model_red.predict(Xtest_red)

#avalia modelo
n_correct = sum(ypred_red == ytest_red)    
print(n_correct / len(ypred_red)) 

#evaluating
mat = confusion_matrix(ytest_red, ypred_red)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_red, ypred_red))
print(recall_score(ytest_red, ypred_red))
print(f1_score(ytest_red, ypred_red))

#curva ROC
y_probas_tree_red = cross_val_predict(model_red, Xtest_red, ytest_red, cv=3, method="predict_proba") 

y_scores_tree_red = y_probas_tree_red[:, 1]   # score = proba of positive class 
fpr_tree_red, tpr_tree_red, thresholds_tree_red = roc_curve(ytest_red, y_scores_tree_red)

fig = plt.figure()

plot_roc_curve(fpr_tree_red, tpr_tree_red) 
plt.show()
print(roc_auc_score(ytest_red, y_scores_tree_red))
# Out:
# {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=10, min_impurity_split=1e-07,
#             min_samples_leaf=10, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# Model with rank: 1
# Mean validation score: 0.905 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.905 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.905 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.905 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.905 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.905 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.905 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.905 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.905 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# 0.908692933083
# 0.945568736916
# 0.952213633169
# 0.948879551821
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.800878825145

# %%
#EDA DAS NOTAS 

dados_eda = dados[['descricao_mae_escolaridade', 'descricao_pai_escolaridade', 
                   'descricao_raca', 'pessoa_fisica__sexo', 
                   'renda_bruta_familiar', 'sigla']]

nota_1 = dados[['LnguaPortuguesaeLiteraturaI90H', 'LnguaPortuguesaeLiteraturaII90H']].mean(axis=1)
nota_2 = dados[['MatemticaI120H', 'MatemticaII90H']].mean(axis=1)

dados_eda['1_ano'] = nota_1
dados_eda['2_ano'] = nota_2
dados_eda['classe'] = y

dados_eda
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#            descricao_mae_escolaridade     descricao_pai_escolaridade  \
# 0            Pós graduação incompleto         Pós graduação completo
# 100002  Ensino fundamental incompleto          Ensino médio completo
# 100021          Ensino médio completo        Ensino médio incompleto
# 100034          Ensino médio completo          Ensino médio completo
# 10005   Ensino fundamental incompleto       Ensino superior completo
# 100064          Ensino médio completo          Ensino médio completo
# 100095          Ensino médio completo          Ensino médio completo
# 100108    Ensino fundamental completo          Ensino médio completo
# 100137          Ensino médio completo          Ensino médio completo
# 100153       Ensino superior completo        Ensino médio incompleto
# 100183  Ensino fundamental incompleto          Ensino médio completo
# 10022        Ensino superior completo       Ensino superior completo
# 100222          Ensino médio completo          Ensino médio completo
# 100250          Ensino médio completo          Ensino médio completo
# 100267          Ensino médio completo          Ensino médio completo
# 100296          Ensino médio completo          Ensino médio completo
# 100323          Ensino médio completo        Ensino médio incompleto
# 10035        Ensino superior completo       Ensino superior completo
# 100352          Ensino médio completo          Ensino médio completo
# 100383          Ensino médio completo          Ensino médio completo
# 100413          Ensino médio completo          Ensino médio completo
# 100427          Ensino médio completo     Ensino superior incompleto
# 100442          Ensino médio completo          Ensino médio completo
# 100456          Ensino médio completo          Ensino médio completo
# 100485          Ensino médio completo          Ensino médio completo
# 10049           Ensino médio completo       Ensino superior completo
# 100499          Ensino médio completo  Ensino fundamental incompleto
# 100515          Ensino médio completo  Ensino fundamental incompleto
# 100530          Ensino médio completo       Ensino superior completo
# 100563          Ensino médio completo        Ensino médio incompleto
# ...                               ...                            ...
# 99353        Ensino superior completo       Ensino superior completo
# 99382        Ensino superior completo       Ensino superior completo
# 99404        Ensino superior completo       Ensino superior completo
# 9945         Ensino superior completo       Ensino superior completo
# 99465           Ensino médio completo       Ensino superior completo
# 99491        Ensino superior completo       Ensino superior completo
# 99508        Ensino superior completo       Ensino superior completo
# 99538        Ensino superior completo          Ensino médio completo
# 99552        Ensino superior completo          Ensino médio completo
# 99579        Ensino superior completo        Ensino médio incompleto
# 9959         Ensino superior completo       Ensino superior completo
# 99611        Ensino superior completo       Ensino superior completo
# 99623        Ensino superior completo          Ensino médio completo
# 99651        Ensino superior completo       Ensino superior completo
# 99663        Ensino superior completo  Ensino fundamental incompleto
# 99682        Ensino superior completo       Ensino superior completo
# 99695        Ensino superior completo     Ensino superior incompleto
# 99724   Ensino fundamental incompleto  Ensino fundamental incompleto
# 99739           Ensino médio completo          Ensino médio completo
# 99766           Ensino médio completo          Ensino médio completo
# 99779           Ensino médio completo          Ensino médio completo
# 99794           Ensino médio completo          Ensino médio completo
# 99807      Ensino superior incompleto          Ensino médio completo
# 99834         Ensino médio incompleto          Ensino médio completo
# 99863           Ensino médio completo          Ensino médio completo
# 99877      Ensino superior incompleto          Ensino médio completo
# 9990           Pós graduação completo       Ensino superior completo
# 99905     Ensino fundamental completo          Ensino médio completo
# 99918         Ensino médio incompleto          Ensino médio completo
# 99974           Ensino médio completo          Ensino médio completo
#
#        descricao_raca pessoa_fisica__sexo  renda_bruta_familiar sigla  1_ano  \
# 0               Parda                   M               9000.00  CNAT   42.5
# 100002         Branca                   M                500.00    AP   34.0
# 100021         Branca                   F               2500.00    SC   41.0
# 100034          Parda                   F                788.00    CA   86.0
# 10005           Parda                   F                900.00  CNAT   37.5
# 100064          Parda                   M               1760.00  CNAT   62.5
# 100095          Parda                   M                900.00  CNAT    9.5
# 100108          Parda                   F               2000.00    SC   88.5
# 100137         Branca                   M               1500.00    CN   36.0
# 100153         Branca                   M               2380.00    MO   68.5
# 100183          Parda                   M                200.00    JC   -0.5
# 10022           Parda                   M               4000.00   PAR   38.0
# 100222         Branca                   M                724.00    CM   67.0
# 100250          Parda                   M               1368.00    CA   31.5
# 100267         Branca                   F               3500.00  CNAT   74.5
# 100296         Branca                   M                500.00    CM   75.5
# 100323         Branca                   M               1137.00  CANG   60.5
# 10035           Parda                   M               5000.00    MO   40.5
# 100352          Parda                   F                400.00  CNAT   66.0
# 100383          Parda                   F                200.00   CAL   35.5
# 100413          Parda                   F               1200.00   SGA   14.0
# 100427         Branca                   F                  3.00  CNAT   44.5
# 100442          Parda                   F               1000.00  CNAT   37.5
# 100456          Parda                   F                937.20    ZN   40.5
# 100485          Parda                   F                500.00  CNAT   37.5
# 10049          Branca                   F               9000.00    CA   45.0
# 100499          Parda                   F                788.00    CN   40.5
# 100515          Parda                   F                880.00    CA   35.0
# 100530          Parda                   M                760.00  CNAT   69.0
# 100563          Parda                   F                756.96  CNAT   73.0
# ...               ...                 ...                   ...   ...    ...
# 99353           Parda                   F               5500.00  CNAT   77.0
# 99382          Branca                   F               3500.00   CAL   90.5
# 99404          Branca                   M               1660.00  CNAT   85.0
# 9945    Não declarado                   M               4000.00  CNAT   35.0
# 99465          Branca                   M               2330.00  CNAT   85.5
# 99491          Branca                   F               3200.00    ZN   32.0
# 99508          Branca                   F               4488.00    CA   82.0
# 99538           Parda                   M                788.00   SPP   34.5
# 99552           Parda                   M               2800.00    PF   73.5
# 99579           Parda                   F               3700.00  CNAT   62.5
# 9959          Amarela                   F               5000.00  CNAT   70.5
# 99611           Preta                   M               2000.00    SC   39.0
# 99623          Branca                   F               2160.00  CNAT   42.5
# 99651          Branca                   M               3500.00    SC   43.5
# 99663           Parda                   F                937.00   LAJ   36.0
# 99682          Branca                   M               3600.00  CNAT   30.0
# 99695          Branca                   M               1800.00  CNAT   -0.5
# 99724           Parda                   M               1511.61  CNAT   38.0
# 99739           Parda                   M               1874.00   LAJ   71.0
# 99766           Parda                   F                800.00  PAAS   35.0
# 99779           Parda                   F               3900.00    ZN   32.5
# 99794          Branca                   M               2664.90  CNAT   40.5
# 99807          Branca                   M                850.00    MO   78.5
# 99834          Branca                   M                724.00    SC   81.0
# 99863   Não declarado                   F                900.00    JC   32.0
# 99877        Indígena                   F               2500.00    MC   30.0
# 9990            Parda                   M               6590.00    MO   40.0
# 99905           Parda                   M                788.00    CN    6.5
# 99918           Parda                   M               1500.00   SGA   29.5
# 99974          Branca                   M               1500.00  CNAT   91.0
#
#         2_ano  classe
# 0        43.0       1
# 100002    2.0       1
# 100021   38.0       1
# 100034   75.0       1
# 10005    15.5       1
# 100064   36.0       1
# 100095    6.5       0
# 100108   86.0       1
# 100137   42.5       1
# 100153   65.0       1
# 100183   -0.5       0
# 10022    40.0       1
# 100222   44.5       1
# 100250    9.5       0
# 100267   70.5       1
# 100296   92.0       1
# 100323   83.0       1
# 10035    44.5       1
# 100352   67.0       1
# 100383   23.5       1
# 100413   22.0       0
# 100427   37.5       1
# 100442   34.5       1
# 100456   40.5       0
# 100485   17.0       1
# 10049    41.0       1
# 100499   31.5       1
# 100515   35.5       1
# 100530   60.0       1
# 100563   87.5       1
# ...       ...     ...
# 99353    72.0       1
# 99382    72.0       1
# 99404    84.0       1
# 9945     30.5       1
# 99465    82.5       1
# 99491    16.5       1
# 99508    84.5       1
# 99538    17.0       1
# 99552    84.5       1
# 99579    38.0       1
# 9959     86.0       1
# 99611    40.5       1
# 99623    30.5       0
# 99651    36.5       1
# 99663    35.0       1
# 99682    31.5       1
# 99695    -0.5       0
# 99724    34.5       1
# 99739    85.0       1
# 99766    29.5       1
# 99779    24.5       1
# 99794    34.5       1
# 99807    69.5       1
# 99834    66.0       1
# 99863    33.5       1
# 99877    29.5       1
# 9990     39.0       1
# 99905     9.5       0
# 99918    33.0       1
# 99974    78.0       1
#
# [6395 rows x 9 columns]

# %%
#plot eixo y media do primeiro ano, eixo x media do segundo. cores representando evasao ou nao
colors = ['red','blue']
plt.scatter(dados_eda.loc[:, '1_ano'], dados_eda.loc[:, '2_ano'], c=dados_eda['classe'], cmap=matplotlib.colors.ListedColormap(colors))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
sns.set(style="whitegrid")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="1_ano", y="sigla", hue="classe",
              data=dados_eda, jitter=True,
              alpha=.25, zorder=1)

# Show the conditional means
sns.pointplot(x="1_ano", y="sigla", hue="classe",
              data=dados_eda, join=False, palette="dark",
              markers="d", scale=.75, ci=None)

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[2:], labels[2:], title="evasao",
          handletextpad=0, columnspacing=1,
          loc="lower right", ncol=2, frameon=True)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
sns.boxplot(x="classe", y="1_ano", hue="sigla", data=dados_eda, palette="PRGn")
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
g = sns.FacetGrid(dados_eda, col="classe",  row="sigla")
g = g.map(sns.kdeplot, "1_ano")
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#print(dados_eda.groupby('sigla')['1_ano'].mean())
#print(dados_eda.groupby('sigla')['1_ano'].mean().index)

data_plot = [dados_eda.groupby('sigla')['1_ano'].mean(), dados_eda.groupby('sigla')['2_ano'].mean()]

fig, ax = plt.subplots(figsize=(20, 20))
plt.boxplot(data_plot)
plt.plot([1, 2], [dados_eda.groupby('sigla')['1_ano'].mean(), dados_eda.groupby('sigla')['2_ano'].mean()], 'r.', alpha=0.5)


for i, txt in enumerate( dados_eda.groupby('sigla')['1_ano'].mean().index ):
    ax.annotate( txt, (1, dados_eda.groupby('sigla')['1_ano'].mean()[i]), fontsize=10)
    ax.annotate( txt, (2, dados_eda.groupby('sigla')['2_ano'].mean()[i]) )


fig = plt.figure()
dados_eda.boxplot(column='1_ano',by='sigla')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
