# %% [markdown]
# # Análise de alunos do integrado do IFRN
# a base de dados consiste em dados socioeconômicos e as notas finais de português e matemática do 1º e 2º ano. Essas disciplinas foram selecionadas devido a certeza delas estarem presente em todos os cursos de integrado ofertados no IFRN

# %%
#import os pacotes utilizados
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

#ESCALONAMENTO DE DADOS
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler

#SELECIONANDO MELHOR MODELO
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from scipy.stats import randint as sp_randint
from sklearn.cross_validation import train_test_split

#Evaluating
import seaborn as sns; sns.set()

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import f1_score

#EXPORTAR ARVORE
from sklearn.tree import export_graphviz
import os

#CURVA ROC
# %matplotlib inline
from sklearn.metrics import roc_curve
from sklearn.model_selection import cross_val_predict 
from sklearn.metrics import roc_auc_score

#REDUÇÃO DE DIMENSIONALIDADE
from sklearn.decomposition import PCA

#exibindo todas as colunas
pd.set_option('display.max_columns', None)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#definicao de funcoes que serao utilizadas

# Utility function to report best scores
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")
            
def plot_roc_curve(fpr, tpr, label=None):    
    plt.plot(fpr, tpr, linewidth=2, label=label)    
    plt.plot([0, 1], [0, 1], 'k--')    
    plt.axis([0, 1, 0, 1])   
    plt.xlabel('False Positive Rate')    
    plt.ylabel('True Positive Rate')

# %%
#importando base já tratada
dados = pd.read_json('dados/dados_flat_sem_social.json')
print(dados.id.nunique())
print(dados.shape)
dados.head(3)
# Out:
# 7587
# (7587, 16)
#        LnguaPortuguesaeLiteraturaI90H  LnguaPortuguesaeLiteraturaII90H  \
# 10000                              72                             41.0
# 10001                              73                             68.0
# 10002                              66                              NaN
#
#        MatemticaI120H  MatemticaII90H  ano_letivo__ano  \
# 10000              68             0.0             2015
# 10001              70             0.0             2017
# 10002              60             NaN             2016
#
#        ano_letivo__ano_matricula_periodo        cep  classe    descricao  \
# 10000                               2015  59215-000       1  Matriculado
# 10001                               2015  59255-000       1  Matriculado
# 10002                               2016  59219-000       1  Matriculado
#
#                            descricao_historico  \
# 10000  Técnico de Nível Médio em Administração
# 10001  Técnico de Nível Médio em Administração
# 10002  Técnico de Nível Médio em Administração
#
#       descricao_situacao_matricula_periodo            id  \
# 10000                          Dependência  464291724941
# 10001                          Dependência  573829066825
# 10002                          Dependência  503648996253
#
#        percentual_frequencia pessoa_fisica__nascimento_data  \
# 10000                   92.0                     10/08/1999
# 10001                  100.0                     26/07/2000
# 10002                  100.0                     25/01/2001
#
#       pessoa_fisica__sexo sigla
# 10000                   M    NC
# 10001                   F    NC
# 10002                   M    NC

# %%
#removendo colunas que explodem a quantidade de atributos quando binarizados
del dados['id']

#dados que fazem a indicação se o aluno teve evasão
del dados['descricao']
del dados['descricao_situacao_matricula_periodo']

# %%
#transformando o dado em int
dados['cep'] = dados['cep'].str.replace('-', '')
dados['cep'] = dados['cep'].apply(pd.to_numeric, errors='coerce')

# %%
#transformando o dado em int
dados['pessoa_fisica__nascimento_data'] = dados['pessoa_fisica__nascimento_data'].str.replace('/','').apply(int)

# %%
#convertendo os NaN das notas em -1 para usar o RF 
dados['LnguaPortuguesaeLiteraturaI90H'].fillna(-1, inplace=True)
dados['MatemticaI120H'].fillna(-1, inplace=True)
dados['LnguaPortuguesaeLiteraturaII90H'].fillna(-1, inplace=True)
dados['MatemticaII90H'].fillna(-1, inplace=True)

# %%
#limpando os NaN devido ao RF
print(dados.shape)
df = dados.dropna()
dados = df
print(dados.shape)
# Out:
# (7587, 13)
# (7457, 13)

# %%
#configura os dados de entrada e saída
y = dados.classe
X = dados

del X['classe']
X.shape
# Out:
# (7457, 12)

# %%
#visualizacao hist da classe
y.plot.hist()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#binazira os dados devido aos atributos categoricos 
dados_dummies = pd.get_dummies(X, drop_first=False)
dados_dummies.shape
# Out:
# (7457, 65)

# %%
dados_dummies.hist(figsize=(20, 15))
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#remove atributos inconistentes
dados_clean = dados_dummies.replace([np.inf, -np.inf], np.nan)
dados_clean = dados_clean.dropna(axis=1, how='all')
dados_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7457 entries, 10000 to 9997
# Data columns (total 65 columns):
# LnguaPortuguesaeLiteraturaI90H                                                       7457 non-null int64
# LnguaPortuguesaeLiteraturaII90H                                                      7457 non-null float64
# MatemticaI120H                                                                       7457 non-null int64
# MatemticaII90H                                                                       7457 non-null float64
# ano_letivo__ano                                                                      7457 non-null int64
# ano_letivo__ano_matricula_periodo                                                    7457 non-null int64
# cep                                                                                  7457 non-null float64
# percentual_frequencia                                                                7457 non-null float64
# pessoa_fisica__nascimento_data                                                       7457 non-null int64
# descricao_historico_Técnico de Nivel Médio Informática                               7457 non-null uint8
# descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada       7457 non-null uint8
# descricao_historico_Técnico de Nivel Médio em Biocombustíveis                        7457 non-null uint8
# descricao_historico_Técnico de Nivel Médio em Equipamentos Biomédicos                7457 non-null uint8
# descricao_historico_Técnico de Nivel Médio em Informática                            7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Administração                          7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Agroecologia                           7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Alimentos                              7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Apicultura                             7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Comércio                               7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Controle Ambiental                     7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Edificações                            7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Eletromecânica                         7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Eletrotécnica                          7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Eletrônica                             7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Eventos                                7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Geologia                               7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Informática                            7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Informática para Internet              7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Lazer                                  7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Logística                              7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática    7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Mecatrônica                            7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Mecânica                               7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Meio Ambiente                          7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Mineração                              7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Multimídia                             7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Química                                7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado            7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros                    7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Refrigeração e Climatização            7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Têxtil                                 7457 non-null uint8
# descricao_historico_Técnico de Nível Médio em Vestuário                              7457 non-null uint8
# descricao_historico_Técnico em Programação de Jogos Digitais                         7457 non-null uint8
# pessoa_fisica__sexo_F                                                                7457 non-null uint8
# pessoa_fisica__sexo_M                                                                7457 non-null uint8
# sigla_AP                                                                             7457 non-null uint8
# sigla_CA                                                                             7457 non-null uint8
# sigla_CAL                                                                            7457 non-null uint8
# sigla_CANG                                                                           7457 non-null uint8
# sigla_CM                                                                             7457 non-null uint8
# sigla_CN                                                                             7457 non-null uint8
# sigla_CNAT                                                                           7457 non-null uint8
# sigla_IP                                                                             7457 non-null uint8
# sigla_JC                                                                             7457 non-null uint8
# sigla_LAJ                                                                            7457 non-null uint8
# sigla_MC                                                                             7457 non-null uint8
# sigla_MO                                                                             7457 non-null uint8
# sigla_NC                                                                             7457 non-null uint8
# sigla_PAAS                                                                           7457 non-null uint8
# sigla_PAR                                                                            7457 non-null uint8
# sigla_PF                                                                             7457 non-null uint8
# sigla_SC                                                                             7457 non-null uint8
# sigla_SGA                                                                            7457 non-null uint8
# sigla_SPP                                                                            7457 non-null uint8
# sigla_ZN                                                                             7457 non-null uint8
# dtypes: float64(4), int64(5), uint8(56)
# memory usage: 990.4 KB

# %%
#SELECIONANDO MELHOR MODEL RF

#cria a randomforest 
forest_clf = RandomForestClassifier(oob_score=True, n_jobs=-1) 

param_grid_forest = {'max_depth': [3, 5, None],
              'max_features': ['auto', 'sqrt', 'log2'],
              'n_estimators': [10, 30, 60, 100, 200],
              'criterion': ["gini", "entropy"]}

#dividir os dados para treino e teste. default é 25% p teste
Xtrain, Xtest, ytrain, ytest = train_test_split(dados_clean, y, random_state=0, stratify = y)

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_forest = GridSearchCV(estimator=forest_clf, param_grid=param_grid_forest)
grid_search_forest.fit(Xtrain, ytrain)
print(grid_search_forest.best_params_)
print(grid_search_forest.best_estimator_)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=-1, oob_score=True, random_state=None,
#             verbose=0, warm_start=False)

# %%
#mostra os 5 melhores modelos
report(grid_search_forest.cv_results_, 5)
# Out:
# Model with rank: 1
# Mean validation score: 0.954 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.954 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.954 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 200}
#
# Model with rank: 4
# Mean validation score: 0.953 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 60}
#
# Model with rank: 5
# Mean validation score: 0.953 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}

# %%
#seleciona o melhor modelo
model_forest = grid_search_forest.best_estimator_
ypred_forest = model_forest.predict(Xtest)

# %%
#Evaluating
mat = confusion_matrix(ytest, ypred_forest)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))
print(f1_score(ytest, ypred_forest))

#qnt de evadidos 
print(sum(ytest==0))
# Out:
# 0.964530892449
# 0.988856304985
# 0.964530892449
# 0.988856304985
# 0.976542137272
# 160
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#CURVA ROC

y_probas_forest = cross_val_predict(model_forest, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_forest = y_probas_forest[:, 1]   # score = proba of positive class 
fpr_forest, tpr_forest, thresholds_forest = roc_curve(ytest, y_scores_forest)

plot_roc_curve(fpr_forest, tpr_forest) 
plt.show()
print(roc_auc_score(ytest, y_scores_forest))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.943698680352

# %%
#exibe os atributos mais importantes

importances = model_forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in model_forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(Xtest.shape[1]):
    print("%d. feature %d [%s] (%f)" % (f + 1, indices[f], dados_clean.columns[indices[f]],importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(Xtest.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(Xtest.shape[1]), indices)
plt.xlim([-1, Xtest.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 0 [LnguaPortuguesaeLiteraturaI90H] (0.206937)
# 2. feature 2 [MatemticaI120H] (0.127883)
# 3. feature 7 [percentual_frequencia] (0.103707)
# 4. feature 5 [ano_letivo__ano_matricula_periodo] (0.088014)
# 5. feature 1 [LnguaPortuguesaeLiteraturaII90H] (0.072138)
# 6. feature 6 [cep] (0.061986)
# 7. feature 8 [pessoa_fisica__nascimento_data] (0.061119)
# 8. feature 3 [MatemticaII90H] (0.046521)
# 9. feature 4 [ano_letivo__ano] (0.045801)
# 10. feature 55 [sigla_MC] (0.010719)
# 11. feature 44 [pessoa_fisica__sexo_M] (0.010580)
# 12. feature 43 [pessoa_fisica__sexo_F] (0.009848)
# 13. feature 13 [descricao_historico_Técnico de Nivel Médio em Informática] (0.006664)
# 14. feature 61 [sigla_SC] (0.006622)
# 15. feature 42 [descricao_historico_Técnico em Programação de Jogos Digitais] (0.006576)
# 16. feature 46 [sigla_CA] (0.006217)
# 17. feature 51 [sigla_CNAT] (0.005930)
# 18. feature 20 [descricao_historico_Técnico de Nível Médio em Edificações] (0.005572)
# 19. feature 57 [sigla_NC] (0.005276)
# 20. feature 54 [sigla_LAJ] (0.005111)
# 21. feature 38 [descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros] (0.005065)
# 22. feature 33 [descricao_historico_Técnico de Nível Médio em Meio Ambiente] (0.004780)
# 23. feature 14 [descricao_historico_Técnico de Nível Médio em Administração] (0.004567)
# 24. feature 49 [sigla_CM] (0.004399)
# 25. feature 53 [sigla_JC] (0.004094)
# 26. feature 26 [descricao_historico_Técnico de Nível Médio em Informática] (0.003993)
# 27. feature 63 [sigla_SPP] (0.003988)
# 28. feature 9 [descricao_historico_Técnico de Nivel Médio Informática] (0.003796)
# 29. feature 22 [descricao_historico_Técnico de Nível Médio em Eletrotécnica] (0.003709)
# 30. feature 32 [descricao_historico_Técnico de Nível Médio em Mecânica] (0.003352)
# 31. feature 47 [sigla_CAL] (0.003163)
# 32. feature 64 [sigla_ZN] (0.003157)
# 33. feature 50 [sigla_CN] (0.003046)
# 34. feature 27 [descricao_historico_Técnico de Nível Médio em Informática para Internet] (0.003043)
# 35. feature 58 [sigla_PAAS] (0.002882)
# 36. feature 48 [sigla_CANG] (0.002853)
# 37. feature 36 [descricao_historico_Técnico de Nível Médio em Química] (0.002821)
# 38. feature 45 [sigla_AP] (0.002789)
# 39. feature 59 [sigla_PAR] (0.002758)
# 40. feature 30 [descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática] (0.002710)
# 41. feature 10 [descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada] (0.002638)
# 42. feature 62 [sigla_SGA] (0.002467)
# 43. feature 40 [descricao_historico_Técnico de Nível Médio em Têxtil] (0.002176)
# 44. feature 34 [descricao_historico_Técnico de Nível Médio em Mineração] (0.002045)
# 45. feature 35 [descricao_historico_Técnico de Nível Médio em Multimídia] (0.002028)
# 46. feature 37 [descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado] (0.001913)
# 47. feature 52 [sigla_IP] (0.001833)
# 48. feature 41 [descricao_historico_Técnico de Nível Médio em Vestuário] (0.001791)
# 49. feature 19 [descricao_historico_Técnico de Nível Médio em Controle Ambiental] (0.001760)
# 50. feature 16 [descricao_historico_Técnico de Nível Médio em Alimentos] (0.001747)
# 51. feature 18 [descricao_historico_Técnico de Nível Médio em Comércio] (0.001746)
# 52. feature 60 [sigla_PF] (0.001736)
# 53. feature 56 [sigla_MO] (0.001682)
# 54. feature 25 [descricao_historico_Técnico de Nível Médio em Geologia] (0.001381)
# 55. feature 23 [descricao_historico_Técnico de Nível Médio em Eletrônica] (0.001377)
# 56. feature 29 [descricao_historico_Técnico de Nível Médio em Logística] (0.001309)
# 57. feature 12 [descricao_historico_Técnico de Nivel Médio em Equipamentos Biomédicos] (0.001177)
# 58. feature 21 [descricao_historico_Técnico de Nível Médio em Eletromecânica] (0.001006)
# 59. feature 28 [descricao_historico_Técnico de Nível Médio em Lazer] (0.000992)
# 60. feature 17 [descricao_historico_Técnico de Nível Médio em Apicultura] (0.000755)
# 61. feature 31 [descricao_historico_Técnico de Nível Médio em Mecatrônica] (0.000716)
# 62. feature 24 [descricao_historico_Técnico de Nível Médio em Eventos] (0.000614)
# 63. feature 39 [descricao_historico_Técnico de Nível Médio em Refrigeração e Climatização] (0.000503)
# 64. feature 15 [descricao_historico_Técnico de Nível Médio em Agroecologia] (0.000354)
# 65. feature 11 [descricao_historico_Técnico de Nivel Médio em Biocombustíveis] (0.000063)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#DECISION TREE
tree_clf = DecisionTreeClassifier() 

param_grid_tree = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_tree = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree)
grid_search_tree.fit(Xtrain, ytrain)
print(grid_search_tree.best_params_)
print(grid_search_tree.best_estimator_)
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=10,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
#seleciona o melhor modelo e exibe os 5 melhores
report(grid_search_tree.cv_results_, 5)

model_tree = grid_search_tree.best_estimator_
ypred_tree = model_tree.predict(Xtest)
# Out:
# Model with rank: 1
# Mean validation score: 0.949 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 2
# Mean validation score: 0.949 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.948 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 4
# Mean validation score: 0.948 (std: 0.006)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 5
# Mean validation score: 0.947 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}

# %%
#porcentagem de predicao correta
n_correct = sum(ypred_tree == ytest)    
print(n_correct / len(ypred_tree)) 

#evaluating
mat = confusion_matrix(ytest, ypred_tree)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_tree))
print(recall_score(ytest, ypred_tree))
print(f1_score(ytest, ypred_tree))
# Out:
# 0.942091152815
# 0.966686148451
# 0.97008797654
# 0.968384074941
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#gera a arvore de decisao
export_graphviz(model_tree,
                feature_names=dados_clean.columns,
                filled=True,
                rounded=True, 
                out_file='tree.dot')

os.system('dot -Tpng tree.dot -o tree.png')
# Out:
# 0

# %%
y_probas_tree = cross_val_predict(model_tree, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_tree = y_probas_tree[:, 1]   # score = proba of positive class 
fpr_tree, tpr_tree, thresholds_tree = roc_curve(ytest, y_scores_tree)

plot_roc_curve(fpr_tree, tpr_tree) 
plt.show()
print(roc_auc_score(ytest, y_scores_tree))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.875075146628

# %%
#PLOTAR DUAS CURVAS ROC (DT e RF)
plt.plot(fpr_tree, tpr_tree, "b:", label="DT") 
plot_roc_curve(fpr_forest, tpr_forest, "Random Forest") 
plt.legend(loc="bottom right") 
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:326: UserWarning: Unrecognized location "bottom right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   six.iterkeys(self.codes))))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#REDUÇÃO DE DIMENSIONALIDADE

#pca = PCA(n_components=0.95) 
pca = PCA(n_components=2) 
X_reduced = pca.fit_transform(dados_clean) 

print(pca.explained_variance_ratio_) 
print(X_reduced.shape)

pca = PCA() 
pca.fit(dados_clean) 
cumsum = np.cumsum(pca.explained_variance_ratio_) 
d = np.argmax(cumsum >= 0.95) + 1
plt.plot(cumsum)
# Out:
# [ 0.98025088  0.01974912]
# (7457, 2)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
colors = ['red','blue']
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y, cmap=matplotlib.colors.ListedColormap(colors))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#cria a randomforest  
forest_pca = RandomForestClassifier() 

param_grid_pca = {'max_depth': [3, 5, None],
              'max_features': ['auto', 'sqrt', 'log2'],
              'n_estimators': [10, 30, 60, 100, 200],              
              'criterion': ["gini", "entropy"]}


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_pca, Xtest_pca, ytrain_pca, ytest_pca = train_test_split(X_reduced, y, random_state=0, stratify = y)

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_pca = GridSearchCV(estimator=forest_pca, param_grid=param_grid_pca, cv = 5)
grid_search_pca.fit(Xtrain_pca, ytrain_pca)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'max_depth': [3, 5, None], 'max_features': ['auto', 'sqrt', 'log2'], 'n_estimators': [10, 30, 60, 100, 200], 'criterion': ['gini', 'entropy']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
print(grid_search_pca.best_params_)
print(grid_search_pca.best_estimator_)

#exibir melhor modelo
report(grid_search_pca.cv_results_, 5)

#seleciona o melhor modelo
model_pca = grid_search_pca.best_estimator_
ypred_pca = model_pca.predict(Xtest_pca)
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 10}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=3, max_features='log2', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# Model with rank: 1
# Mean validation score: 0.914 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 10}
#
# Model with rank: 1
# Mean validation score: 0.914 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 60}
#
# Model with rank: 1
# Mean validation score: 0.914 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 30}
#
# Model with rank: 1
# Mean validation score: 0.914 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100}
#
# Model with rank: 1
# Mean validation score: 0.914 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 30}
#
# Model with rank: 1
# Mean validation score: 0.914 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 60}
#
# Model with rank: 1
# Mean validation score: 0.914 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 60}
#
# Model with rank: 1
# Mean validation score: 0.914 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 30}
#
# Model with rank: 1
# Mean validation score: 0.914 (std: 0.001)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 10}

# %%
#Evaluating
mat = confusion_matrix(ytest_pca, ypred_pca)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_pca, ypred_pca))
print(recall_score(ytest_pca, ypred_pca))

#evaluating
print(precision_score(ytest_pca, ypred_pca))
print(recall_score(ytest_pca, ypred_pca))
print(f1_score(ytest_pca, ypred_pca))
# Out:
# 0.914163090129
# 0.999413489736
# 0.914163090129
# 0.999413489736
# 0.954889324741
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#CURVA ROC
y_probas_pca = cross_val_predict(model_pca, Xtest_pca, ytest_pca, cv=3, method="predict_proba") 

y_scores_pca = y_probas_pca[:, 1]   # score = proba of positive class 
fpr_pca, tpr_pca, thresholds_pca = roc_curve(ytest_pca, y_scores_pca)

plot_roc_curve(fpr_pca, tpr_pca) 
plt.show()
print(roc_auc_score(ytest_pca, y_scores_pca))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.522707111437

# %%
#UTILIZANDO APENAS AS NOTAS
dados_reduzido = dados_clean[['LnguaPortuguesaeLiteraturaI90H', 'MatemticaI120H', 
                              'LnguaPortuguesaeLiteraturaII90H', 'MatemticaII90H']]


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_red, Xtest_red, ytrain_red, ytest_red = train_test_split(dados_reduzido, y, random_state=0, stratify = y)

tree_clf = DecisionTreeClassifier() 

param_grid_tree_red = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_red = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree_red)
grid_search_red.fit(Xtrain_red, ytrain_red)
print(grid_search_red.best_params_)
print(grid_search_red.best_estimator_)

#mostra os melhores 5 modelos
report(grid_search_red.cv_results_, 5)

#realiza predicao
model_red = grid_search_red.best_estimator_
ypred_red = model_red.predict(Xtest_red)

#avalia modelo
n_correct = sum(ypred_red == ytest_red)    
print(n_correct / len(ypred_red)) 

#evaluating
mat = confusion_matrix(ytest_red, ypred_red)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_red, ypred_red))
print(recall_score(ytest_red, ypred_red))
print(f1_score(ytest_red, ypred_red))

#curva ROC
y_probas_tree_red = cross_val_predict(model_red, Xtest_red, ytest_red, cv=3, method="predict_proba") 

y_scores_tree_red = y_probas_tree_red[:, 1]   # score = proba of positive class 
fpr_tree_red, tpr_tree_red, thresholds_tree_red = roc_curve(ytest_red, y_scores_tree_red)

fig = plt.figure()

plot_roc_curve(fpr_tree_red, tpr_tree_red) 
plt.show()
print(roc_auc_score(ytest_red, y_scores_tree_red))
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=10, min_impurity_split=1e-07,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# Model with rank: 1
# Mean validation score: 0.929 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.929 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.929 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.929 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.929 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.929 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# 0.923860589812
# 0.950432276657
# 0.96715542522
# 0.958720930233
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.84762829912

# %%
#PLOTAR DUAS CURVAS ROC (DT e RF)
plt.plot(fpr_tree_red, tpr_tree_red, "b:", label="DT-RED") 
plot_roc_curve(fpr_forest, tpr_forest, "Random Forest") 
plt.legend(loc="bottom right") 
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:326: UserWarning: Unrecognized location "bottom right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   six.iterkeys(self.codes))))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#UTILIZANDO AS MÉDIAS DE CADA ANO

nota_1 = dados_clean[['LnguaPortuguesaeLiteraturaI90H', 'MatemticaI120H']].mean(axis=1)
nota_2 = dados_clean[['LnguaPortuguesaeLiteraturaII90H', 'MatemticaII90H']].mean(axis=1)

dados_reduzido = pd.DataFrame()
dados_reduzido['1_ano'] = nota_1
dados_reduzido['2_ano'] = nota_2


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_red, Xtest_red, ytrain_red, ytest_red = train_test_split(dados_reduzido, y, random_state=0)

tree_clf = DecisionTreeClassifier() 

param_grid_tree_red = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_red = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree_red)
grid_search_red.fit(Xtrain_red, ytrain_red)
print(grid_search_red.best_params_)
print(grid_search_red.best_estimator_)

#mostra os melhores 5 modelos
report(grid_search_red.cv_results_, 5)

#realiza predicao
model_red = grid_search_red.best_estimator_
ypred_red = model_red.predict(Xtest_red)

#avalia modelo
n_correct = sum(ypred_red == ytest_red)    
print(n_correct / len(ypred_red)) 

#evaluating
mat = confusion_matrix(ytest_red, ypred_red)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_red, ypred_red))
print(recall_score(ytest_red, ypred_red))
print(f1_score(ytest_red, ypred_red))

#curva ROC
y_probas_tree_red = cross_val_predict(model_red, Xtest_red, ytest_red, cv=3, method="predict_proba") 

y_scores_tree_red = y_probas_tree_red[:, 1]   # score = proba of positive class 
fpr_tree_red, tpr_tree_red, thresholds_tree_red = roc_curve(ytest_red, y_scores_tree_red)

fig = plt.figure()

plot_roc_curve(fpr_tree_red, tpr_tree_red) 
plt.show()
print(roc_auc_score(ytest_red, y_scores_tree_red))
# Out:
# {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.928 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# 0.918498659517
# 0.946613088404
# 0.965456674473
# 0.955942028986
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.821575873745

# %%
#SELECIONANDO OS MELHORES ATRIBUTOS PARA TREINAMENTO
#CRITERIO UTILIZADO 80% DA IMPORTANCIA
print("Feature ranking:")

imp_cum = 0

for f in range(Xtest.shape[1]):
    print("%d. feature %d [%s] (%f)" % (f + 1, indices[f], dados_clean.columns[indices[f]],importances[indices[f]]))
    imp_cum = imp_cum + importances[indices[f]]
    print(imp_cum)
# Out:
# Feature ranking:
# 1. feature 0 [LnguaPortuguesaeLiteraturaI90H] (0.206937)
# 0.206937198227
# 2. feature 2 [MatemticaI120H] (0.127883)
# 0.334820079079
# 3. feature 7 [percentual_frequencia] (0.103707)
# 0.438527105371
# 4. feature 5 [ano_letivo__ano_matricula_periodo] (0.088014)
# 0.526541416098
# 5. feature 1 [LnguaPortuguesaeLiteraturaII90H] (0.072138)
# 0.598679607455
# 6. feature 6 [cep] (0.061986)
# 0.660665846594
# 7. feature 8 [pessoa_fisica__nascimento_data] (0.061119)
# 0.721784700394
# 8. feature 3 [MatemticaII90H] (0.046521)
# 0.768305984822
# 9. feature 4 [ano_letivo__ano] (0.045801)
# 0.814106531841
# 10. feature 55 [sigla_MC] (0.010719)
# 0.824825611294
# 11. feature 44 [pessoa_fisica__sexo_M] (0.010580)
# 0.835405453495
# 12. feature 43 [pessoa_fisica__sexo_F] (0.009848)
# 0.845253938985
# 13. feature 13 [descricao_historico_Técnico de Nivel Médio em Informática] (0.006664)
# 0.851918321842
# 14. feature 61 [sigla_SC] (0.006622)
# 0.858540543389
# 15. feature 42 [descricao_historico_Técnico em Programação de Jogos Digitais] (0.006576)
# 0.865116537202
# 16. feature 46 [sigla_CA] (0.006217)
# 0.871333704644
# 17. feature 51 [sigla_CNAT] (0.005930)
# 0.877263489018
# 18. feature 20 [descricao_historico_Técnico de Nível Médio em Edificações] (0.005572)
# 0.882835683281
# 19. feature 57 [sigla_NC] (0.005276)
# 0.888111891798
# 20. feature 54 [sigla_LAJ] (0.005111)
# 0.893222511467
# 21. feature 38 [descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros] (0.005065)
# 0.898287189126
# 22. feature 33 [descricao_historico_Técnico de Nível Médio em Meio Ambiente] (0.004780)
# 0.903067234213
# 23. feature 14 [descricao_historico_Técnico de Nível Médio em Administração] (0.004567)
# 0.907633821356
# 24. feature 49 [sigla_CM] (0.004399)
# 0.912032590456
# 25. feature 53 [sigla_JC] (0.004094)
# 0.916126422789
# 26. feature 26 [descricao_historico_Técnico de Nível Médio em Informática] (0.003993)
# 0.920119695209
# 27. feature 63 [sigla_SPP] (0.003988)
# 0.924107992133
# 28. feature 9 [descricao_historico_Técnico de Nivel Médio Informática] (0.003796)
# 0.927904133527
# 29. feature 22 [descricao_historico_Técnico de Nível Médio em Eletrotécnica] (0.003709)
# 0.931612821481
# 30. feature 32 [descricao_historico_Técnico de Nível Médio em Mecânica] (0.003352)
# 0.934965275129
# 31. feature 47 [sigla_CAL] (0.003163)
# 0.938128612237
# 32. feature 64 [sigla_ZN] (0.003157)
# 0.941285966676
# 33. feature 50 [sigla_CN] (0.003046)
# 0.944331912999
# 34. feature 27 [descricao_historico_Técnico de Nível Médio em Informática para Internet] (0.003043)
# 0.947375265764
# 35. feature 58 [sigla_PAAS] (0.002882)
# 0.950257295762
# 36. feature 48 [sigla_CANG] (0.002853)
# 0.953110527094
# 37. feature 36 [descricao_historico_Técnico de Nível Médio em Química] (0.002821)
# 0.955931857234
# 38. feature 45 [sigla_AP] (0.002789)
# 0.958720844621
# 39. feature 59 [sigla_PAR] (0.002758)
# 0.961478785049
# 40. feature 30 [descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática] (0.002710)
# 0.964188665884
# 41. feature 10 [descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada] (0.002638)
# 0.966826846343
# 42. feature 62 [sigla_SGA] (0.002467)
# 0.969294291008
# 43. feature 40 [descricao_historico_Técnico de Nível Médio em Têxtil] (0.002176)
# 0.971470713697
# 44. feature 34 [descricao_historico_Técnico de Nível Médio em Mineração] (0.002045)
# 0.973515762854
# 45. feature 35 [descricao_historico_Técnico de Nível Médio em Multimídia] (0.002028)
# 0.975544163748
# 46. feature 37 [descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado] (0.001913)
# 0.977457609479
# 47. feature 52 [sigla_IP] (0.001833)
# 0.979290920908
# 48. feature 41 [descricao_historico_Técnico de Nível Médio em Vestuário] (0.001791)
# 0.981081934848
# 49. feature 19 [descricao_historico_Técnico de Nível Médio em Controle Ambiental] (0.001760)
# 0.982842322169
# 50. feature 16 [descricao_historico_Técnico de Nível Médio em Alimentos] (0.001747)
# 0.984589118632
# 51. feature 18 [descricao_historico_Técnico de Nível Médio em Comércio] (0.001746)
# 0.986334987484
# 52. feature 60 [sigla_PF] (0.001736)
# 0.988070904499
# 53. feature 56 [sigla_MO] (0.001682)
# 0.989752411759
# 54. feature 25 [descricao_historico_Técnico de Nível Médio em Geologia] (0.001381)
# 0.991133095039
# 55. feature 23 [descricao_historico_Técnico de Nível Médio em Eletrônica] (0.001377)
# 0.99251057614
# 56. feature 29 [descricao_historico_Técnico de Nível Médio em Logística] (0.001309)
# 0.993819833212
# 57. feature 12 [descricao_historico_Técnico de Nivel Médio em Equipamentos Biomédicos] (0.001177)
# 0.994996744139
# 58. feature 21 [descricao_historico_Técnico de Nível Médio em Eletromecânica] (0.001006)
# 0.996002656951
# 59. feature 28 [descricao_historico_Técnico de Nível Médio em Lazer] (0.000992)
# 0.996994712052
# 60. feature 17 [descricao_historico_Técnico de Nível Médio em Apicultura] (0.000755)
# 0.997750169576
# 61. feature 31 [descricao_historico_Técnico de Nível Médio em Mecatrônica] (0.000716)
# 0.99846603542
# 62. feature 24 [descricao_historico_Técnico de Nível Médio em Eventos] (0.000614)
# 0.999080486308
# 63. feature 39 [descricao_historico_Técnico de Nível Médio em Refrigeração e Climatização] (0.000503)
# 0.999583004421
# 64. feature 15 [descricao_historico_Técnico de Nível Médio em Agroecologia] (0.000354)
# 0.999937476137
# 65. feature 11 [descricao_historico_Técnico de Nivel Médio em Biocombustíveis] (0.000063)
# 1.0

# %%
dados_reduzido = dados_clean[['LnguaPortuguesaeLiteraturaI90H', 'MatemticaI120H', 
                              'LnguaPortuguesaeLiteraturaII90H', 'MatemticaII90H', 
                              'percentual_frequencia', 'ano_letivo__ano_matricula_periodo', 
                              #'pessoa_fisica__nascimento_data', 
                              'cep', 
                              #'ano_letivo__ano'
                             ]]


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_red, Xtest_red, ytrain_red, ytest_red = train_test_split(dados_reduzido, y, random_state=0, stratify = y)

tree_clf = DecisionTreeClassifier() 

param_grid_tree_red = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_red = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree_red)
grid_search_red.fit(Xtrain_red, ytrain_red)
print(grid_search_red.best_params_)
print(grid_search_red.best_estimator_)

#mostra os melhores 5 modelos
report(grid_search_red.cv_results_, 5)

#realiza predicao
model_red = grid_search_red.best_estimator_
ypred_red = model_red.predict(Xtest_red)

#avalia modelo
n_correct = sum(ypred_red == ytest_red)    
print(n_correct / len(ypred_red)) 

#evaluating
mat = confusion_matrix(ytest_red, ypred_red)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_red, ypred_red))
print(recall_score(ytest_red, ypred_red))
print(f1_score(ytest_red, ypred_red))

#curva ROC
y_probas_tree_red = cross_val_predict(model_red, Xtest_red, ytest_red, cv=3, method="predict_proba") 

y_scores_tree_red = y_probas_tree_red[:, 1]   # score = proba of positive class 
fpr_tree_red, tpr_tree_red, thresholds_tree_red = roc_curve(ytest_red, y_scores_tree_red)

fig = plt.figure()

plot_roc_curve(fpr_tree_red, tpr_tree_red) 
plt.show()
print(roc_auc_score(ytest_red, y_scores_tree_red))
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')
# Model with rank: 1
# Mean validation score: 0.950 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.950 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.950 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 4
# Mean validation score: 0.950 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 4
# Mean validation score: 0.950 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# 0.945844504021
# 0.969005847953
# 0.971847507331
# 0.970424597365
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.882556818182

# %%
#gera a arvore de decisao
export_graphviz(model_red,
                feature_names=dados_reduzido.columns,
                filled=True,
                rounded=True, 
                out_file='tree_red.dot')

os.system('dot -Tpng tree_red.dot -o tree_red.png')
# Out:
# 0
