# %% [markdown]
# # Análise de alunos do integrado do IFRN
# a base de dados consiste em dados socioeconômicos e as notas finais de português e matemática do 1º e 2º ano. Essas disciplinas foram selecionadas devido a certeza delas estarem presente em todos os cursos de integrado ofertados no IFRN

# %%
#import os pacotes utilizados
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

#ESCALONAMENTO DE DADOS
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler

#SELECIONANDO MELHOR MODELO
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from scipy.stats import randint as sp_randint
from sklearn.cross_validation import train_test_split

#Evaluating
import seaborn as sns; sns.set()

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import f1_score

#EXPORTAR ARVORE
from sklearn.tree import export_graphviz
import os

#CURVA ROC
# %matplotlib inline
from sklearn.metrics import roc_curve
from sklearn.model_selection import cross_val_predict 
from sklearn.metrics import roc_auc_score

#REDUÇÃO DE DIMENSIONALIDADE
from sklearn.decomposition import PCA

#exibindo todas as colunas
pd.set_option('display.max_columns', None)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#definicao de funcoes que serao utilizadas

# Utility function to report best scores
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")
            
def plot_roc_curve(fpr, tpr, label=None):    
    plt.plot(fpr, tpr, linewidth=2, label=label)    
    plt.plot([0, 1], [0, 1], 'k--')    
    plt.axis([0, 1, 0, 1])   
    plt.xlabel('False Positive Rate')    
    plt.ylabel('True Positive Rate')

# %%
#importando base já tratada
dados = pd.read_json('dados/dados_flat_COM_social.json')
print(dados.id.nunique())
print(dados.shape)
dados.head(3)
# Out:
# 7520
# (7520, 29)
#        LnguaPortuguesaeLiteraturaI90H  LnguaPortuguesaeLiteraturaII90H  \
# 34217                              68                             68.0
# 34218                              73                             21.0
# 34219                              70                             80.0
#
#        MatemticaI120H  MatemticaII90H  ano_letivo__ano  \
# 34217              66            79.0             2015
# 34218              23             7.0             2015
# 34219              61            73.0             2015
#
#        ano_letivo__ano_matricula_periodo        cep  classe    descricao  \
# 34217                               2015  59535-000       1  Matriculado
# 34218                               2015  59460-000       0    Cancelado
# 34219                               2015  59810-000       1  Matriculado
#
#       descricao_area_residencial descricao_companhia_domiciliar  \
# 34217                     Urbana                            Mãe
# 34218                     Urbana                            Mãe
# 34219                     Urbana                           Pais
#
#                            descricao_historico descricao_imovel  \
# 34217    Técnico de Nivel Médio em Informática          Alugado
# 34218  Técnico de Nível Médio em Meio Ambiente          Alugado
# 34219     Técnico de Nível Médio em Apicultura          Alugado
#
#           descricao_mae_escolaridade     descricao_pai_escolaridade  \
# 34217  Ensino fundamental incompleto  Ensino fundamental incompleto
# 34218  Ensino fundamental incompleto  Ensino fundamental incompleto
# 34219          Ensino médio completo  Ensino fundamental incompleto
#
#       descricao_raca descricao_responsavel_escolaridade  \
# 34217         Branca      Ensino fundamental incompleto
# 34218          Parda      Ensino fundamental incompleto
# 34219          Parda      Ensino fundamental incompleto
#
#       descricao_responsavel_financeiro descricao_situacao_matricula_periodo  \
# 34217                              Mãe                          Dependência
# 34218                              Mãe                          Dependência
# 34219                              Pai                          Dependência
#
#       descricao_trabalho_responsavel            id  \
# 34217                  Não informado  457884597605
# 34218                  Não informado  458436647741
# 34219                       Autônomo  452768375385
#
#            nome_escola_ensino_fundamental  percentual_frequencia  \
# 34217  ESCOLA MUNICIPAL DR. ELOY DE SOUZA                  100.0
# 34218                                                       91.0
# 34219                                                       98.0
#
#       pessoa_fisica__nascimento_data pessoa_fisica__sexo  qnt_pc  \
# 34217                     22/10/1999                   F     0.0
# 34218                     04/10/1997                   M     1.0
# 34219                     05/07/1999                   F     0.0
#
#        qtd_pessoas_domicilio  renda_bruta_familiar sigla
# 34217                      2                 300.0   LAJ
# 34218                      2                   0.0   SPP
# 34219                      6                 720.0    PF

# %%
#removendo colunas que explodem a quantidade de atributos quando binarizados ou nao tragam informacoes
del dados['id']
del dados['qnt_pc']
del dados['nome_escola_ensino_fundamental']

#dados que fazem a indicação se o aluno teve evasão
del dados['descricao']
del dados['descricao_situacao_matricula_periodo']

# %%
#transformando o dado em int
dados['cep'] = dados['cep'].str.replace('-', '')
dados['cep'] = dados['cep'].apply(pd.to_numeric, errors='coerce')

# %%
#transformando o dado em int
dados['pessoa_fisica__nascimento_data'] = dados['pessoa_fisica__nascimento_data'].str.replace('/','').apply(int)

# %%
#convertendo os NaN das notas em -1 para usar o RF 
dados['LnguaPortuguesaeLiteraturaI90H'].fillna(-1, inplace=True)
dados['MatemticaI120H'].fillna(-1, inplace=True)
dados['LnguaPortuguesaeLiteraturaII90H'].fillna(-1, inplace=True)
dados['MatemticaII90H'].fillna(-1, inplace=True)

# %%
#limpando os NaN devido ao RF
print(dados.shape)
df = dados
df = df.dropna()
dados = df
print(dados.shape)
# Out:
# (7520, 24)
# (7394, 24)

# %%
#configura os dados de entrada e saída
y = dados.classe
X = dados

del X['classe']
X.shape
# Out:
# (7394, 23)

# %%
#visualizacao hist da classe
y.plot.hist()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#binazira os dados devido aos atributos categoricos 
dados_dummies = pd.get_dummies(X, drop_first=False)
dados_dummies.shape
# Out:
# (7394, 148)

# %%
dados_dummies.hist(figsize=(20, 15))
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#remove atributos inconistentes
dados_clean = dados_dummies.replace([np.inf, -np.inf], np.nan)
dados_clean = dados_clean.dropna(axis=1, how='all')
dados_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7394 entries, 34217 to 43634
# Columns: 148 entries, LnguaPortuguesaeLiteraturaI90H to sigla_ZN
# dtypes: float64(5), int64(6), uint8(137)
# memory usage: 1.6 MB

# %%
#SELECIONANDO MELHOR MODEL RF

#cria a randomforest 
forest_clf = RandomForestClassifier(oob_score=True, n_jobs=-1) 

param_grid_forest = {'max_depth': [3, 5, None],
              'max_features': ['auto', 'sqrt', 'log2'],
              'n_estimators': [10, 30, 60, 100, 200, 500, 1000],
              'criterion': ["gini", "entropy"]}

#dividir os dados para treino e teste. default é 25% p teste
Xtrain, Xtest, ytrain, ytest = train_test_split(dados_clean, y, random_state=0)

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_forest = GridSearchCV(estimator=forest_clf, param_grid=param_grid_forest)
grid_search_forest.fit(Xtrain, ytrain)
print(grid_search_forest.best_params_)
print(grid_search_forest.best_estimator_)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 30}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=30, n_jobs=-1, oob_score=True, random_state=None,
#             verbose=0, warm_start=False)

# %%
#mostra os 5 melhores modelos
report(grid_search_forest.cv_results_, 5)
# Out:
# Model with rank: 1
# Mean validation score: 0.948 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.948 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.948 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
#
# Model with rank: 4
# Mean validation score: 0.948 (std: 0.003)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 500}
#
# Model with rank: 4
# Mean validation score: 0.948 (std: 0.003)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 100}

# %%
#seleciona o melhor modelo
model_forest = grid_search_forest.best_estimator_
ypred_forest = model_forest.predict(Xtest)

# %%
#Evaluating
mat = confusion_matrix(ytest, ypred_forest)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))
print(f1_score(ytest, ypred_forest))

#qnt de evadidos 
print(sum(ytest==0))
# Out:
# 0.953062392673
# 0.985790408526
# 0.953062392673
# 0.985790408526
# 0.969150174622
# 160
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#CURVA ROC

y_probas_forest = cross_val_predict(model_forest, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_forest = y_probas_forest[:, 1]   # score = proba of positive class 
fpr_forest, tpr_forest, thresholds_forest = roc_curve(ytest, y_scores_forest)

plot_roc_curve(fpr_forest, tpr_forest) 
plt.show()
print(roc_auc_score(ytest, y_scores_forest))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.909950414446

# %%
#exibe os atributos mais importantes

importances = model_forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in model_forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(Xtest.shape[1]):
    print("%d. feature %d [%s] (%f)" % (f + 1, indices[f], dados_clean.columns[indices[f]],importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(Xtest.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(Xtest.shape[1]), indices)
plt.xlim([-1, Xtest.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 0 [LnguaPortuguesaeLiteraturaI90H] (0.144925)
# 2. feature 2 [MatemticaI120H] (0.102099)
# 3. feature 7 [percentual_frequencia] (0.095205)
# 4. feature 1 [LnguaPortuguesaeLiteraturaII90H] (0.047084)
# 5. feature 3 [MatemticaII90H] (0.046896)
# 6. feature 5 [ano_letivo__ano_matricula_periodo] (0.039856)
# 7. feature 6 [cep] (0.038669)
# 8. feature 10 [renda_bruta_familiar] (0.034467)
# 9. feature 8 [pessoa_fisica__nascimento_data] (0.034060)
# 10. feature 4 [ano_letivo__ano] (0.023960)
# 11. feature 9 [qtd_pessoas_domicilio] (0.020996)
# 12. feature 13 [descricao_area_residencial_Não informado] (0.019838)
# 13. feature 15 [descricao_area_residencial_Urbana] (0.010085)
# 14. feature 138 [sigla_MC] (0.009866)
# 15. feature 14 [descricao_area_residencial_Rural] (0.007872)
# 16. feature 127 [pessoa_fisica__sexo_M] (0.007638)
# 17. feature 115 [descricao_trabalho_responsavel_Autônomo] (0.007212)
# 18. feature 117 [descricao_trabalho_responsavel_Empresa privada] (0.006746)
# 19. feature 78 [descricao_pai_escolaridade_Ensino fundamental incompleto] (0.006626)
# 20. feature 28 [descricao_historico_Técnico de Nivel Médio em Informática] (0.006467)
# 21. feature 107 [descricao_responsavel_financeiro_Mãe] (0.006405)
# 22. feature 95 [descricao_responsavel_escolaridade_Ensino fundamental incompleto] (0.006168)
# 23. feature 91 [descricao_raca_Parda] (0.005771)
# 24. feature 111 [descricao_responsavel_financeiro_Pai] (0.005696)
# 25. feature 88 [descricao_raca_Branca] (0.005695)
# 26. feature 21 [descricao_companhia_domiciliar_Pais] (0.005621)
# 27. feature 58 [descricao_imovel_Alugado] (0.005561)
# 28. feature 96 [descricao_responsavel_escolaridade_Ensino médio completo] (0.005439)
# 29. feature 144 [sigla_SC] (0.005428)
# 30. feature 126 [pessoa_fisica__sexo_F] (0.005372)
# 31. feature 64 [descricao_imovel_Próprio] (0.005328)
# 32. feature 79 [descricao_pai_escolaridade_Ensino médio completo] (0.005315)
# 33. feature 123 [descricao_trabalho_responsavel_Serviço público] (0.005226)
# 34. feature 129 [sigla_CA] (0.005043)
# 35. feature 68 [descricao_mae_escolaridade_Ensino médio completo] (0.004840)
# 36. feature 17 [descricao_companhia_domiciliar_Mãe] (0.004730)
# 37. feature 92 [descricao_raca_Preta] (0.004635)
# 38. feature 57 [descricao_historico_Técnico em Programação de Jogos Digitais] (0.004543)
# 39. feature 67 [descricao_mae_escolaridade_Ensino fundamental incompleto] (0.004447)
# 40. feature 134 [sigla_CNAT] (0.004310)
# 41. feature 53 [descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros] (0.004153)
# 42. feature 35 [descricao_historico_Técnico de Nível Médio em Edificações] (0.003964)
# 43. feature 121 [descricao_trabalho_responsavel_Não informado] (0.003950)
# 44. feature 70 [descricao_mae_escolaridade_Ensino superior completo] (0.003787)
# 45. feature 29 [descricao_historico_Técnico de Nível Médio em Administração] (0.003623)
# 46. feature 137 [sigla_LAJ] (0.003611)
# 47. feature 76 [descricao_pai_escolaridade_Alfabetizado] (0.003457)
# 48. feature 81 [descricao_pai_escolaridade_Ensino superior completo] (0.003274)
# 49. feature 22 [descricao_companhia_domiciliar_Parente(s) ou amigo(s)] (0.003240)
# 50. feature 120 [descricao_trabalho_responsavel_Não está trabalhando] (0.003240)
# 51. feature 77 [descricao_pai_escolaridade_Ensino fundamental completo] (0.003188)
# 52. feature 97 [descricao_responsavel_escolaridade_Ensino médio incompleto] (0.003106)
# 53. feature 41 [descricao_historico_Técnico de Nível Médio em Informática] (0.003103)
# 54. feature 66 [descricao_mae_escolaridade_Ensino fundamental completo] (0.003017)
# 55. feature 140 [sigla_NC] (0.002978)
# 56. feature 37 [descricao_historico_Técnico de Nível Médio em Eletrotécnica] (0.002935)
# 57. feature 114 [descricao_trabalho_responsavel_Aposentado] (0.002921)
# 58. feature 69 [descricao_mae_escolaridade_Ensino médio incompleto] (0.002853)
# 59. feature 98 [descricao_responsavel_escolaridade_Ensino superior completo] (0.002823)
# 60. feature 102 [descricao_responsavel_escolaridade_Pós graduação completo] (0.002742)
# 61. feature 42 [descricao_historico_Técnico de Nível Médio em Informática para Internet] (0.002739)
# 62. feature 48 [descricao_historico_Técnico de Nível Médio em Meio Ambiente] (0.002717)
# 63. feature 125 [descricao_trabalho_responsavel_Trabalhador rural/Agricultor] (0.002702)
# 64. feature 74 [descricao_mae_escolaridade_Pós graduação completo] (0.002679)
# 65. feature 146 [sigla_SPP] (0.002644)
# 66. feature 19 [descricao_companhia_domiciliar_Outros] (0.002562)
# 67. feature 132 [sigla_CM] (0.002541)
# 68. feature 141 [sigla_PAAS] (0.002484)
# 69. feature 20 [descricao_companhia_domiciliar_Pai] (0.002480)
# 70. feature 24 [descricao_historico_Técnico de Nivel Médio Informática] (0.002438)
# 71. feature 47 [descricao_historico_Técnico de Nível Médio em Mecânica] (0.002434)
# 72. feature 61 [descricao_imovel_Não informado] (0.002376)
# 73. feature 85 [descricao_pai_escolaridade_Pós graduação completo] (0.002372)
# 74. feature 99 [descricao_responsavel_escolaridade_Ensino superior incompleto] (0.002367)
# 75. feature 93 [descricao_responsavel_escolaridade_Alfabetizado] (0.002345)
# 76. feature 143 [sigla_PF] (0.002318)
# 77. feature 128 [sigla_AP] (0.002250)
# 78. feature 130 [sigla_CAL] (0.002235)
# 79. feature 104 [descricao_responsavel_financeiro_Avô(ó)] (0.002190)
# 80. feature 113 [descricao_responsavel_financeiro_Tio(a)] (0.002125)
# 81. feature 65 [descricao_mae_escolaridade_Alfabetizado] (0.002121)
# 82. feature 109 [descricao_responsavel_financeiro_O próprio aluno] (0.002118)
# 83. feature 84 [descricao_pai_escolaridade_Não estudou] (0.002115)
# 84. feature 60 [descricao_imovel_Financiado] (0.002110)
# 85. feature 135 [sigla_IP] (0.002067)
# 86. feature 55 [descricao_historico_Técnico de Nível Médio em Têxtil] (0.002052)
# 87. feature 145 [sigla_SGA] (0.002026)
# 88. feature 49 [descricao_historico_Técnico de Nível Médio em Mineração] (0.002012)
# 89. feature 83 [descricao_pai_escolaridade_Não conhece] (0.002000)
# 90. feature 142 [sigla_PAR] (0.001982)
# 91. feature 94 [descricao_responsavel_escolaridade_Ensino fundamental completo] (0.001966)
# 92. feature 147 [sigla_ZN] (0.001946)
# 93. feature 80 [descricao_pai_escolaridade_Ensino médio incompleto] (0.001920)
# 94. feature 45 [descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática] (0.001860)
# 95. feature 16 [descricao_companhia_domiciliar_Cônjuge] (0.001807)
# 96. feature 62 [descricao_imovel_Outro] (0.001787)
# 97. feature 87 [descricao_raca_Amarela] (0.001786)
# 98. feature 136 [sigla_JC] (0.001780)
# 99. feature 131 [sigla_CANG] (0.001760)
# 100. feature 133 [sigla_CN] (0.001699)
# 101. feature 73 [descricao_mae_escolaridade_Não estudou] (0.001670)
# 102. feature 106 [descricao_responsavel_financeiro_Irmão(ã)] (0.001425)
# 103. feature 27 [descricao_historico_Técnico de Nivel Médio em Equipamentos Biomédicos] (0.001332)
# 104. feature 116 [descricao_trabalho_responsavel_Beneficiário ou Pensionista do INSS] (0.001316)
# 105. feature 25 [descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada] (0.001307)
# 106. feature 31 [descricao_historico_Técnico de Nível Médio em Alimentos] (0.001290)
# 107. feature 71 [descricao_mae_escolaridade_Ensino superior incompleto] (0.001193)
# 108. feature 101 [descricao_responsavel_escolaridade_Não estudou] (0.001162)
# 109. feature 56 [descricao_historico_Técnico de Nível Médio em Vestuário] (0.001146)
# 110. feature 34 [descricao_historico_Técnico de Nível Médio em Controle Ambiental] (0.001087)
# 111. feature 51 [descricao_historico_Técnico de Nível Médio em Química] (0.001032)
# 112. feature 33 [descricao_historico_Técnico de Nível Médio em Comércio] (0.000958)
# 113. feature 44 [descricao_historico_Técnico de Nível Médio em Logística] (0.000953)
# 114. feature 52 [descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado] (0.000912)
# 115. feature 139 [sigla_MO] (0.000896)
# 116. feature 59 [descricao_imovel_Cedido ou Emprestado] (0.000805)
# 117. feature 38 [descricao_historico_Técnico de Nível Médio em Eletrônica] (0.000802)
# 118. feature 124 [descricao_trabalho_responsavel_Trabalha com vínculo empregatício] (0.000800)
# 119. feature 82 [descricao_pai_escolaridade_Ensino superior incompleto] (0.000799)
# 120. feature 50 [descricao_historico_Técnico de Nível Médio em Multimídia] (0.000761)
# 121. feature 54 [descricao_historico_Técnico de Nível Médio em Refrigeração e Climatização] (0.000744)
# 122. feature 90 [descricao_raca_Não declarado] (0.000716)
# 123. feature 32 [descricao_historico_Técnico de Nível Médio em Apicultura] (0.000692)
# 124. feature 46 [descricao_historico_Técnico de Nível Médio em Mecatrônica] (0.000663)
# 125. feature 122 [descricao_trabalho_responsavel_Pescador] (0.000543)
# 126. feature 119 [descricao_trabalho_responsavel_Nunca trabalhou] (0.000457)
# 127. feature 110 [descricao_responsavel_financeiro_Outros] (0.000447)
# 128. feature 40 [descricao_historico_Técnico de Nível Médio em Geologia] (0.000429)
# 129. feature 89 [descricao_raca_Indígena] (0.000385)
# 130. feature 26 [descricao_historico_Técnico de Nivel Médio em Biocombustíveis] (0.000375)
# 131. feature 36 [descricao_historico_Técnico de Nível Médio em Eletromecânica] (0.000350)
# 132. feature 105 [descricao_responsavel_financeiro_Cônjuge] (0.000339)
# 133. feature 112 [descricao_responsavel_financeiro_Parentes] (0.000330)
# 134. feature 30 [descricao_historico_Técnico de Nível Médio em Agroecologia] (0.000323)
# 135. feature 43 [descricao_historico_Técnico de Nível Médio em Lazer] (0.000307)
# 136. feature 18 [descricao_companhia_domiciliar_Não informado] (0.000305)
# 137. feature 39 [descricao_historico_Técnico de Nível Médio em Eventos] (0.000176)
# 138. feature 108 [descricao_responsavel_financeiro_Não informado] (0.000169)
# 139. feature 75 [descricao_mae_escolaridade_Pós graduação incompleto] (0.000154)
# 140. feature 103 [descricao_responsavel_escolaridade_Pós graduação incompleto] (0.000148)
# 141. feature 63 [descricao_imovel_Pensionato ou Alojamento] (0.000136)
# 142. feature 23 [descricao_companhia_domiciliar_Sozinho(a)] (0.000095)
# 143. feature 72 [descricao_mae_escolaridade_Não conhece] (0.000048)
# 144. feature 86 [descricao_pai_escolaridade_Pós graduação incompleto] (0.000001)
# 145. feature 11 [descricao_area_residencial_Comunidade Indígena] (0.000000)
# 146. feature 118 [descricao_trabalho_responsavel_Estágio ou bolsa] (0.000000)
# 147. feature 100 [descricao_responsavel_escolaridade_Não conhece] (0.000000)
# 148. feature 12 [descricao_area_residencial_Comunidade Quilombola] (0.000000)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#DECISION TREE
tree_clf = DecisionTreeClassifier() 

param_grid_tree = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_tree = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree)
grid_search_tree.fit(Xtrain, ytrain)
print(grid_search_tree.best_params_)
print(grid_search_tree.best_estimator_)
# Out:
# {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=10, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#seleciona o melhor modelo e exibe os 5 melhores
report(grid_search_tree.cv_results_, 5)

model_tree = grid_search_tree.best_estimator_
ypred_tree = model_tree.predict(Xtest)
# Out:
# Model with rank: 1
# Mean validation score: 0.945 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.945 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.945 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.945 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.945 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.945 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.945 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.945 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.945 (std: 0.005)
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}

# %%
#porcentagem de predicao correta
n_correct = sum(ypred_tree == ytest)    
print(n_correct / len(ypred_tree)) 

#evaluating
mat = confusion_matrix(ytest, ypred_tree)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_tree))
print(recall_score(ytest, ypred_tree))
print(f1_score(ytest, ypred_tree))
# Out:
# 0.943212547323
# 0.954128440367
# 0.985198342214
# 0.969414506263
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#gera a arvore de decisao
export_graphviz(model_tree,
                feature_names=dados_clean.columns,
                filled=True,
                rounded=True, 
                out_file='tree.dot')

os.system('dot -Tpng tree.dot -o tree.png')
# Out:
# -1

# %%
y_probas_tree = cross_val_predict(model_tree, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_tree = y_probas_tree[:, 1]   # score = proba of positive class 
fpr_tree, tpr_tree, thresholds_tree = roc_curve(ytest, y_scores_tree)

plot_roc_curve(fpr_tree, tpr_tree) 
plt.show()
print(roc_auc_score(ytest, y_scores_tree))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.806200044405

# %%
#PLOTAR DUAS CURVAS ROC (DT e RF)
plt.plot(fpr_tree, tpr_tree, "b:", label="DT") 
plot_roc_curve(fpr_forest, tpr_forest, "Random Forest") 
plt.legend(loc="bottom right") 
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:326: UserWarning: Unrecognized location "bottom right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   six.iterkeys(self.codes))))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#REDUÇÃO DE DIMENSIONALIDADE

#pca = PCA(n_components=0.95) 
pca = PCA(n_components=2) 
X_reduced = pca.fit_transform(dados_clean) 

print(pca.explained_variance_ratio_) 
print(X_reduced.shape)

pca = PCA() 
pca.fit(dados_clean) 
cumsum = np.cumsum(pca.explained_variance_ratio_) 
d = np.argmax(cumsum >= 0.95) + 1
plt.plot(cumsum)
# Out:
# [ 0.98009735  0.01989412]
# (7394, 2)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
colors = ['red','blue']
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y, cmap=matplotlib.colors.ListedColormap(colors))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#cria a randomforest  
forest_pca = RandomForestClassifier() 

param_grid_pca = {'max_depth': [3, 5, None],
              'max_features': ['auto', 'sqrt', 'log2'],
              'n_estimators': [10, 30, 60, 100, 200, 500, 1000],              
              'criterion': ["gini", "entropy"]}


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_pca, Xtest_pca, ytrain_pca, ytest_pca = train_test_split(X_reduced, y, random_state=0)

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_pca = GridSearchCV(estimator=forest_pca, param_grid=param_grid_pca, cv = 5)
grid_search_pca.fit(Xtrain_pca, ytrain_pca)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'max_depth': [3, 5, None], 'max_features': ['auto', 'sqrt', 'log2'], 'n_estimators': [10, 30, 60, 100, 200, 500, 1000], 'criterion': ['gini', 'entropy']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
print(grid_search_pca.best_params_)
print(grid_search_pca.best_estimator_)

#exibir melhor modelo
report(grid_search_pca.cv_results_, 5)

#seleciona o melhor modelo
model_pca = grid_search_pca.best_estimator_
ypred_pca = model_pca.predict(Xtest_pca)
# Out:
# {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 10}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# Model with rank: 1
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 10}
#
# Model with rank: 1
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 100}
#
# Model with rank: 1
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 200}
#
# Model with rank: 1
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 1000}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 10}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 60}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 30}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 60}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 200}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 500}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 1000}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 30}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 60}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 100}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 500}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 10}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 60}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 100}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 200}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 500}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 1000}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 30}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 100}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 500}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 1000}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 500}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 1000}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 60}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 500}
#
# Model with rank: 5
# Mean validation score: 0.918 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 1000}

# %%
#Evaluating
mat = confusion_matrix(ytest_pca, ypred_pca)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_pca, ypred_pca))
print(recall_score(ytest_pca, ypred_pca))

#evaluating
print(precision_score(ytest_pca, ypred_pca))
print(recall_score(ytest_pca, ypred_pca))
print(f1_score(ytest_pca, ypred_pca))
# Out:
# 0.913466738778
# 1.0
# 0.913466738778
# 1.0
# 0.954776710006
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#CURVA ROC
y_probas_pca = cross_val_predict(model_pca, Xtest_pca, ytest_pca, cv=3, method="predict_proba") 

y_scores_pca = y_probas_pca[:, 1]   # score = proba of positive class 
fpr_pca, tpr_pca, thresholds_pca = roc_curve(ytest_pca, y_scores_pca)

plot_roc_curve(fpr_pca, tpr_pca) 
plt.show()
print(roc_auc_score(ytest_pca, y_scores_pca))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.546164520426

# %%
#UTILIZANDO APENAS AS NOTAS
dados_reduzido = dados_clean[['LnguaPortuguesaeLiteraturaI90H', 'MatemticaI120H', 
                              'LnguaPortuguesaeLiteraturaII90H', 'MatemticaII90H']]


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_red, Xtest_red, ytrain_red, ytest_red = train_test_split(dados_reduzido, y, random_state=0)

tree_clf = DecisionTreeClassifier() 

param_grid_tree_red = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_red = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree_red)
grid_search_red.fit(Xtrain_red, ytrain_red)
print(grid_search_red.best_params_)
print(grid_search_red.best_estimator_)

#mostra os melhores 5 modelos
report(grid_search_red.cv_results_, 5)

#realiza predicao
model_red = grid_search_red.best_estimator_
ypred_red = model_red.predict(Xtest_red)

#avalia modelo
n_correct = sum(ypred_red == ytest_red)    
print(n_correct / len(ypred_red)) 

#evaluating
mat = confusion_matrix(ytest_red, ypred_red)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_red, ypred_red))
print(recall_score(ytest_red, ypred_red))
print(f1_score(ytest_red, ypred_red))

#curva ROC
y_probas_tree_red = cross_val_predict(model_red, Xtest_red, ytest_red, cv=3, method="predict_proba") 

y_scores_tree_red = y_probas_tree_red[:, 1]   # score = proba of positive class 
fpr_tree_red, tpr_tree_red, thresholds_tree_red = roc_curve(ytest_red, y_scores_tree_red)

fig = plt.figure()

plot_roc_curve(fpr_tree_red, tpr_tree_red) 
plt.show()
print(roc_auc_score(ytest_red, y_scores_tree_red))
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')
# Model with rank: 1
# Mean validation score: 0.931 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.931 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.931 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 3
# Mean validation score: 0.931 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.931 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 3
# Mean validation score: 0.931 (std: 0.004)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# 0.91400757166
# 0.952127659574
# 0.953818827709
# 0.952972493345
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.878078744819

# %%
#PLOTAR DUAS CURVAS ROC (DT e RF)
plt.plot(fpr_tree_red, tpr_tree_red, "b:", label="DT-RED") 
plot_roc_curve(fpr_forest, tpr_forest, "Random Forest") 
plt.legend(loc="bottom right") 
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:326: UserWarning: Unrecognized location "bottom right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   six.iterkeys(self.codes))))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#UTILIZANDO AS MÉDIAS DE CADA ANO

nota_1 = dados_clean[['LnguaPortuguesaeLiteraturaI90H', 'MatemticaI120H']].mean(axis=1)
nota_2 = dados_clean[['LnguaPortuguesaeLiteraturaII90H', 'MatemticaII90H']].mean(axis=1)

dados_reduzido = pd.DataFrame()
dados_reduzido['1_ano'] = nota_1
dados_reduzido['2_ano'] = nota_2


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_red, Xtest_red, ytrain_red, ytest_red = train_test_split(dados_reduzido, y, random_state=0)

tree_clf = DecisionTreeClassifier() 

param_grid_tree_red = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_red = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree_red)
grid_search_red.fit(Xtrain_red, ytrain_red)
print(grid_search_red.best_params_)
print(grid_search_red.best_estimator_)

#mostra os melhores 5 modelos
report(grid_search_red.cv_results_, 5)

#realiza predicao
model_red = grid_search_red.best_estimator_
ypred_red = model_red.predict(Xtest_red)

#avalia modelo
n_correct = sum(ypred_red == ytest_red)    
print(n_correct / len(ypred_red)) 

#evaluating
mat = confusion_matrix(ytest_red, ypred_red)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_red, ypred_red))
print(recall_score(ytest_red, ypred_red))
print(f1_score(ytest_red, ypred_red))

#curva ROC
y_probas_tree_red = cross_val_predict(model_red, Xtest_red, ytest_red, cv=3, method="predict_proba") 

y_scores_tree_red = y_probas_tree_red[:, 1]   # score = proba of positive class 
fpr_tree_red, tpr_tree_red, thresholds_tree_red = roc_curve(ytest_red, y_scores_tree_red)

fig = plt.figure()

plot_roc_curve(fpr_tree_red, tpr_tree_red) 
plt.show()
print(roc_auc_score(ytest_red, y_scores_tree_red))
# Out:
# {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=10, min_impurity_split=1e-07,
#             min_samples_leaf=10, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# Model with rank: 1
# Mean validation score: 0.932 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.932 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.932 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.932 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.932 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.932 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.932 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.932 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.932 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.932 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.932 (std: 0.002)
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# 0.918875067604
# 0.955595026643
# 0.955595026643
# 0.955595026643
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.878282267614

# %%
#SELECIONANDO OS MELHORES ATRIBUTOS PARA TREINAMENTO
#CRITERIO UTILIZADO 80% DA IMPORTANCIA
print("Feature ranking:")

imp_cum = 0

for f in range(Xtest.shape[1]):
    print("%d. feature %d [%s] (%f)" % (f + 1, indices[f], dados_clean.columns[indices[f]],importances[indices[f]]))
    imp_cum = imp_cum + importances[indices[f]]
    print(imp_cum)
# Out:
# Feature ranking:
# 1. feature 0 [LnguaPortuguesaeLiteraturaI90H] (0.144925)
# 0.144924830007
# 2. feature 2 [MatemticaI120H] (0.102099)
# 0.24702401766
# 3. feature 7 [percentual_frequencia] (0.095205)
# 0.342229146512
# 4. feature 1 [LnguaPortuguesaeLiteraturaII90H] (0.047084)
# 0.389313478411
# 5. feature 3 [MatemticaII90H] (0.046896)
# 0.436209408016
# 6. feature 5 [ano_letivo__ano_matricula_periodo] (0.039856)
# 0.476065758479
# 7. feature 6 [cep] (0.038669)
# 0.514734780089
# 8. feature 10 [renda_bruta_familiar] (0.034467)
# 0.549201796284
# 9. feature 8 [pessoa_fisica__nascimento_data] (0.034060)
# 0.583261635116
# 10. feature 4 [ano_letivo__ano] (0.023960)
# 0.607221156359
# 11. feature 9 [qtd_pessoas_domicilio] (0.020996)
# 0.628216688742
# 12. feature 13 [descricao_area_residencial_Não informado] (0.019838)
# 0.648054355421
# 13. feature 15 [descricao_area_residencial_Urbana] (0.010085)
# 0.658139837308
# 14. feature 138 [sigla_MC] (0.009866)
# 0.66800559735
# 15. feature 14 [descricao_area_residencial_Rural] (0.007872)
# 0.675877419437
# 16. feature 127 [pessoa_fisica__sexo_M] (0.007638)
# 0.683515504951
# 17. feature 115 [descricao_trabalho_responsavel_Autônomo] (0.007212)
# 0.690727107504
# 18. feature 117 [descricao_trabalho_responsavel_Empresa privada] (0.006746)
# 0.697472779828
# 19. feature 78 [descricao_pai_escolaridade_Ensino fundamental incompleto] (0.006626)
# 0.704098573042
# 20. feature 28 [descricao_historico_Técnico de Nivel Médio em Informática] (0.006467)
# 0.710565569982
# 21. feature 107 [descricao_responsavel_financeiro_Mãe] (0.006405)
# 0.716970901029
# 22. feature 95 [descricao_responsavel_escolaridade_Ensino fundamental incompleto] (0.006168)
# 0.723138840903
# 23. feature 91 [descricao_raca_Parda] (0.005771)
# 0.728910115546
# 24. feature 111 [descricao_responsavel_financeiro_Pai] (0.005696)
# 0.734605679923
# 25. feature 88 [descricao_raca_Branca] (0.005695)
# 0.740300971359
# 26. feature 21 [descricao_companhia_domiciliar_Pais] (0.005621)
# 0.745921954396
# 27. feature 58 [descricao_imovel_Alugado] (0.005561)
# 0.751483368068
# 28. feature 96 [descricao_responsavel_escolaridade_Ensino médio completo] (0.005439)
# 0.756922674239
# 29. feature 144 [sigla_SC] (0.005428)
# 0.76235081362
# 30. feature 126 [pessoa_fisica__sexo_F] (0.005372)
# 0.767723208884
# 31. feature 64 [descricao_imovel_Próprio] (0.005328)
# 0.773050912759
# 32. feature 79 [descricao_pai_escolaridade_Ensino médio completo] (0.005315)
# 0.778366185335
# 33. feature 123 [descricao_trabalho_responsavel_Serviço público] (0.005226)
# 0.78359168814
# 34. feature 129 [sigla_CA] (0.005043)
# 0.788634717068
# 35. feature 68 [descricao_mae_escolaridade_Ensino médio completo] (0.004840)
# 0.793475057201
# 36. feature 17 [descricao_companhia_domiciliar_Mãe] (0.004730)
# 0.798205153826
# 37. feature 92 [descricao_raca_Preta] (0.004635)
# 0.80284055804
# 38. feature 57 [descricao_historico_Técnico em Programação de Jogos Digitais] (0.004543)
# 0.807383336058
# 39. feature 67 [descricao_mae_escolaridade_Ensino fundamental incompleto] (0.004447)
# 0.811830023966
# 40. feature 134 [sigla_CNAT] (0.004310)
# 0.816139657399
# 41. feature 53 [descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros] (0.004153)
# 0.820292589104
# 42. feature 35 [descricao_historico_Técnico de Nível Médio em Edificações] (0.003964)
# 0.824256556682
# 43. feature 121 [descricao_trabalho_responsavel_Não informado] (0.003950)
# 0.828206612942
# 44. feature 70 [descricao_mae_escolaridade_Ensino superior completo] (0.003787)
# 0.831993788284
# 45. feature 29 [descricao_historico_Técnico de Nível Médio em Administração] (0.003623)
# 0.835616708495
# 46. feature 137 [sigla_LAJ] (0.003611)
# 0.839228087001
# 47. feature 76 [descricao_pai_escolaridade_Alfabetizado] (0.003457)
# 0.842685104334
# 48. feature 81 [descricao_pai_escolaridade_Ensino superior completo] (0.003274)
# 0.845959080069
# 49. feature 22 [descricao_companhia_domiciliar_Parente(s) ou amigo(s)] (0.003240)
# 0.849198983455
# 50. feature 120 [descricao_trabalho_responsavel_Não está trabalhando] (0.003240)
# 0.852438585461
# 51. feature 77 [descricao_pai_escolaridade_Ensino fundamental completo] (0.003188)
# 0.855626741029
# 52. feature 97 [descricao_responsavel_escolaridade_Ensino médio incompleto] (0.003106)
# 0.858732425964
# 53. feature 41 [descricao_historico_Técnico de Nível Médio em Informática] (0.003103)
# 0.861835008094
# 54. feature 66 [descricao_mae_escolaridade_Ensino fundamental completo] (0.003017)
# 0.864852403478
# 55. feature 140 [sigla_NC] (0.002978)
# 0.867830809714
# 56. feature 37 [descricao_historico_Técnico de Nível Médio em Eletrotécnica] (0.002935)
# 0.870765997382
# 57. feature 114 [descricao_trabalho_responsavel_Aposentado] (0.002921)
# 0.873687295629
# 58. feature 69 [descricao_mae_escolaridade_Ensino médio incompleto] (0.002853)
# 0.876539939532
# 59. feature 98 [descricao_responsavel_escolaridade_Ensino superior completo] (0.002823)
# 0.879363360457
# 60. feature 102 [descricao_responsavel_escolaridade_Pós graduação completo] (0.002742)
# 0.882105381076
# 61. feature 42 [descricao_historico_Técnico de Nível Médio em Informática para Internet] (0.002739)
# 0.884844025927
# 62. feature 48 [descricao_historico_Técnico de Nível Médio em Meio Ambiente] (0.002717)
# 0.887560710416
# 63. feature 125 [descricao_trabalho_responsavel_Trabalhador rural/Agricultor] (0.002702)
# 0.890262942615
# 64. feature 74 [descricao_mae_escolaridade_Pós graduação completo] (0.002679)
# 0.892941592646
# 65. feature 146 [sigla_SPP] (0.002644)
# 0.895585390698
# 66. feature 19 [descricao_companhia_domiciliar_Outros] (0.002562)
# 0.898147588879
# 67. feature 132 [sigla_CM] (0.002541)
# 0.900688677828
# 68. feature 141 [sigla_PAAS] (0.002484)
# 0.903172682677
# 69. feature 20 [descricao_companhia_domiciliar_Pai] (0.002480)
# 0.905652719952
# 70. feature 24 [descricao_historico_Técnico de Nivel Médio Informática] (0.002438)
# 0.908091074225
# 71. feature 47 [descricao_historico_Técnico de Nível Médio em Mecânica] (0.002434)
# 0.910524721228
# 72. feature 61 [descricao_imovel_Não informado] (0.002376)
# 0.912900349825
# 73. feature 85 [descricao_pai_escolaridade_Pós graduação completo] (0.002372)
# 0.915272287027
# 74. feature 99 [descricao_responsavel_escolaridade_Ensino superior incompleto] (0.002367)
# 0.917639773443
# 75. feature 93 [descricao_responsavel_escolaridade_Alfabetizado] (0.002345)
# 0.919985218424
# 76. feature 143 [sigla_PF] (0.002318)
# 0.922303644408
# 77. feature 128 [sigla_AP] (0.002250)
# 0.924554010428
# 78. feature 130 [sigla_CAL] (0.002235)
# 0.926789249078
# 79. feature 104 [descricao_responsavel_financeiro_Avô(ó)] (0.002190)
# 0.928979500928
# 80. feature 113 [descricao_responsavel_financeiro_Tio(a)] (0.002125)
# 0.931104084399
# 81. feature 65 [descricao_mae_escolaridade_Alfabetizado] (0.002121)
# 0.93322494783
# 82. feature 109 [descricao_responsavel_financeiro_O próprio aluno] (0.002118)
# 0.935342976373
# 83. feature 84 [descricao_pai_escolaridade_Não estudou] (0.002115)
# 0.937458148291
# 84. feature 60 [descricao_imovel_Financiado] (0.002110)
# 0.939567780457
# 85. feature 135 [sigla_IP] (0.002067)
# 0.941634931643
# 86. feature 55 [descricao_historico_Técnico de Nível Médio em Têxtil] (0.002052)
# 0.943687101282
# 87. feature 145 [sigla_SGA] (0.002026)
# 0.945713243386
# 88. feature 49 [descricao_historico_Técnico de Nível Médio em Mineração] (0.002012)
# 0.947725165912
# 89. feature 83 [descricao_pai_escolaridade_Não conhece] (0.002000)
# 0.949725629284
# 90. feature 142 [sigla_PAR] (0.001982)
# 0.951707681074
# 91. feature 94 [descricao_responsavel_escolaridade_Ensino fundamental completo] (0.001966)
# 0.953673802501
# 92. feature 147 [sigla_ZN] (0.001946)
# 0.955620127332
# 93. feature 80 [descricao_pai_escolaridade_Ensino médio incompleto] (0.001920)
# 0.957540023121
# 94. feature 45 [descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática] (0.001860)
# 0.959399565781
# 95. feature 16 [descricao_companhia_domiciliar_Cônjuge] (0.001807)
# 0.96120706154
# 96. feature 62 [descricao_imovel_Outro] (0.001787)
# 0.962994302003
# 97. feature 87 [descricao_raca_Amarela] (0.001786)
# 0.964780396083
# 98. feature 136 [sigla_JC] (0.001780)
# 0.966560821005
# 99. feature 131 [sigla_CANG] (0.001760)
# 0.968320669807
# 100. feature 133 [sigla_CN] (0.001699)
# 0.970019643529
# 101. feature 73 [descricao_mae_escolaridade_Não estudou] (0.001670)
# 0.971690103871
# 102. feature 106 [descricao_responsavel_financeiro_Irmão(ã)] (0.001425)
# 0.973115494189
# 103. feature 27 [descricao_historico_Técnico de Nivel Médio em Equipamentos Biomédicos] (0.001332)
# 0.974447845686
# 104. feature 116 [descricao_trabalho_responsavel_Beneficiário ou Pensionista do INSS] (0.001316)
# 0.97576424136
# 105. feature 25 [descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada] (0.001307)
# 0.977071652434
# 106. feature 31 [descricao_historico_Técnico de Nível Médio em Alimentos] (0.001290)
# 0.978361527531
# 107. feature 71 [descricao_mae_escolaridade_Ensino superior incompleto] (0.001193)
# 0.979554276428
# 108. feature 101 [descricao_responsavel_escolaridade_Não estudou] (0.001162)
# 0.980716515494
# 109. feature 56 [descricao_historico_Técnico de Nível Médio em Vestuário] (0.001146)
# 0.981862566361
# 110. feature 34 [descricao_historico_Técnico de Nível Médio em Controle Ambiental] (0.001087)
# 0.982949569357
# 111. feature 51 [descricao_historico_Técnico de Nível Médio em Química] (0.001032)
# 0.983981852214
# 112. feature 33 [descricao_historico_Técnico de Nível Médio em Comércio] (0.000958)
# 0.984940303232
# 113. feature 44 [descricao_historico_Técnico de Nível Médio em Logística] (0.000953)
# 0.985893473978
# 114. feature 52 [descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado] (0.000912)
# 0.986805630883
# 115. feature 139 [sigla_MO] (0.000896)
# 0.987701769636
# 116. feature 59 [descricao_imovel_Cedido ou Emprestado] (0.000805)
# 0.98850713595
# 117. feature 38 [descricao_historico_Técnico de Nível Médio em Eletrônica] (0.000802)
# 0.989309167486
# 118. feature 124 [descricao_trabalho_responsavel_Trabalha com vínculo empregatício] (0.000800)
# 0.990108782903
# 119. feature 82 [descricao_pai_escolaridade_Ensino superior incompleto] (0.000799)
# 0.990907637984
# 120. feature 50 [descricao_historico_Técnico de Nível Médio em Multimídia] (0.000761)
# 0.99166875186
# 121. feature 54 [descricao_historico_Técnico de Nível Médio em Refrigeração e Climatização] (0.000744)
# 0.992412932721
# 122. feature 90 [descricao_raca_Não declarado] (0.000716)
# 0.993128440678
# 123. feature 32 [descricao_historico_Técnico de Nível Médio em Apicultura] (0.000692)
# 0.993820345123
# 124. feature 46 [descricao_historico_Técnico de Nível Médio em Mecatrônica] (0.000663)
# 0.994483757914
# 125. feature 122 [descricao_trabalho_responsavel_Pescador] (0.000543)
# 0.995026456697
# 126. feature 119 [descricao_trabalho_responsavel_Nunca trabalhou] (0.000457)
# 0.995483847936
# 127. feature 110 [descricao_responsavel_financeiro_Outros] (0.000447)
# 0.995930499224
# 128. feature 40 [descricao_historico_Técnico de Nível Médio em Geologia] (0.000429)
# 0.996359414988
# 129. feature 89 [descricao_raca_Indígena] (0.000385)
# 0.996744321208
# 130. feature 26 [descricao_historico_Técnico de Nivel Médio em Biocombustíveis] (0.000375)
# 0.9971197379
# 131. feature 36 [descricao_historico_Técnico de Nível Médio em Eletromecânica] (0.000350)
# 0.997470137999
# 132. feature 105 [descricao_responsavel_financeiro_Cônjuge] (0.000339)
# 0.99780952731
# 133. feature 112 [descricao_responsavel_financeiro_Parentes] (0.000330)
# 0.998139059164
# 134. feature 30 [descricao_historico_Técnico de Nível Médio em Agroecologia] (0.000323)
# 0.998462133836
# 135. feature 43 [descricao_historico_Técnico de Nível Médio em Lazer] (0.000307)
# 0.998769103941
# 136. feature 18 [descricao_companhia_domiciliar_Não informado] (0.000305)
# 0.999074477439
# 137. feature 39 [descricao_historico_Técnico de Nível Médio em Eventos] (0.000176)
# 0.999250177835
# 138. feature 108 [descricao_responsavel_financeiro_Não informado] (0.000169)
# 0.999419466234
# 139. feature 75 [descricao_mae_escolaridade_Pós graduação incompleto] (0.000154)
# 0.999573034746
# 140. feature 103 [descricao_responsavel_escolaridade_Pós graduação incompleto] (0.000148)
# 0.999720591503
# 141. feature 63 [descricao_imovel_Pensionato ou Alojamento] (0.000136)
# 0.999856214644
# 142. feature 23 [descricao_companhia_domiciliar_Sozinho(a)] (0.000095)
# 0.999951237719
# 143. feature 72 [descricao_mae_escolaridade_Não conhece] (0.000048)
# 0.999999370131
# 144. feature 86 [descricao_pai_escolaridade_Pós graduação incompleto] (0.000001)
# 1.0
# 145. feature 11 [descricao_area_residencial_Comunidade Indígena] (0.000000)
# 1.0
# 146. feature 118 [descricao_trabalho_responsavel_Estágio ou bolsa] (0.000000)
# 1.0
# 147. feature 100 [descricao_responsavel_escolaridade_Não conhece] (0.000000)
# 1.0
# 148. feature 12 [descricao_area_residencial_Comunidade Quilombola] (0.000000)
# 1.0

# %%
dados_reduzido = dados_clean[['LnguaPortuguesaeLiteraturaI90H', 'MatemticaI120H', 
                              'LnguaPortuguesaeLiteraturaII90H', 'MatemticaII90H', 
                              'percentual_frequencia', 
                              'ano_letivo__ano_matricula_periodo', 
                              #'pessoa_fisica__nascimento_data', 
                              'cep', 
                              #'renda_bruta_familiar', 
                              #'qtd_pessoas_domicilio'
                             ]]


#dividir os dados para treino e teste. default é 25% p teste
Xtrain_red, Xtest_red, ytrain_red, ytest_red = train_test_split(dados_reduzido, y, random_state=0)

tree_clf = DecisionTreeClassifier() 

param_grid_tree_red = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_red = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree_red)
grid_search_red.fit(Xtrain_red, ytrain_red)
print(grid_search_red.best_params_)
print(grid_search_red.best_estimator_)

#mostra os melhores 5 modelos
report(grid_search_red.cv_results_, 5)

#realiza predicao
model_red = grid_search_red.best_estimator_
ypred_red = model_red.predict(Xtest_red)

#avalia modelo
n_correct = sum(ypred_red == ytest_red)    
print(n_correct / len(ypred_red)) 

#evaluating
mat = confusion_matrix(ytest_red, ypred_red)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest_red, ypred_red))
print(recall_score(ytest_red, ypred_red))
print(f1_score(ytest_red, ypred_red))

#curva ROC
y_probas_tree_red = cross_val_predict(model_red, Xtest_red, ytest_red, cv=3, method="predict_proba") 

y_scores_tree_red = y_probas_tree_red[:, 1]   # score = proba of positive class 
fpr_tree_red, tpr_tree_red, thresholds_tree_red = roc_curve(ytest_red, y_scores_tree_red)

fig = plt.figure()

plot_roc_curve(fpr_tree_red, tpr_tree_red) 
plt.show()
print(roc_auc_score(ytest_red, y_scores_tree_red))
# Out:
# {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=20, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# Model with rank: 1
# Mean validation score: 0.947 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.947 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.947 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.947 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.947 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.947 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.947 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.947 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.947 (std: 0.005)
# Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
#
# 0.944294213088
# 0.973150357995
# 0.965660153937
# 0.969390787519
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.902673549438

# %%
#gera a arvore de decisao
export_graphviz(model_red,
                feature_names=dados_reduzido.columns,
                filled=True,
                rounded=True, 
                out_file='tree_red.dot')

os.system('dot -Tpng tree_red.dot -o tree_red.png')
# Out:
# 0
