# %% [markdown]
# # Análise de alunos do integrado do IFRN
# a base de dados consiste em dados socioeconômicos e as notas finais de português e matemática do 1º e 2º ano. Essas disciplinas foram selecionadas devido a certeza delas estarem presente em todos os cursos de integrado ofertados no IFRN

# %%
#import os pacotes utilizados
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

#ESCALONAMENTO DE DADOS
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler

#SELECIONANDO MELHOR MODELO
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from scipy.stats import randint as sp_randint
from sklearn.cross_validation import train_test_split

#Evaluating
import seaborn as sns; sns.set()

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import precision_score, recall_score 
from sklearn.metrics import f1_score

#EXPORTAR ARVORE
from sklearn.tree import export_graphviz
import os

#CURVA ROC
# %matplotlib inline
from sklearn.metrics import roc_curve
from sklearn.model_selection import cross_val_predict 
from sklearn.metrics import roc_auc_score

#REDUÇÃO DE DIMENSIONALIDADE
from sklearn.decomposition import PCA

#exibindo todas as colunas
pd.set_option('display.max_columns', None)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#definicao de funcoes que serao utilizadas

# Utility function to report best scores
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")
            
def plot_roc_curve(fpr, tpr, label=None):    
    plt.plot(fpr, tpr, linewidth=2, label=label)    
    plt.plot([0, 1], [0, 1], 'k--')    
    plt.axis([0, 1, 0, 1])   
    plt.xlabel('False Positive Rate')    
    plt.ylabel('True Positive Rate')

# %%
#importando base já tratada
dados = pd.read_json('dados/dados_filtrado_CA.json')
print(dados.id.nunique())
print(dados.shape)
dados.head(3)
# Out:
# 7201
# (7201, 27)
#        LnguaPortuguesaeLiteraturaI90H  LnguaPortuguesaeLiteraturaII90H  \
# 34217                              68                             68.0
# 34218                              73                             21.0
# 34219                              70                             80.0
#
#        MatemticaI120H  MatemticaII90H        cep  classe    descricao  \
# 34217              66            79.0  59535-000       1  Matriculado
# 34218              23             7.0  59460-000       0    Cancelado
# 34219              61            73.0  59810-000       1  Matriculado
#
#       descricao_area_residencial descricao_companhia_domiciliar  \
# 34217                     Urbana                            Mãe
# 34218                     Urbana                            Mãe
# 34219                     Urbana                           Pais
#
#                            descricao_historico descricao_imovel  \
# 34217    Técnico de Nivel Médio em Informática          Alugado
# 34218  Técnico de Nível Médio em Meio Ambiente          Alugado
# 34219     Técnico de Nível Médio em Apicultura          Alugado
#
#           descricao_mae_escolaridade     descricao_pai_escolaridade  \
# 34217  Ensino fundamental incompleto  Ensino fundamental incompleto
# 34218  Ensino fundamental incompleto  Ensino fundamental incompleto
# 34219          Ensino médio completo  Ensino fundamental incompleto
#
#       descricao_raca descricao_responsavel_escolaridade  \
# 34217         Branca      Ensino fundamental incompleto
# 34218          Parda      Ensino fundamental incompleto
# 34219          Parda      Ensino fundamental incompleto
#
#       descricao_responsavel_financeiro descricao_situacao_matricula_periodo  \
# 34217                              Mãe                          Dependência
# 34218                              Mãe                          Dependência
# 34219                              Pai                          Dependência
#
#       descricao_trabalho_responsavel            id  \
# 34217                  Não informado  457884597605
# 34218                  Não informado  458436647741
# 34219                       Autônomo  452768375385
#
#            nome_escola_ensino_fundamental  percentual_frequencia  \
# 34217  ESCOLA MUNICIPAL DR. ELOY DE SOUZA                  100.0
# 34218                                                       91.0
# 34219                                                       98.0
#
#       pessoa_fisica__nascimento_data pessoa_fisica__sexo  qnt_salario  \
# 34217                     22/10/1999                   F            0
# 34218                     04/10/1997                   M            0
# 34219                     05/07/1999                   F            1
#
#        qtd_pessoas_domicilio  renda_bruta_familiar sigla
# 34217                      2                 300.0   LAJ
# 34218                      2                   0.0   SPP
# 34219                      6                 720.0    PF

# %%
df = dados



dados = dados[
                [
                'cep', 'classe', 'descricao_area_residencial', 
                'descricao_companhia_domiciliar', 'descricao_historico', 'descricao_imovel', 
                'descricao_mae_escolaridade', 'descricao_pai_escolaridade', 
                'descricao_raca', 'descricao_responsavel_escolaridade', 
                'descricao_responsavel_financeiro', 'descricao_trabalho_responsavel', 
                'pessoa_fisica__nascimento_data', 'pessoa_fisica__sexo', 
                'qnt_salario', 'qtd_pessoas_domicilio', 'sigla'
                ]
]

dados
# Out:
#               cep  classe descricao_area_residencial  \
# 34217   59535-000       1                     Urbana
# 34218   59460-000       0                     Urbana
# 34219   59810-000       1                     Urbana
# 34220   59611-070       1                     Urbana
# 34221   59190-000       1                     Urbana
# 34222   59258-000       1                     Urbana
# 34223   59080-050       1                     Urbana
# 34224   59104-260       1                     Urbana
# 34225   59520-000       1                     Urbana
# 34227   59032-130       1                     Urbana
# 34228   59075-225       1                     Urbana
# 34229   59600-610       1                     Urbana
# 34230   59508-000       1              Não informado
# 34231   59905-000       0              Não informado
# 34232   59607-225       1              Não informado
# 34234   59570-000       0              Não informado
# 34235   59570-000       1              Não informado
# 34236   59650-000       1              Não informado
# 34237   59598-000       1              Não informado
# 34238   59375-000       1              Não informado
# 34240   59068-220       0              Não informado
# 34241   59370-000       1              Não informado
# 34246   59970-000       1              Não informado
# 34247   59500-000       1              Não informado
# 34249   59300-000       0              Não informado
# 34250   59143-215       1              Não informado
# 34251   59110-290       1              Não informado
# 34253   59570-000       1              Não informado
# 34255   59300-000       1              Não informado
# 34256   59586-000       1              Não informado
# ...           ...     ...                        ...
# 43495   59380-000       1                     Urbana
# 43502   59110-550       1                     Urbana
# 43510                   0              Não informado
# 43513                   0              Não informado
# 43514    59517000       0              Não informado
# 43515   59410-000       0                      Rural
# 43518   59270-000       0                     Urbana
# 43519   59214-000       0                      Rural
# 43521                   0                     Urbana
# 43582   59700-000       1                     Urbana
# 43611   59090-615       1                     Urbana
# 43612   59343-000       0              Não informado
# 43613   59535-000       0              Não informado
# 43614   59535-000       0              Não informado
# 43615   59530-000       0              Não informado
# 43616   59856-000       0                     Urbana
# 43617   59535-000       0                     Urbana
# 43619   59910-000       0                      Rural
# 43620   59370-000       0                     Urbana
# 43622   59374-000       0                     Urbana
# 43623   59600-000       0                     Urbana
# 43624   59780-000       0                     Urbana
# 43625   59810-000       0                      Rural
# 43626   59343-000       0                      Rural
# 43627   59560-000       0                      Rural
# 43628   59800-000       0                      Rural
# 43629   59598-000       0                      Rural
# 43631   59680-000       0                      Rural
# 43632   59064-680       0                     Urbana
# 43634  60.356-090       1                     Urbana
#
#       descricao_companhia_domiciliar  \
# 34217                            Mãe
# 34218                            Mãe
# 34219                           Pais
# 34220                            Mãe
# 34221                           Pais
# 34222                            Mãe
# 34223                           Pais
# 34224                            Mãe
# 34225                            Mãe
# 34227                            Mãe
# 34228                           Pais
# 34229                            Mãe
# 34230                            Mãe
# 34231                           Pais
# 34232                           Pais
# 34234                            Mãe
# 34235                           Pais
# 34236                           Pais
# 34237                            Mãe
# 34238                            Mãe
# 34240                            Mãe
# 34241                           Pais
# 34246                           Pais
# 34247                           Pais
# 34249                           Pais
# 34250                           Pais
# 34251                           Pais
# 34253                           Pais
# 34255                           Pais
# 34256                           Pais
# ...                              ...
# 43495                           Pais
# 43502                            Mãe
# 43510                           Pais
# 43513                           Pais
# 43514                        Cônjuge
# 43515                           Pais
# 43518                         Outros
# 43519                           Pais
# 43521                           Pais
# 43582                           Pais
# 43611                            Mãe
# 43612                            Mãe
# 43613                           Pais
# 43614                           Pais
# 43615                           Pais
# 43616         Parente(s) ou amigo(s)
# 43617                            Mãe
# 43619                           Pais
# 43620                           Pais
# 43622                           Pais
# 43623                           Pais
# 43624                           Pais
# 43625                            Mãe
# 43626                           Pais
# 43627                           Pais
# 43628                           Pais
# 43629                            Mãe
# 43631                         Outros
# 43632                            Mãe
# 43634         Parente(s) ou amigo(s)
#
#                                      descricao_historico  \
# 34217              Técnico de Nivel Médio em Informática
# 34218            Técnico de Nível Médio em Meio Ambiente
# 34219               Técnico de Nível Médio em Apicultura
# 34220                 Técnico de Nível Médio em Mecânica
# 34221              Técnico de Nivel Médio em Informática
# 34222            Técnico de Nível Médio em Administração
# 34223                 Técnico de Nível Médio em Geologia
# 34224       Técnico de Nível Médio em Controle Ambiental
# 34225             Técnico de Nível Médio em Agroecologia
# 34227                 Técnico de Nivel Médio Informática
# 34228                 Técnico de Nível Médio em Geologia
# 34229            Técnico de Nível Médio em Eletrotécnica
# 34230            Técnico de Nível Médio em Meio Ambiente
# 34231               Técnico de Nível Médio em Apicultura
# 34232                 Técnico de Nível Médio em Mecânica
# 34234           Técnico em Programação de Jogos Digitais
# 34235           Técnico em Programação de Jogos Digitais
# 34236              Técnico de Nivel Médio em Informática
# 34237                  Técnico de Nível Médio em Química
# 34238              Técnico de Nível Médio em Informática
# 34240                 Técnico de Nivel Médio Informática
# 34241  Técnico de Nível Médio em Manutenção e Suporte...
# 34246                Técnico de Nível Médio em Alimentos
# 34247                  Técnico de Nível Médio em Química
# 34249            Técnico de Nível Médio em Eletrotécnica
# 34250              Técnico de Nível Médio em Mecatrônica
# 34251                 Técnico de Nível Médio em Comércio
# 34253              Técnico de Nivel Médio em Informática
# 34255                Técnico de Nível Médio em Vestuário
# 34256              Técnico de Nivel Médio em Informática
# ...                                                  ...
# 43495                Técnico de Nível Médio em Alimentos
# 43502       Técnico de Nível Médio em Controle Ambiental
# 43510            Técnico de Nível Médio em Administração
# 43513            Técnico de Nível Médio em Administração
# 43514              Técnico de Nivel Médio em Informática
# 43515              Técnico de Nível Médio em Edificações
# 43518              Técnico de Nível Médio em Edificações
# 43519  Técnico de Nível Médio em Química, na Forma In...
# 43521                 Técnico de Nível Médio em Mecânica
# 43582  Técnico de Nivel Médio em Agropecuária, na For...
# 43611            Técnico de Nível Médio em Administração
# 43612                Técnico de Nível Médio em Mineração
# 43613              Técnico de Nivel Médio em Informática
# 43614            Técnico de Nível Médio em Administração
# 43615            Técnico de Nível Médio em Administração
# 43616  Técnico de Nivel Médio em Agropecuária, na For...
# 43617              Técnico de Nivel Médio em Informática
# 43619                 Técnico de Nivel Médio Informática
# 43620                Técnico de Nível Médio em Mineração
# 43622                Técnico de Nível Médio em Mineração
# 43623              Técnico de Nível Médio em Edificações
# 43624  Técnico de Nivel Médio em Agropecuária, na For...
# 43625                Técnico de Nível Médio em Alimentos
# 43626              Técnico de Nivel Médio em Informática
# 43627  Técnico de Nivel Médio em Equipamentos Biomédicos
# 43628                Técnico de Nível Médio em Alimentos
# 43629              Técnico de Nivel Médio em Informática
# 43631          Técnico de Nivel Médio em Biocombustíveis
# 43632                  Técnico de Nível Médio em Eventos
# 43634               Técnico de Nível Médio em Eletrônica
#
#            descricao_imovel     descricao_mae_escolaridade  \
# 34217               Alugado  Ensino fundamental incompleto
# 34218               Alugado  Ensino fundamental incompleto
# 34219               Alugado          Ensino médio completo
# 34220               Alugado          Ensino médio completo
# 34221               Alugado          Ensino médio completo
# 34222               Alugado          Ensino médio completo
# 34223               Alugado          Ensino médio completo
# 34224               Alugado                    Não estudou
# 34225               Alugado        Ensino médio incompleto
# 34227               Alugado          Ensino médio completo
# 34228               Alugado    Ensino fundamental completo
# 34229               Alugado       Pós graduação incompleto
# 34230               Alugado  Ensino fundamental incompleto
# 34231               Alugado  Ensino fundamental incompleto
# 34232               Alugado  Ensino fundamental incompleto
# 34234               Alugado  Ensino fundamental incompleto
# 34235               Alugado       Pós graduação incompleto
# 34236               Alugado    Ensino fundamental completo
# 34237               Alugado    Ensino fundamental completo
# 34238               Alugado         Pós graduação completo
# 34240               Alugado         Pós graduação completo
# 34241               Alugado         Pós graduação completo
# 34246               Alugado          Ensino médio completo
# 34247               Alugado          Ensino médio completo
# 34249               Alugado        Ensino médio incompleto
# 34250               Alugado     Ensino superior incompleto
# 34251               Alugado     Ensino superior incompleto
# 34253               Alugado          Ensino médio completo
# 34255               Alugado          Ensino médio completo
# 34256               Alugado    Ensino fundamental completo
# ...                     ...                            ...
# 43495               Próprio  Ensino fundamental incompleto
# 43502               Próprio     Ensino superior incompleto
# 43510               Próprio  Ensino fundamental incompleto
# 43513               Próprio    Ensino fundamental completo
# 43514         Não informado          Ensino médio completo
# 43515               Próprio                   Alfabetizado
# 43518               Próprio  Ensino fundamental incompleto
# 43519               Próprio         Pós graduação completo
# 43521                 Outro  Ensino fundamental incompleto
# 43582               Próprio         Pós graduação completo
# 43611  Cedido ou Emprestado          Ensino médio completo
# 43612               Próprio  Ensino fundamental incompleto
# 43613               Próprio          Ensino médio completo
# 43614               Próprio  Ensino fundamental incompleto
# 43615               Próprio  Ensino fundamental incompleto
# 43616               Próprio       Ensino superior completo
# 43617               Próprio    Ensino fundamental completo
# 43619               Próprio       Ensino superior completo
# 43620               Alugado          Ensino médio completo
# 43622               Próprio  Ensino fundamental incompleto
# 43623               Próprio        Ensino médio incompleto
# 43624               Próprio                    Não estudou
# 43625               Próprio  Ensino fundamental incompleto
# 43626               Próprio    Ensino fundamental completo
# 43627               Próprio          Ensino médio completo
# 43628               Próprio  Ensino fundamental incompleto
# 43629               Próprio        Ensino médio incompleto
# 43631               Próprio  Ensino fundamental incompleto
# 43632            Financiado          Ensino médio completo
# 43634               Próprio       Ensino superior completo
#
#           descricao_pai_escolaridade descricao_raca  \
# 34217  Ensino fundamental incompleto         Branca
# 34218  Ensino fundamental incompleto          Parda
# 34219  Ensino fundamental incompleto          Parda
# 34220  Ensino fundamental incompleto          Parda
# 34221          Ensino médio completo          Parda
# 34222          Ensino médio completo         Branca
# 34223          Ensino médio completo          Parda
# 34224          Ensino médio completo          Preta
# 34225        Ensino médio incompleto          Parda
# 34227        Ensino médio incompleto          Parda
# 34228    Ensino fundamental completo          Preta
# 34229     Ensino superior incompleto         Branca
# 34230  Ensino fundamental incompleto         Branca
# 34231  Ensino fundamental incompleto         Branca
# 34232  Ensino fundamental incompleto          Parda
# 34234          Ensino médio completo          Parda
# 34235  Ensino fundamental incompleto          Parda
# 34236  Ensino fundamental incompleto          Parda
# 34237                    Não estudou          Preta
# 34238         Pós graduação completo         Branca
# 34240         Pós graduação completo         Branca
# 34241                   Alfabetizado          Parda
# 34246                   Alfabetizado          Parda
# 34247          Ensino médio completo         Branca
# 34249          Ensino médio completo         Branca
# 34250          Ensino médio completo         Branca
# 34251          Ensino médio completo         Branca
# 34253    Ensino fundamental completo         Branca
# 34255          Ensino médio completo          Parda
# 34256          Ensino médio completo          Parda
# ...                              ...            ...
# 43495                    Não estudou         Branca
# 43502          Ensino médio completo          Parda
# 43510  Ensino fundamental incompleto          Preta
# 43513    Ensino fundamental completo          Parda
# 43514  Ensino fundamental incompleto         Branca
# 43515  Ensino fundamental incompleto         Branca
# 43518  Ensino fundamental incompleto          Parda
# 43519  Ensino fundamental incompleto          Parda
# 43521  Ensino fundamental incompleto          Parda
# 43582         Pós graduação completo         Branca
# 43611          Ensino médio completo          Parda
# 43612                    Não estudou          Parda
# 43613  Ensino fundamental incompleto          Parda
# 43614  Ensino fundamental incompleto          Parda
# 43615  Ensino fundamental incompleto          Parda
# 43616        Ensino médio incompleto         Branca
# 43617        Ensino médio incompleto         Branca
# 43619  Ensino fundamental incompleto         Branca
# 43620          Ensino médio completo          Parda
# 43622          Ensino médio completo         Branca
# 43623  Ensino fundamental incompleto         Branca
# 43624                    Não estudou          Parda
# 43625  Ensino fundamental incompleto          Preta
# 43626  Ensino fundamental incompleto         Branca
# 43627  Ensino fundamental incompleto          Parda
# 43628          Ensino médio completo          Parda
# 43629  Ensino fundamental incompleto          Parda
# 43631                   Alfabetizado          Preta
# 43632       Ensino superior completo         Branca
# 43634     Ensino superior incompleto         Branca
#
#       descricao_responsavel_escolaridade descricao_responsavel_financeiro  \
# 34217      Ensino fundamental incompleto                              Mãe
# 34218      Ensino fundamental incompleto                              Mãe
# 34219      Ensino fundamental incompleto                              Pai
# 34220              Ensino médio completo                              Mãe
# 34221              Ensino médio completo                              Mãe
# 34222              Ensino médio completo                              Mãe
# 34223              Ensino médio completo                              Pai
# 34224              Ensino médio completo                              Pai
# 34225            Ensino médio incompleto                              Mãe
# 34227            Ensino médio incompleto                              Pai
# 34228        Ensino fundamental completo                              Pai
# 34229         Ensino superior incompleto                              Pai
# 34230      Ensino fundamental incompleto                              Mãe
# 34231      Ensino fundamental incompleto                              Mãe
# 34232      Ensino fundamental incompleto                              Mãe
# 34234      Ensino fundamental incompleto                              Mãe
# 34235      Ensino fundamental incompleto                              Pai
# 34236      Ensino fundamental incompleto                           Avô(ó)
# 34237      Ensino fundamental incompleto                           Outros
# 34238             Pós graduação completo                              Mãe
# 34240             Pós graduação completo                              Mãe
# 34241             Pós graduação completo                              Mãe
# 34246              Ensino médio completo                              Mãe
# 34247              Ensino médio completo                              Pai
# 34249              Ensino médio completo                              Pai
# 34250              Ensino médio completo                              Pai
# 34251              Ensino médio completo                              Pai
# 34253              Ensino médio completo                              Pai
# 34255              Ensino médio completo                              Pai
# 34256              Ensino médio completo                              Pai
# ...                                  ...                              ...
# 43495                        Não estudou                              Pai
# 43502              Ensino médio completo                              Mãe
# 43510      Ensino fundamental incompleto                              Mãe
# 43513        Ensino fundamental completo                              Pai
# 43514              Ensino médio completo                  O próprio aluno
# 43515      Ensino fundamental incompleto                              Mãe
# 43518      Ensino fundamental incompleto                           Avô(ó)
# 43519      Ensino fundamental incompleto                              Pai
# 43521      Ensino fundamental incompleto                              Pai
# 43582             Pós graduação completo                              Mãe
# 43611              Ensino médio completo                              Pai
# 43612      Ensino fundamental incompleto                              Mãe
# 43613      Ensino fundamental incompleto                              Pai
# 43614      Ensino fundamental incompleto                              Pai
# 43615      Ensino fundamental incompleto                              Pai
# 43616           Ensino superior completo                              Mãe
# 43617        Ensino fundamental completo                              Mãe
# 43619           Ensino superior completo                              Mãe
# 43620                       Alfabetizado                           Outros
# 43622              Ensino médio completo                              Pai
# 43623            Ensino médio incompleto                              Mãe
# 43624                        Não estudou                              Pai
# 43625      Ensino fundamental incompleto                              Mãe
# 43626      Ensino fundamental incompleto                              Pai
# 43627              Ensino médio completo                              Mãe
# 43628              Ensino médio completo                              Pai
# 43629            Ensino médio incompleto                              Mãe
# 43631        Ensino fundamental completo                           Avô(ó)
# 43632              Ensino médio completo                              Mãe
# 43634         Ensino superior incompleto                              Pai
#
#             descricao_trabalho_responsavel pessoa_fisica__nascimento_data  \
# 34217                        Não informado                     22/10/1999
# 34218                        Não informado                     04/10/1997
# 34219                             Autônomo                     05/07/1999
# 34220                             Autônomo                     16/07/1998
# 34221                             Autônomo                     17/06/1999
# 34222                 Não está trabalhando                     15/08/2000
# 34223                      Empresa privada                     11/09/2000
# 34224                      Serviço público                     20/04/1999
# 34225                             Autônomo                     15/04/1999
# 34227                             Autônomo                     29/05/1999
# 34228                      Empresa privada                     12/12/1999
# 34229                      Empresa privada                     02/05/1999
# 34230                             Autônomo                     07/12/1999
# 34231                             Autônomo                     06/08/1998
# 34232                      Empresa privada                     11/07/2000
# 34234  Beneficiário ou Pensionista do INSS                     20/05/1997
# 34235                      Empresa privada                     25/02/2000
# 34236                      Empresa privada                     26/01/2000
# 34237                        Não informado                     06/05/1998
# 34238                      Serviço público                     01/04/2000
# 34240                      Serviço público                     28/08/1998
# 34241                      Serviço público                     01/10/2000
# 34246                             Autônomo                     27/09/1999
# 34247                        Não informado                     02/06/1998
# 34249                      Serviço público                     03/02/2000
# 34250                      Serviço público                     11/05/1999
# 34251                      Serviço público                     24/05/1999
# 34253                      Serviço público                     24/03/1999
# 34255                      Serviço público                     25/05/1999
# 34256                      Serviço público                     07/02/1997
# ...                                    ...                            ...
# 43495                             Pescador                     01/03/2002
# 43502                 Não está trabalhando                     01/06/2000
# 43510  Beneficiário ou Pensionista do INSS                     12/02/1997
# 43513                      Serviço público                     29/01/1996
# 43514                      Serviço público                     30/10/1981
# 43515         Trabalhador rural/Agricultor                     27/10/1995
# 43518                           Aposentado                     15/11/1995
# 43519         Trabalhador rural/Agricultor                     08/06/2000
# 43521                             Autônomo                     27/03/1998
# 43582                      Serviço público                     07/12/2000
# 43611                           Aposentado                     29/10/1999
# 43612                        Não informado                     20/02/1994
# 43613                        Não informado                     06/12/1991
# 43614                      Empresa privada                     01/01/1992
# 43615                      Empresa privada                     25/11/1998
# 43616                             Autônomo                     28/02/2001
# 43617                           Aposentado                     22/06/1997
# 43619                      Serviço público                     09/09/2001
# 43620                      Empresa privada                     14/01/2000
# 43622    Trabalha com vínculo empregatício                     13/11/2001
# 43623                 Não está trabalhando                     13/05/2001
# 43624         Trabalhador rural/Agricultor                     29/08/2000
# 43625         Trabalhador rural/Agricultor                     11/03/1999
# 43626         Trabalhador rural/Agricultor                     06/11/2000
# 43627                      Empresa privada                     17/05/1999
# 43628         Trabalhador rural/Agricultor                     05/07/2000
# 43629                      Empresa privada                     15/10/2000
# 43631                           Aposentado                     05/10/2000
# 43632                             Autônomo                     12/02/2001
# 43634                      Serviço público                     16/06/1998
#
#       pessoa_fisica__sexo  qnt_salario  qtd_pessoas_domicilio sigla
# 34217                   F            0                      2   LAJ
# 34218                   M            0                      2   SPP
# 34219                   F            1                      6    PF
# 34220                   F            1                      2    MO
# 34221                   M            2                      5  CANG
# 34222                   M            0                      4    NC
# 34223                   F            1                      4  CNAT
# 34224                   F            1                      4  CNAT
# 34225                   M            1                      3    IP
# 34227                   M            1                      4   SGA
# 34228                   M            2                      6  CNAT
# 34229                   F            1                      2    MO
# 34230                   F            1                      5    IP
# 34231                   F            0                      4    PF
# 34232                   F            2                      5    MO
# 34234                   M            1                      3    CM
# 34235                   M            1                      3    CM
# 34236                   F            0                      4    IP
# 34237                   F            1                      4    MC
# 34238                   M            2                      5    CA
# 34240                   M            6                      4   PAR
# 34241                   M            4                      6    CN
# 34246                   M            1                      6    PF
# 34247                   M            4                      3    MC
# 34249                   M            0                      4    CA
# 34250                   M            4                      4   PAR
# 34251                   M            3                      3    ZN
# 34253                   M            3                      3    CM
# 34255                   F            2                      4    CA
# 34256                   M            1                      5    JC
# ...                   ...          ...                    ...   ...
# 43495                   M            1                      5    CN
# 43502                   F            1                      6  CNAT
# 43510                   F            1                      5   LAJ
# 43513                   M            1                      3   LAJ
# 43514                   M            1                      3   LAJ
# 43515                   F            0                      6   SPP
# 43518                   M            1                      2   SPP
# 43519                   F            1                      4    NC
# 43521                   M            0                      5  CNAT
# 43582                   F            1                      4    AP
# 43611                   F            1                      2  CNAT
# 43612                   F            1                      5  PAAS
# 43613                   M            1                      4   LAJ
# 43614                   M            2                      5   LAJ
# 43615                   F            1                      6   LAJ
# 43616                   F            1                      4    AP
# 43617                   F            1                      3   LAJ
# 43619                   M            4                      5    PF
# 43620                   F            3                      5  PAAS
# 43622                   M            1                      4  PAAS
# 43623                   F            0                      4    MO
# 43624                   F            1                      5    AP
# 43625                   M            0                      2    PF
# 43626                   F            1                      4  PAAS
# 43627                   M            1                      6    CM
# 43628                   F            1                      4    PF
# 43629                   M            1                      5    MC
# 43631                   M            1                      2    AP
# 43632                   F            2                      3  CANG
# 43634                   M            5                      5    ZN
#
# [7201 rows x 17 columns]

# %%
#transformando o dado em int
dados['cep'] = dados['cep'].str.replace('-', '')
dados['cep'] = dados['cep'].apply(pd.to_numeric, errors='coerce')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#transformando o dado em int
dados['pessoa_fisica__nascimento_data'] = dados['pessoa_fisica__nascimento_data'].str.replace('/','').apply(int)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#convertendo os NaN das notas em -1 para usar o RF 
dados['LnguaPortuguesaeLiteraturaI90H'].fillna(-1, inplace=True)
dados['MatemticaI120H'].fillna(-1, inplace=True)
dados['LnguaPortuguesaeLiteraturaII90H'].fillna(-1, inplace=True)
dados['MatemticaII90H'].fillna(-1, inplace=True)

# %%
#limpando os NaN devido ao RF
print(dados.shape)
df = dados
df = df.dropna()
dados = df
print(dados.shape)
# Out:
# (7201, 17)
# (7084, 17)

# %%
#configura os dados de entrada e saída
y = dados.classe
X = dados

del X['classe']
X.shape
# Out:
# (7084, 16)

# %%
#visualizacao hist da classe
y.plot.hist()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#binazira os dados devido aos atributos categoricos 
dados_dummies = pd.get_dummies(X, drop_first=False)
dados_dummies.shape
# Out:
# (7084, 141)

# %%
dados_dummies.hist(figsize=(20, 15))
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#remove atributos inconistentes
dados_clean = dados_dummies.replace([np.inf, -np.inf], np.nan)
dados_clean = dados_clean.dropna(axis=1, how='all')
dados_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7084 entries, 34217 to 43634
# Columns: 141 entries, cep to sigla_ZN
# dtypes: float64(1), int64(3), uint8(137)
# memory usage: 1.2 MB

# %%
#SELECIONANDO MELHOR MODEL RF

#cria a randomforest 
forest_clf = RandomForestClassifier(oob_score=True, n_jobs=-1) 

param_grid_forest = {'max_depth': [3, 5, None],
              'max_features': ['auto', 'sqrt', 'log2'],
              'n_estimators': [10, 30, 60, 100, 200, 500, 1000],
              'criterion': ["gini", "entropy"]}

#dividir os dados para treino e teste. default é 25% p teste
Xtrain, Xtest, ytrain, ytest = train_test_split(dados_clean, y, random_state=0)

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_forest = GridSearchCV(estimator=forest_clf, param_grid=param_grid_forest)
grid_search_forest.fit(Xtrain, ytrain)
print(grid_search_forest.best_params_)
print(grid_search_forest.best_estimator_)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=200, n_jobs=-1, oob_score=True, random_state=None,
#             verbose=0, warm_start=False)

# %%
#mostra os 5 melhores modelos
report(grid_search_forest.cv_results_, 5)
# Out:
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.917 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.917 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.917 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.917 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 1000}

# %%
#seleciona o melhor modelo
model_forest = grid_search_forest.best_estimator_
ypred_forest = model_forest.predict(Xtest)

# %%
#Evaluating
mat = confusion_matrix(ytest, ypred_forest)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))
print(f1_score(ytest, ypred_forest))

#qnt de evadidos 
print(sum(ytest==0))
# Out:
# 0.921380090498
# 0.999386503067
# 0.921380090498
# 0.999386503067
# 0.958799293702
# 141
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#CURVA ROC

y_probas_forest = cross_val_predict(model_forest, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_forest = y_probas_forest[:, 1]   # score = proba of positive class 
fpr_forest, tpr_forest, thresholds_forest = roc_curve(ytest, y_scores_forest)

plot_roc_curve(fpr_forest, tpr_forest) 
plt.show()
print(roc_auc_score(ytest, y_scores_forest))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.652573641387

# %%
#exibe os atributos mais importantes

importances = model_forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in model_forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(Xtest.shape[1]):
    print("%d. feature %d [%s] (%f)" % (f + 1, indices[f], dados_clean.columns[indices[f]],importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(Xtest.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(Xtest.shape[1]), indices)
plt.xlim([-1, Xtest.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 1 [pessoa_fisica__nascimento_data] (0.093512)
# 2. feature 0 [cep] (0.075842)
# 3. feature 3 [qtd_pessoas_domicilio] (0.054458)
# 4. feature 2 [qnt_salario] (0.035139)
# 5. feature 6 [descricao_area_residencial_Não informado] (0.020068)
# 6. feature 84 [descricao_raca_Parda] (0.016709)
# 7. feature 120 [pessoa_fisica__sexo_M] (0.016652)
# 8. feature 119 [pessoa_fisica__sexo_F] (0.016424)
# 9. feature 108 [descricao_trabalho_responsavel_Autônomo] (0.015607)
# 10. feature 81 [descricao_raca_Branca] (0.014764)
# 11. feature 71 [descricao_pai_escolaridade_Ensino fundamental incompleto] (0.014503)
# 12. feature 14 [descricao_companhia_domiciliar_Pais] (0.013994)
# 13. feature 57 [descricao_imovel_Próprio] (0.013898)
# 14. feature 61 [descricao_mae_escolaridade_Ensino médio completo] (0.013273)
# 15. feature 8 [descricao_area_residencial_Urbana] (0.013018)
# 16. feature 100 [descricao_responsavel_financeiro_Mãe] (0.012981)
# 17. feature 116 [descricao_trabalho_responsavel_Serviço público] (0.012922)
# 18. feature 60 [descricao_mae_escolaridade_Ensino fundamental incompleto] (0.012786)
# 19. feature 110 [descricao_trabalho_responsavel_Empresa privada] (0.012515)
# 20. feature 10 [descricao_companhia_domiciliar_Mãe] (0.012400)
# 21. feature 104 [descricao_responsavel_financeiro_Pai] (0.012388)
# 22. feature 21 [descricao_historico_Técnico de Nivel Médio em Informática] (0.011817)
# 23. feature 88 [descricao_responsavel_escolaridade_Ensino fundamental incompleto] (0.011796)
# 24. feature 89 [descricao_responsavel_escolaridade_Ensino médio completo] (0.010916)
# 25. feature 51 [descricao_imovel_Alugado] (0.010198)
# 26. feature 72 [descricao_pai_escolaridade_Ensino médio completo] (0.009778)
# 27. feature 114 [descricao_trabalho_responsavel_Não informado] (0.008767)
# 28. feature 62 [descricao_mae_escolaridade_Ensino médio incompleto] (0.008632)
# 29. feature 85 [descricao_raca_Preta] (0.008536)
# 30. feature 28 [descricao_historico_Técnico de Nível Médio em Edificações] (0.008174)
# 31. feature 7 [descricao_area_residencial_Rural] (0.008105)
# 32. feature 129 [sigla_JC] (0.007731)
# 33. feature 90 [descricao_responsavel_escolaridade_Ensino médio incompleto] (0.007531)
# 34. feature 22 [descricao_historico_Técnico de Nível Médio em Administração] (0.007379)
# 35. feature 107 [descricao_trabalho_responsavel_Aposentado] (0.007296)
# 36. feature 73 [descricao_pai_escolaridade_Ensino médio incompleto] (0.007287)
# 37. feature 15 [descricao_companhia_domiciliar_Parente(s) ou amigo(s)] (0.007100)
# 38. feature 113 [descricao_trabalho_responsavel_Não está trabalhando] (0.007038)
# 39. feature 41 [descricao_historico_Técnico de Nível Médio em Meio Ambiente] (0.006998)
# 40. feature 118 [descricao_trabalho_responsavel_Trabalhador rural/Agricultor] (0.006940)
# 41. feature 63 [descricao_mae_escolaridade_Ensino superior completo] (0.006845)
# 42. feature 137 [sigla_SC] (0.006824)
# 43. feature 34 [descricao_historico_Técnico de Nível Médio em Informática] (0.006813)
# 44. feature 131 [sigla_MC] (0.006663)
# 45. feature 91 [descricao_responsavel_escolaridade_Ensino superior completo] (0.006502)
# 46. feature 69 [descricao_pai_escolaridade_Alfabetizado] (0.006436)
# 47. feature 127 [sigla_CNAT] (0.006381)
# 48. feature 59 [descricao_mae_escolaridade_Ensino fundamental completo] (0.006304)
# 49. feature 133 [sigla_NC] (0.006101)
# 50. feature 139 [sigla_SPP] (0.006042)
# 51. feature 48 [descricao_historico_Técnico de Nível Médio em Têxtil] (0.005972)
# 52. feature 12 [descricao_companhia_domiciliar_Outros] (0.005836)
# 53. feature 87 [descricao_responsavel_escolaridade_Ensino fundamental completo] (0.005774)
# 54. feature 122 [sigla_CA] (0.005731)
# 55. feature 17 [descricao_historico_Técnico de Nivel Médio Informática] (0.005692)
# 56. feature 77 [descricao_pai_escolaridade_Não estudou] (0.005687)
# 57. feature 125 [sigla_CM] (0.005678)
# 58. feature 70 [descricao_pai_escolaridade_Ensino fundamental completo] (0.005470)
# 59. feature 97 [descricao_responsavel_financeiro_Avô(ó)] (0.005440)
# 60. feature 30 [descricao_historico_Técnico de Nível Médio em Eletrotécnica] (0.005350)
# 61. feature 55 [descricao_imovel_Outro] (0.005317)
# 62. feature 64 [descricao_mae_escolaridade_Ensino superior incompleto] (0.005295)
# 63. feature 74 [descricao_pai_escolaridade_Ensino superior completo] (0.005221)
# 64. feature 40 [descricao_historico_Técnico de Nível Médio em Mecânica] (0.005151)
# 65. feature 67 [descricao_mae_escolaridade_Pós graduação completo] (0.005117)
# 66. feature 130 [sigla_LAJ] (0.005035)
# 67. feature 9 [descricao_companhia_domiciliar_Cônjuge] (0.004973)
# 68. feature 109 [descricao_trabalho_responsavel_Beneficiário ou Pensionista do INSS] (0.004910)
# 69. feature 128 [sigla_IP] (0.004901)
# 70. feature 76 [descricao_pai_escolaridade_Não conhece] (0.004585)
# 71. feature 86 [descricao_responsavel_escolaridade_Alfabetizado] (0.004585)
# 72. feature 94 [descricao_responsavel_escolaridade_Não estudou] (0.004216)
# 73. feature 140 [sigla_ZN] (0.004197)
# 74. feature 58 [descricao_mae_escolaridade_Alfabetizado] (0.004190)
# 75. feature 54 [descricao_imovel_Não informado] (0.004155)
# 76. feature 66 [descricao_mae_escolaridade_Não estudou] (0.003914)
# 77. feature 80 [descricao_raca_Amarela] (0.003885)
# 78. feature 35 [descricao_historico_Técnico de Nível Médio em Informática para Internet] (0.003879)
# 79. feature 121 [sigla_AP] (0.003843)
# 80. feature 95 [descricao_responsavel_escolaridade_Pós graduação completo] (0.003832)
# 81. feature 106 [descricao_responsavel_financeiro_Tio(a)] (0.003807)
# 82. feature 52 [descricao_imovel_Cedido ou Emprestado] (0.003570)
# 83. feature 138 [sigla_SGA] (0.003541)
# 84. feature 134 [sigla_PAAS] (0.003507)
# 85. feature 132 [sigla_MO] (0.003498)
# 86. feature 102 [descricao_responsavel_financeiro_O próprio aluno] (0.003461)
# 87. feature 126 [sigla_CN] (0.003456)
# 88. feature 136 [sigla_PF] (0.003371)
# 89. feature 46 [descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros] (0.003341)
# 90. feature 18 [descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada] (0.003338)
# 91. feature 50 [descricao_historico_Técnico em Programação de Jogos Digitais] (0.003328)
# 92. feature 13 [descricao_companhia_domiciliar_Pai] (0.003314)
# 93. feature 117 [descricao_trabalho_responsavel_Trabalha com vínculo empregatício] (0.003310)
# 94. feature 42 [descricao_historico_Técnico de Nível Médio em Mineração] (0.003227)
# 95. feature 53 [descricao_imovel_Financiado] (0.003224)
# 96. feature 31 [descricao_historico_Técnico de Nível Médio em Eletrônica] (0.003065)
# 97. feature 92 [descricao_responsavel_escolaridade_Ensino superior incompleto] (0.002946)
# 98. feature 75 [descricao_pai_escolaridade_Ensino superior incompleto] (0.002918)
# 99. feature 26 [descricao_historico_Técnico de Nível Médio em Comércio] (0.002917)
# 100. feature 45 [descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado] (0.002899)
# 101. feature 24 [descricao_historico_Técnico de Nível Médio em Alimentos] (0.002886)
# 102. feature 135 [sigla_PAR] (0.002744)
# 103. feature 38 [descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática] (0.002663)
# 104. feature 43 [descricao_historico_Técnico de Nível Médio em Multimídia] (0.002528)
# 105. feature 124 [sigla_CANG] (0.002519)
# 106. feature 49 [descricao_historico_Técnico de Nível Médio em Vestuário] (0.002503)
# 107. feature 44 [descricao_historico_Técnico de Nível Médio em Química] (0.002401)
# 108. feature 123 [sigla_CAL] (0.002382)
# 109. feature 103 [descricao_responsavel_financeiro_Outros] (0.002091)
# 110. feature 27 [descricao_historico_Técnico de Nível Médio em Controle Ambiental] (0.002008)
# 111. feature 83 [descricao_raca_Não declarado] (0.002005)
# 112. feature 98 [descricao_responsavel_financeiro_Cônjuge] (0.001990)
# 113. feature 99 [descricao_responsavel_financeiro_Irmão(ã)] (0.001963)
# 114. feature 20 [descricao_historico_Técnico de Nivel Médio em Equipamentos Biomédicos] (0.001918)
# 115. feature 25 [descricao_historico_Técnico de Nível Médio em Apicultura] (0.001859)
# 116. feature 32 [descricao_historico_Técnico de Nível Médio em Eventos] (0.001776)
# 117. feature 78 [descricao_pai_escolaridade_Pós graduação completo] (0.001702)
# 118. feature 39 [descricao_historico_Técnico de Nível Médio em Mecatrônica] (0.001414)
# 119. feature 115 [descricao_trabalho_responsavel_Pescador] (0.001377)
# 120. feature 47 [descricao_historico_Técnico de Nível Médio em Refrigeração e Climatização] (0.001339)
# 121. feature 23 [descricao_historico_Técnico de Nível Médio em Agroecologia] (0.001313)
# 122. feature 36 [descricao_historico_Técnico de Nível Médio em Lazer] (0.001310)
# 123. feature 33 [descricao_historico_Técnico de Nível Médio em Geologia] (0.001211)
# 124. feature 11 [descricao_companhia_domiciliar_Não informado] (0.001159)
# 125. feature 16 [descricao_companhia_domiciliar_Sozinho(a)] (0.001049)
# 126. feature 93 [descricao_responsavel_escolaridade_Não conhece] (0.001024)
# 127. feature 29 [descricao_historico_Técnico de Nível Médio em Eletromecânica] (0.001004)
# 128. feature 19 [descricao_historico_Técnico de Nivel Médio em Biocombustíveis] (0.000891)
# 129. feature 65 [descricao_mae_escolaridade_Não conhece] (0.000827)
# 130. feature 82 [descricao_raca_Indígena] (0.000725)
# 131. feature 96 [descricao_responsavel_escolaridade_Pós graduação incompleto] (0.000644)
# 132. feature 112 [descricao_trabalho_responsavel_Nunca trabalhou] (0.000553)
# 133. feature 68 [descricao_mae_escolaridade_Pós graduação incompleto] (0.000478)
# 134. feature 105 [descricao_responsavel_financeiro_Parentes] (0.000446)
# 135. feature 37 [descricao_historico_Técnico de Nível Médio em Logística] (0.000224)
# 136. feature 111 [descricao_trabalho_responsavel_Estágio ou bolsa] (0.000167)
# 137. feature 101 [descricao_responsavel_financeiro_Não informado] (0.000166)
# 138. feature 5 [descricao_area_residencial_Comunidade Quilombola] (0.000057)
# 139. feature 79 [descricao_pai_escolaridade_Pós graduação incompleto] (0.000033)
# 140. feature 4 [descricao_area_residencial_Comunidade Indígena] (0.000002)
# 141. feature 56 [descricao_imovel_Pensionato ou Alojamento] (0.000000)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#DECISION TREE
tree_clf = DecisionTreeClassifier() 

param_grid_tree = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_tree = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree)
grid_search_tree.fit(Xtrain, ytrain)
print(grid_search_tree.best_params_)
print(grid_search_tree.best_estimator_)
# Out:
# {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=10,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
#seleciona o melhor modelo e exibe os 5 melhores
report(grid_search_tree.cv_results_, 5)

model_tree = grid_search_tree.best_estimator_
ypred_tree = model_tree.predict(Xtest)
# Out:
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.001)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}

# %%
#porcentagem de predicao correta
n_correct = sum(ypred_tree == ytest)    
print(n_correct / len(ypred_tree)) 

#evaluating
mat = confusion_matrix(ytest, ypred_tree)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_tree))
print(recall_score(ytest, ypred_tree))
print(f1_score(ytest, ypred_tree))
# Out:
# 0.917560700169
# 0.920634920635
# 0.996319018405
# 0.956982911019
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#gera a arvore de decisao
export_graphviz(model_tree,
                feature_names=dados_clean.columns,
                filled=True,
                rounded=True, 
                out_file='tree.dot')

os.system('dot -Tpng tree.dot -o tree.png')
# Out:
# -1

# %%
y_probas_tree = cross_val_predict(model_tree, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_tree = y_probas_tree[:, 1]   # score = proba of positive class 
fpr_tree, tpr_tree, thresholds_tree = roc_curve(ytest, y_scores_tree)

plot_roc_curve(fpr_tree, tpr_tree) 
plt.show()
print(roc_auc_score(ytest, y_scores_tree))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.631201322717

# %%
#PLOTAR DUAS CURVAS ROC (DT e RF)
plt.plot(fpr_tree, tpr_tree, "b:", label="DT") 
plot_roc_curve(fpr_forest, tpr_forest, "Random Forest") 
plt.legend(loc="bottom right") 
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:326: UserWarning: Unrecognized location "bottom right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   six.iterkeys(self.codes))))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#importando base já tratada
dados = pd.read_json('dados/dados_filtrado_CA.json')
dados = dados[
                ['LnguaPortuguesaeLiteraturaI90H', 'LnguaPortuguesaeLiteraturaII90H', 
                 'MatemticaI120H', 'MatemticaII90H',
                'cep', 'classe', 'descricao_area_residencial', 
                'descricao_companhia_domiciliar', 'descricao_historico', 'descricao_imovel', 
                'descricao_mae_escolaridade', 'descricao_pai_escolaridade', 
                'descricao_raca', 'descricao_responsavel_escolaridade', 
                'descricao_responsavel_financeiro', 'descricao_trabalho_responsavel', 
                'pessoa_fisica__nascimento_data', 'pessoa_fisica__sexo', 
                'qnt_salario', 'qtd_pessoas_domicilio', 'sigla'
                ]
]

# %%
#transformando o dado em int
dados['cep'] = dados['cep'].str.replace('-', '')
dados['cep'] = dados['cep'].apply(pd.to_numeric, errors='coerce')

#transformando o dado em int
dados['pessoa_fisica__nascimento_data'] = dados['pessoa_fisica__nascimento_data'].str.replace('/','').apply(int)

#convertendo os NaN das notas em -1 para usar o RF 
dados['LnguaPortuguesaeLiteraturaI90H'].fillna(-1, inplace=True)
dados['MatemticaI120H'].fillna(-1, inplace=True)
dados['LnguaPortuguesaeLiteraturaII90H'].fillna(-1, inplace=True)
dados['MatemticaII90H'].fillna(-1, inplace=True)

#limpando os NaN devido ao RF
print(dados.shape)
df = dados
df = df.dropna()
dados = df
print(dados.shape)

#configura os dados de entrada e saída
y = dados.classe
X = dados

del X['classe']
X.shape

#binazira os dados devido aos atributos categoricos 
dados_dummies = pd.get_dummies(X, drop_first=False)
dados_dummies.shape

#remove atributos inconistentes
dados_clean = dados_dummies.replace([np.inf, -np.inf], np.nan)
dados_clean = dados_clean.dropna(axis=1, how='all')
dados_clean.info()
# Out:
# (7201, 21)
# (7084, 21)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7084 entries, 34217 to 43634
# Columns: 145 entries, LnguaPortuguesaeLiteraturaI90H to sigla_ZN
# dtypes: float64(3), int64(5), uint8(137)
# memory usage: 1.4 MB

# %%
#SELECIONANDO MELHOR MODEL RF

#cria a randomforest 
forest_clf = RandomForestClassifier(oob_score=True, n_jobs=-1) 

param_grid_forest = {'max_depth': [3, 5, None],
              'max_features': ['auto', 'sqrt', 'log2'],
              'n_estimators': [10, 30, 60, 100, 200, 500, 1000],
              'criterion': ["gini", "entropy"]}

#dividir os dados para treino e teste. default é 25% p teste
Xtrain, Xtest, ytrain, ytest = train_test_split(dados_clean, y, random_state=0)

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_forest = GridSearchCV(estimator=forest_clf, param_grid=param_grid_forest)
grid_search_forest.fit(Xtrain, ytrain)
print(grid_search_forest.best_params_)
print(grid_search_forest.best_estimator_)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 500}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=500, n_jobs=-1, oob_score=True, random_state=None,
#             verbose=0, warm_start=False)

# %%
#mostra os 5 melhores modelos
report(grid_search_forest.cv_results_, 5)

#seleciona o melhor modelo
model_forest = grid_search_forest.best_estimator_
ypred_forest = model_forest.predict(Xtest)

# %%
#Evaluating
mat = confusion_matrix(ytest, ypred_forest)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))
print(f1_score(ytest, ypred_forest))

#qnt de evadidos 
print(sum(ytest==0))

# %%
#CURVA ROC

y_probas_forest = cross_val_predict(model_forest, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_forest = y_probas_forest[:, 1]   # score = proba of positive class 
fpr_forest, tpr_forest, thresholds_forest = roc_curve(ytest, y_scores_forest)

plot_roc_curve(fpr_forest, tpr_forest) 
plt.show()
print(roc_auc_score(ytest, y_scores_forest))

# %%
#exibe os atributos mais importantes

importances = model_forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in model_forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(Xtest.shape[1]):
    print("%d. feature %d [%s] (%f)" % (f + 1, indices[f], dados_clean.columns[indices[f]],importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(Xtest.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(Xtest.shape[1]), indices)
plt.xlim([-1, Xtest.shape[1]])
plt.show()

# %%
#DECISION TREE
tree_clf = DecisionTreeClassifier() 

param_grid_tree = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_tree = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree)
grid_search_tree.fit(Xtrain, ytrain)
print(grid_search_tree.best_params_)
print(grid_search_tree.best_estimator_)

# %%
#seleciona o melhor modelo e exibe os 5 melhores
report(grid_search_tree.cv_results_, 5)

model_tree = grid_search_tree.best_estimator_
ypred_tree = model_tree.predict(Xtest)

# %%
#porcentagem de predicao correta
n_correct = sum(ypred_tree == ytest)    
print(n_correct / len(ypred_tree)) 

#evaluating
mat = confusion_matrix(ytest, ypred_tree)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_tree))
print(recall_score(ytest, ypred_tree))
print(f1_score(ytest, ypred_tree))

# %%
y_probas_tree = cross_val_predict(model_tree, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_tree = y_probas_tree[:, 1]   # score = proba of positive class 
fpr_tree, tpr_tree, thresholds_tree = roc_curve(ytest, y_scores_tree)

plot_roc_curve(fpr_tree, tpr_tree) 
plt.show()
print(roc_auc_score(ytest, y_scores_tree))

# %%
#PLOTAR DUAS CURVAS ROC (DT e RF)
plt.plot(fpr_tree, tpr_tree, "b:", label="DT") 
plot_roc_curve(fpr_forest, tpr_forest, "Random Forest") 
plt.legend(loc="bottom right") 
plt.show()

# %% [markdown]
# # utilizando informacao CA
# filtrando de acordo com os atributos que no note "EDA" tem maior relação com a evasão na análise de CA

# %%
#importando base já tratada
dados = pd.read_json('dados/dados_filtrado_CA.json')
dados = dados[
                ['LnguaPortuguesaeLiteraturaI90H', 'LnguaPortuguesaeLiteraturaII90H', 
                 'MatemticaI120H', 'MatemticaII90H',
                'cep', 'classe', 'descricao_area_residencial', 
                'descricao_companhia_domiciliar', 'descricao_historico', 'descricao_imovel', 
                'descricao_mae_escolaridade', 'descricao_pai_escolaridade', 
                'descricao_raca', 'descricao_responsavel_escolaridade', 
                'descricao_responsavel_financeiro', 'descricao_trabalho_responsavel', 
                'pessoa_fisica__nascimento_data', 'pessoa_fisica__sexo', 
                'qnt_salario', 'qtd_pessoas_domicilio', 'sigla'
                ]
]

# %%
#transformando o dado em int
dados['cep'] = dados['cep'].str.replace('-', '')
dados['cep'] = dados['cep'].apply(pd.to_numeric, errors='coerce')

#transformando o dado em int
dados['pessoa_fisica__nascimento_data'] = dados['pessoa_fisica__nascimento_data'].str.replace('/','').apply(int)

#convertendo os NaN das notas em -1 para usar o RF 
dados['LnguaPortuguesaeLiteraturaI90H'].fillna(-1, inplace=True)
dados['MatemticaI120H'].fillna(-1, inplace=True)
dados['LnguaPortuguesaeLiteraturaII90H'].fillna(-1, inplace=True)
dados['MatemticaII90H'].fillna(-1, inplace=True)

#limpando os NaN devido ao RF
print(dados.shape)
df = dados
df = df.dropna()
dados = df
print(dados.shape)

#configura os dados de entrada e saída
y = dados.classe
X = dados

del X['classe']
X.shape

#binazira os dados devido aos atributos categoricos 
dados_dummies = pd.get_dummies(X, drop_first=False)
dados_dummies.shape

#remove atributos inconistentes
dados_clean = dados_dummies.replace([np.inf, -np.inf], np.nan)
dados_clean = dados_clean.dropna(axis=1, how='all')
dados_clean.info()
# Out:
# (7201, 21)
# (7084, 21)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7084 entries, 34217 to 43634
# Columns: 145 entries, LnguaPortuguesaeLiteraturaI90H to sigla_ZN
# dtypes: float64(3), int64(5), uint8(137)
# memory usage: 1.4 MB

# %%
print(dados_clean.shape)
for c in dados_clean.columns:
    print(c)
# Out:
# (3356, 138)
# LnguaPortuguesaeLiteraturaI90H
# LnguaPortuguesaeLiteraturaII90H
# MatemticaI120H
# MatemticaII90H
# cep
# pessoa_fisica__nascimento_data
# qnt_salario
# qtd_pessoas_domicilio
# descricao_area_residencial_Comunidade Quilombola
# descricao_area_residencial_Não informado
# descricao_area_residencial_Rural
# descricao_area_residencial_Urbana
# descricao_companhia_domiciliar_Cônjuge
# descricao_companhia_domiciliar_Mãe
# descricao_companhia_domiciliar_Não informado
# descricao_companhia_domiciliar_Outros
# descricao_companhia_domiciliar_Pai
# descricao_companhia_domiciliar_Pais
# descricao_companhia_domiciliar_Parente(s) ou amigo(s)
# descricao_companhia_domiciliar_Sozinho(a)
# descricao_historico_Técnico de Nivel Médio Informática
# descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada
# descricao_historico_Técnico de Nivel Médio em Biocombustíveis
# descricao_historico_Técnico de Nivel Médio em Informática
# descricao_historico_Técnico de Nível Médio em Administração
# descricao_historico_Técnico de Nível Médio em Agroecologia
# descricao_historico_Técnico de Nível Médio em Alimentos
# descricao_historico_Técnico de Nível Médio em Apicultura
# descricao_historico_Técnico de Nível Médio em Comércio
# descricao_historico_Técnico de Nível Médio em Controle Ambiental
# descricao_historico_Técnico de Nível Médio em Edificações
# descricao_historico_Técnico de Nível Médio em Eletromecânica
# descricao_historico_Técnico de Nível Médio em Eletrotécnica
# descricao_historico_Técnico de Nível Médio em Eletrônica
# descricao_historico_Técnico de Nível Médio em Geologia
# descricao_historico_Técnico de Nível Médio em Informática
# descricao_historico_Técnico de Nível Médio em Informática para Internet
# descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática
# descricao_historico_Técnico de Nível Médio em Mecatrônica
# descricao_historico_Técnico de Nível Médio em Mecânica
# descricao_historico_Técnico de Nível Médio em Meio Ambiente
# descricao_historico_Técnico de Nível Médio em Mineração
# descricao_historico_Técnico de Nível Médio em Multimídia
# descricao_historico_Técnico de Nível Médio em Química
# descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado
# descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros
# descricao_historico_Técnico de Nível Médio em Têxtil
# descricao_historico_Técnico de Nível Médio em Vestuário
# descricao_historico_Técnico em Programação de Jogos Digitais
# descricao_imovel_Alugado
# descricao_imovel_Cedido ou Emprestado
# descricao_imovel_Financiado
# descricao_imovel_Não informado
# descricao_imovel_Outro
# descricao_imovel_Próprio
# descricao_mae_escolaridade_Alfabetizado
# descricao_mae_escolaridade_Ensino fundamental completo
# descricao_mae_escolaridade_Ensino fundamental incompleto
# descricao_mae_escolaridade_Ensino médio completo
# descricao_mae_escolaridade_Ensino médio incompleto
# descricao_mae_escolaridade_Ensino superior completo
# descricao_mae_escolaridade_Ensino superior incompleto
# descricao_mae_escolaridade_Não conhece
# descricao_mae_escolaridade_Não estudou
# descricao_mae_escolaridade_Pós graduação completo
# descricao_mae_escolaridade_Pós graduação incompleto
# descricao_pai_escolaridade_Alfabetizado
# descricao_pai_escolaridade_Ensino fundamental completo
# descricao_pai_escolaridade_Ensino fundamental incompleto
# descricao_pai_escolaridade_Ensino médio completo
# descricao_pai_escolaridade_Ensino médio incompleto
# descricao_pai_escolaridade_Ensino superior completo
# descricao_pai_escolaridade_Ensino superior incompleto
# descricao_pai_escolaridade_Não conhece
# descricao_pai_escolaridade_Não estudou
# descricao_pai_escolaridade_Pós graduação completo
# descricao_pai_escolaridade_Pós graduação incompleto
# descricao_raca_Amarela
# descricao_raca_Branca
# descricao_raca_Indígena
# descricao_raca_Não declarado
# descricao_raca_Parda
# descricao_raca_Preta
# descricao_responsavel_escolaridade_Alfabetizado
# descricao_responsavel_escolaridade_Ensino fundamental completo
# descricao_responsavel_escolaridade_Ensino fundamental incompleto
# descricao_responsavel_escolaridade_Ensino médio completo
# descricao_responsavel_escolaridade_Ensino médio incompleto
# descricao_responsavel_escolaridade_Ensino superior completo
# descricao_responsavel_escolaridade_Ensino superior incompleto
# descricao_responsavel_escolaridade_Não conhece
# descricao_responsavel_escolaridade_Não estudou
# descricao_responsavel_escolaridade_Pós graduação completo
# descricao_responsavel_escolaridade_Pós graduação incompleto
# descricao_responsavel_financeiro_Avô(ó)
# descricao_responsavel_financeiro_Cônjuge
# descricao_responsavel_financeiro_Irmão(ã)
# descricao_responsavel_financeiro_Mãe
# descricao_responsavel_financeiro_Não informado
# descricao_responsavel_financeiro_O próprio aluno
# descricao_responsavel_financeiro_Outros
# descricao_responsavel_financeiro_Pai
# descricao_responsavel_financeiro_Parentes
# descricao_responsavel_financeiro_Tio(a)
# descricao_trabalho_responsavel_Aposentado
# descricao_trabalho_responsavel_Autônomo
# descricao_trabalho_responsavel_Beneficiário ou Pensionista do INSS
# descricao_trabalho_responsavel_Empresa privada
# descricao_trabalho_responsavel_Estágio ou bolsa
# descricao_trabalho_responsavel_Nunca trabalhou
# descricao_trabalho_responsavel_Não está trabalhando
# descricao_trabalho_responsavel_Não informado
# descricao_trabalho_responsavel_Pescador
# descricao_trabalho_responsavel_Serviço público
# descricao_trabalho_responsavel_Trabalha com vínculo empregatício
# descricao_trabalho_responsavel_Trabalhador rural/Agricultor
# pessoa_fisica__sexo_F
# pessoa_fisica__sexo_M
# sigla_AP
# sigla_CA
# sigla_CAL
# sigla_CANG
# sigla_CM
# sigla_CN
# sigla_CNAT
# sigla_IP
# sigla_JC
# sigla_LAJ
# sigla_MC
# sigla_MO
# sigla_NC
# sigla_PAAS
# sigla_PAR
# sigla_PF
# sigla_SC
# sigla_SGA
# sigla_SPP
# sigla_ZN

# %%
dados_filtrado = dados_clean[
                                [
                                #'cep', 
                                #'pessoa_fisica__nascimento_data', 
                                    
                                #'descricao_area_residencial', 
                                'descricao_area_residencial_Não informado',
                                'descricao_area_residencial_Rural',
                                    
                                #'descricao_companhia_domiciliar', 
                                'descricao_companhia_domiciliar_Cônjuge', 
                                'descricao_companhia_domiciliar_Outros', 
                                'descricao_companhia_domiciliar_Parente(s) ou amigo(s)',   
                                    
                                #'descricao_historico', 
                                'descricao_historico_Técnico de Nivel Médio Informática',
                                'descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada', 
                                'descricao_historico_Técnico de Nivel Médio em Biocombustíveis', 
                                'descricao_historico_Técnico de Nivel Médio em Equipamentos Biomédicos',
                                'descricao_historico_Técnico de Nivel Médio em Informática',
                                'descricao_historico_Técnico de Nível Médio em Administração',
                                'descricao_historico_Técnico de Nível Médio em Agroecologia',
                                'descricao_historico_Técnico de Nível Médio em Alimentos',
                                'descricao_historico_Técnico de Nível Médio em Apicultura',
                                'descricao_historico_Técnico de Nível Médio em Comércio',
                                'descricao_historico_Técnico de Nível Médio em Controle Ambiental',
                                'descricao_historico_Técnico de Nível Médio em Edificações',
                                'descricao_historico_Técnico de Nível Médio em Eletromecânica',
                                'descricao_historico_Técnico de Nível Médio em Eletrotécnica',
                                'descricao_historico_Técnico de Nível Médio em Eletrônica',
                                'descricao_historico_Técnico de Nível Médio em Eventos',
                                'descricao_historico_Técnico de Nível Médio em Geologia',
                                'descricao_historico_Técnico de Nível Médio em Informática',
                                'descricao_historico_Técnico de Nível Médio em Informática para Internet',
                                'descricao_historico_Técnico de Nível Médio em Lazer',
                                'descricao_historico_Técnico de Nível Médio em Logística',
                                'descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática',
                                'descricao_historico_Técnico de Nível Médio em Mecatrônica',
                                'descricao_historico_Técnico de Nível Médio em Mecânica',
                                'descricao_historico_Técnico de Nível Médio em Meio Ambiente',
                                'descricao_historico_Técnico de Nível Médio em Mineração',
                                'descricao_historico_Técnico de Nível Médio em Multimídia',
                                'descricao_historico_Técnico de Nível Médio em Química',
                                'descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado',
                                'descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros',
                                'descricao_historico_Técnico de Nível Médio em Refrigeração e Climatização',
                                'descricao_historico_Técnico de Nível Médio em Têxtil',
                                'descricao_historico_Técnico de Nível Médio em Vestuário',
                                'descricao_historico_Técnico em Programação de Jogos Digitais',
                                       
                                #'descricao_imovel', 
                                'descricao_imovel_Alugado',
                                'descricao_imovel_Não informado',    
                                    
                                #'descricao_mae_escolaridade',
                                'descricao_mae_escolaridade_Ensino fundamental incompleto',
                                'descricao_mae_escolaridade_Alfabetizado',
                                    
                                #'descricao_pai_escolaridade', 
                                'descricao_pai_escolaridade_Ensino fundamental incompleto', 
                                'descricao_pai_escolaridade_Alfabetizado',
                                
                                #'descricao_raca', 
                                'descricao_raca_Amarela', 
                                'descricao_raca_Preta',
                                
                                #'descricao_responsavel_escolaridade',
                                'descricao_responsavel_escolaridade_Ensino fundamental incompleto', 
                                'descricao_responsavel_escolaridade_Alfabetizado', 
                                    
                                #'descricao_responsavel_financeiro',
                                'descricao_responsavel_financeiro_Mãe',
                                'descricao_responsavel_financeiro_Avô(ó)',
                                
                                #'descricao_trabalho_responsavel', 
                                'descricao_trabalho_responsavel_Não informado',
                                    
                                #'pessoa_fisica__sexo', 
                                'pessoa_fisica__sexo_F',
                                
                                'qnt_salario', 
                                'qtd_pessoas_domicilio', 
                                
                                #'sigla'
                                'sigla_AP',
                                'sigla_CA',
                                'sigla_CAL',
                                'sigla_CANG',
                                'sigla_CM',
                                'sigla_CN',
                                'sigla_CNAT',
                                'sigla_IP',
                                'sigla_JC',
                                'sigla_LAJ',
                                'sigla_MC',
                                'sigla_MO',
                                'sigla_NC',
                                'sigla_PAAS',
                                'sigla_PAR',
                                'sigla_PF',
                                'sigla_SC',
                                'sigla_SGA',
                                'sigla_SPP',
                                'sigla_ZN'
                                
                                ]
                            ]

# %%
print(dados_clean.shape)
print(dados_filtrado.shape)

#dividir os dados para treino e teste. default é 25% p teste
Xtrain, Xtest, ytrain, ytest = train_test_split(dados_filtrado, y, random_state=0)

print(Xtest.shape)
# Out:
# (7084, 145)
# (7084, 75)
# (1771, 75)

# %%
#SELECIONANDO MELHOR MODEL RF

#cria a randomforest 
forest_clf = RandomForestClassifier(oob_score=True, n_jobs=-1) 

param_grid_forest = {'max_depth': [3, 5, None],
              'max_features': ['auto', 'sqrt', 'log2'],
              'n_estimators': [10, 30, 60, 100, 200, 500, 1000],
              'criterion': ["gini", "entropy"]}

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_forest = GridSearchCV(estimator=forest_clf, param_grid=param_grid_forest)
grid_search_forest.fit(Xtrain, ytrain)
print(grid_search_forest.best_params_)
print(grid_search_forest.best_estimator_)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 10}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=-1, oob_score=True, random_state=None,
#             verbose=0, warm_start=False)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])

# %%
#mostra os 5 melhores modelos
report(grid_search_forest.cv_results_, 5)

#seleciona o melhor modelo
model_forest = grid_search_forest.best_estimator_
ypred_forest = model_forest.predict(Xtest)
# Out:
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 1000}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 10}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 30}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 60}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 500}
#
# Model with rank: 2
# Mean validation score: 0.916 (std: 0.000)
# Parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 1000}

# %%
#Evaluating
mat = confusion_matrix(ytest, ypred_forest)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))

#evaluating
print(precision_score(ytest, ypred_forest))
print(recall_score(ytest, ypred_forest))
print(f1_score(ytest, ypred_forest))

#qnt de evadidos 
print(sum(ytest==0))
# Out:
# 0.920383963862
# 1.0
# 0.920383963862
# 1.0
# 0.95854160541
# 141
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#CURVA ROC

y_probas_forest = cross_val_predict(model_forest, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_forest = y_probas_forest[:, 1]   # score = proba of positive class 
fpr_forest, tpr_forest, thresholds_forest = roc_curve(ytest, y_scores_forest)

plot_roc_curve(fpr_forest, tpr_forest) 
plt.show()
print(roc_auc_score(ytest, y_scores_forest))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:439: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:444: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.67302789018

# %%
#exibe os atributos mais importantes

importances = model_forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in model_forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(Xtest.shape[1]):
    print("%d. feature %d [%s] (%f)" % (f + 1, indices[f], dados_filtrado.columns[indices[f]],importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(Xtest.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(Xtest.shape[1]), indices)
plt.xlim([-1, Xtest.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 54 [qtd_pessoas_domicilio] (0.138291)
# 2. feature 0 [descricao_area_residencial_Não informado] (0.101152)
# 3. feature 2 [descricao_companhia_domiciliar_Cônjuge] (0.066050)
# 4. feature 9 [descricao_historico_Técnico de Nivel Médio em Informática] (0.046613)
# 5. feature 40 [descricao_imovel_Não informado] (0.040133)
# 6. feature 51 [descricao_trabalho_responsavel_Não informado] (0.039697)
# 7. feature 42 [descricao_mae_escolaridade_Alfabetizado] (0.038060)
# 8. feature 63 [sigla_JC] (0.037229)
# 9. feature 65 [sigla_MC] (0.036371)
# 10. feature 43 [descricao_pai_escolaridade_Ensino fundamental incompleto] (0.035865)
# 11. feature 53 [qnt_salario] (0.033279)
# 12. feature 41 [descricao_mae_escolaridade_Ensino fundamental incompleto] (0.031545)
# 13. feature 3 [descricao_companhia_domiciliar_Outros] (0.024460)
# 14. feature 47 [descricao_responsavel_escolaridade_Ensino fundamental incompleto] (0.022536)
# 15. feature 48 [descricao_responsavel_escolaridade_Alfabetizado] (0.022051)
# 16. feature 50 [descricao_responsavel_financeiro_Avô(ó)] (0.019092)
# 17. feature 29 [descricao_historico_Técnico de Nível Médio em Meio Ambiente] (0.017641)
# 18. feature 56 [sigla_CA] (0.017070)
# 19. feature 52 [pessoa_fisica__sexo_F] (0.015766)
# 20. feature 32 [descricao_historico_Técnico de Nível Médio em Química] (0.013499)
# 21. feature 69 [sigla_PAR] (0.012390)
# 22. feature 4 [descricao_companhia_domiciliar_Parente(s) ou amigo(s)] (0.011419)
# 23. feature 10 [descricao_historico_Técnico de Nível Médio em Administração] (0.010700)
# 24. feature 39 [descricao_imovel_Alugado] (0.010697)
# 25. feature 71 [sigla_SC] (0.009303)
# 26. feature 49 [descricao_responsavel_financeiro_Mãe] (0.009119)
# 27. feature 12 [descricao_historico_Técnico de Nível Médio em Alimentos] (0.008917)
# 28. feature 36 [descricao_historico_Técnico de Nível Médio em Têxtil] (0.008856)
# 29. feature 17 [descricao_historico_Técnico de Nível Médio em Eletromecânica] (0.008723)
# 30. feature 1 [descricao_area_residencial_Rural] (0.008625)
# 31. feature 44 [descricao_pai_escolaridade_Alfabetizado] (0.007452)
# 32. feature 30 [descricao_historico_Técnico de Nível Médio em Mineração] (0.007452)
# 33. feature 13 [descricao_historico_Técnico de Nível Médio em Apicultura] (0.007444)
# 34. feature 59 [sigla_CM] (0.007402)
# 35. feature 60 [sigla_CN] (0.007401)
# 36. feature 74 [sigla_ZN] (0.007362)
# 37. feature 45 [descricao_raca_Amarela] (0.007311)
# 38. feature 64 [sigla_LAJ] (0.007239)
# 39. feature 18 [descricao_historico_Técnico de Nível Médio em Eletrotécnica] (0.006675)
# 40. feature 68 [sigla_PAAS] (0.005301)
# 41. feature 67 [sigla_NC] (0.004998)
# 42. feature 19 [descricao_historico_Técnico de Nível Médio em Eletrônica] (0.004084)
# 43. feature 55 [sigla_AP] (0.003925)
# 44. feature 22 [descricao_historico_Técnico de Nível Médio em Informática] (0.003592)
# 45. feature 35 [descricao_historico_Técnico de Nível Médio em Refrigeração e Climatização] (0.003117)
# 46. feature 37 [descricao_historico_Técnico de Nível Médio em Vestuário] (0.003076)
# 47. feature 61 [sigla_CNAT] (0.002947)
# 48. feature 16 [descricao_historico_Técnico de Nível Médio em Edificações] (0.002884)
# 49. feature 5 [descricao_historico_Técnico de Nivel Médio Informática] (0.001580)
# 50. feature 73 [sigla_SPP] (0.001551)
# 51. feature 26 [descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática] (0.001273)
# 52. feature 23 [descricao_historico_Técnico de Nível Médio em Informática para Internet] (0.000781)
# 53. feature 46 [descricao_raca_Preta] (0.000003)
# 54. feature 33 [descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado] (0.000000)
# 55. feature 11 [descricao_historico_Técnico de Nível Médio em Agroecologia] (0.000000)
# 56. feature 34 [descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros] (0.000000)
# 57. feature 6 [descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada] (0.000000)
# 58. feature 7 [descricao_historico_Técnico de Nivel Médio em Biocombustíveis] (0.000000)
# 59. feature 70 [sigla_PF] (0.000000)
# 60. feature 8 [descricao_historico_Técnico de Nivel Médio em Equipamentos Biomédicos] (0.000000)
# 61. feature 66 [sigla_MO] (0.000000)
# 62. feature 72 [sigla_SGA] (0.000000)
# 63. feature 28 [descricao_historico_Técnico de Nível Médio em Mecânica] (0.000000)
# 64. feature 14 [descricao_historico_Técnico de Nível Médio em Comércio] (0.000000)
# 65. feature 62 [sigla_IP] (0.000000)
# 66. feature 27 [descricao_historico_Técnico de Nível Médio em Mecatrônica] (0.000000)
# 67. feature 15 [descricao_historico_Técnico de Nível Médio em Controle Ambiental] (0.000000)
# 68. feature 58 [sigla_CANG] (0.000000)
# 69. feature 31 [descricao_historico_Técnico de Nível Médio em Multimídia] (0.000000)
# 70. feature 20 [descricao_historico_Técnico de Nível Médio em Eventos] (0.000000)
# 71. feature 21 [descricao_historico_Técnico de Nível Médio em Geologia] (0.000000)
# 72. feature 57 [sigla_CAL] (0.000000)
# 73. feature 24 [descricao_historico_Técnico de Nível Médio em Lazer] (0.000000)
# 74. feature 25 [descricao_historico_Técnico de Nível Médio em Logística] (0.000000)
# 75. feature 38 [descricao_historico_Técnico em Programação de Jogos Digitais] (0.000000)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#DECISION TREE
tree_clf = DecisionTreeClassifier() 

param_grid_tree = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_tree = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree)
grid_search_tree.fit(Xtrain, ytrain)
print(grid_search_tree.best_params_)
print(grid_search_tree.best_estimator_)
# Out:
# {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=5, min_impurity_split=1e-07,
#             min_samples_leaf=10, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#seleciona o melhor modelo e exibe os 5 melhores
report(grid_search_tree.cv_results_, 5)

model_tree = grid_search_tree.best_estimator_
ypred_tree = model_tree.predict(Xtest)
# Out:
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# Model with rank: 1
# Mean validation score: 0.917 (std: 0.000)
# Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}

# %%
#porcentagem de predicao correta
n_correct = sum(ypred_tree == ytest)    
print(n_correct / len(ypred_tree)) 

#evaluating
mat = confusion_matrix(ytest, ypred_tree)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_tree))
print(recall_score(ytest, ypred_tree))
print(f1_score(ytest, ypred_tree))
# Out:
# 0.917560700169
# 0.920634920635
# 0.996319018405
# 0.956982911019
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
y_probas_tree = cross_val_predict(model_tree, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_tree = y_probas_tree[:, 1]   # score = proba of positive class 
fpr_tree, tpr_tree, thresholds_tree = roc_curve(ytest, y_scores_tree)

plot_roc_curve(fpr_tree, tpr_tree) 
plt.show()
print(roc_auc_score(ytest, y_scores_tree))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# 0.565609363443

# %%
#PLOTAR DUAS CURVAS ROC (DT e RF)
plt.plot(fpr_tree, tpr_tree, "b:", label="DT") 
plot_roc_curve(fpr_forest, tpr_forest, "Random Forest") 
plt.legend(loc="bottom right") 
plt.show()
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:326: UserWarning: Unrecognized location "bottom right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   six.iterkeys(self.codes))))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
dados_filtrado = dados_clean[
                                [
                                #'LnguaPortuguesaeLiteraturaI90H', 
                                #'LnguaPortuguesaeLiteraturaII90H', 
                                #'MatemticaI120H', 
                                #'MatemticaII90H',                                    
                                #'cep', 
                                #'pessoa_fisica__nascimento_data', 
                                    
                                #'descricao_area_residencial', 
                                'descricao_area_residencial_Não informado',
                                'descricao_area_residencial_Rural',
                                    
                                #'descricao_companhia_domiciliar', 
                                'descricao_companhia_domiciliar_Cônjuge', 
                                'descricao_companhia_domiciliar_Outros', 
                                'descricao_companhia_domiciliar_Parente(s) ou amigo(s)',   
                                    
                                #'descricao_historico', 
                                'descricao_historico_Técnico de Nivel Médio Informática',
                                'descricao_historico_Técnico de Nivel Médio em Agropecuária, na Forma Integrada', 
                                'descricao_historico_Técnico de Nivel Médio em Biocombustíveis', 
                                'descricao_historico_Técnico de Nivel Médio em Equipamentos Biomédicos',
                                'descricao_historico_Técnico de Nivel Médio em Informática',
                                'descricao_historico_Técnico de Nível Médio em Administração',
                                'descricao_historico_Técnico de Nível Médio em Agroecologia',
                                'descricao_historico_Técnico de Nível Médio em Alimentos',
                                'descricao_historico_Técnico de Nível Médio em Apicultura',
                                'descricao_historico_Técnico de Nível Médio em Comércio',
                                'descricao_historico_Técnico de Nível Médio em Controle Ambiental',
                                'descricao_historico_Técnico de Nível Médio em Edificações',
                                'descricao_historico_Técnico de Nível Médio em Eletromecânica',
                                'descricao_historico_Técnico de Nível Médio em Eletrotécnica',
                                'descricao_historico_Técnico de Nível Médio em Eletrônica',
                                'descricao_historico_Técnico de Nível Médio em Eventos',
                                'descricao_historico_Técnico de Nível Médio em Geologia',
                                'descricao_historico_Técnico de Nível Médio em Informática',
                                'descricao_historico_Técnico de Nível Médio em Informática para Internet',
                                'descricao_historico_Técnico de Nível Médio em Lazer',
                                'descricao_historico_Técnico de Nível Médio em Logística',
                                'descricao_historico_Técnico de Nível Médio em Manutenção e Suporte em Informática',
                                'descricao_historico_Técnico de Nível Médio em Mecatrônica',
                                'descricao_historico_Técnico de Nível Médio em Mecânica',
                                'descricao_historico_Técnico de Nível Médio em Meio Ambiente',
                                'descricao_historico_Técnico de Nível Médio em Mineração',
                                'descricao_historico_Técnico de Nível Médio em Multimídia',
                                'descricao_historico_Técnico de Nível Médio em Química',
                                'descricao_historico_Técnico de Nível Médio em Química, na Forma Integrado',
                                'descricao_historico_Técnico de Nível Médio em Recursos Pesqueiros',
                                'descricao_historico_Técnico de Nível Médio em Refrigeração e Climatização',
                                'descricao_historico_Técnico de Nível Médio em Têxtil',
                                'descricao_historico_Técnico de Nível Médio em Vestuário',
                                'descricao_historico_Técnico em Programação de Jogos Digitais',
                                       
                                #'descricao_imovel', 
                                'descricao_imovel_Alugado',
                                'descricao_imovel_Não informado',    
                                    
                                #'descricao_mae_escolaridade',
                                'descricao_mae_escolaridade_Ensino fundamental incompleto',
                                'descricao_mae_escolaridade_Alfabetizado',
                                    
                                #'descricao_pai_escolaridade', 
                                'descricao_pai_escolaridade_Ensino fundamental incompleto', 
                                'descricao_pai_escolaridade_Alfabetizado',
                                
                                #'descricao_raca', 
                                'descricao_raca_Amarela', 
                                'descricao_raca_Preta',
                                
                                #'descricao_responsavel_escolaridade',
                                'descricao_responsavel_escolaridade_Ensino fundamental incompleto', 
                                'descricao_responsavel_escolaridade_Alfabetizado', 
                                    
                                #'descricao_responsavel_financeiro',
                                'descricao_responsavel_financeiro_Mãe',
                                'descricao_responsavel_financeiro_Avô(ó)',
                                
                                #'descricao_trabalho_responsavel', 
                                'descricao_trabalho_responsavel_Não informado',
                                    
                                #'pessoa_fisica__sexo', 
                                'pessoa_fisica__sexo_F',
                                
                                'qnt_salario', 
                                'qtd_pessoas_domicilio', 
                                
                                #'sigla'
                                'sigla_AP',
                                'sigla_CA',
                                'sigla_CAL',
                                'sigla_CANG',
                                'sigla_CM',
                                'sigla_CN',
                                'sigla_CNAT',
                                'sigla_IP',
                                'sigla_JC',
                                'sigla_LAJ',
                                'sigla_MC',
                                'sigla_MO',
                                'sigla_NC',
                                'sigla_PAAS',
                                'sigla_PAR',
                                'sigla_PF',
                                'sigla_SC',
                                'sigla_SGA',
                                'sigla_SPP',
                                'sigla_ZN',
                     
#dados complementares
#'descricao_area_residencial_Urbana',
#'descricao_companhia_domiciliar_Pais',
#'descricao_imovel_Cedido ou Emprestado',
#'descricao_imovel_Financiado',
#'descricao_mae_escolaridade_Ensino médio completo',
#'descricao_mae_escolaridade_Ensino superior completo',
#'descricao_mae_escolaridade_Pós graduação completo',
#'descricao_pai_escolaridade_Ensino médio completo',
#'descricao_pai_escolaridade_Ensino superior completo',
#'descricao_pai_escolaridade_Não estudou',
#'descricao_raca_Branca',
#'descricao_raca_Parda',
#'descricao_responsavel_escolaridade_Ensino médio completo',
#'descricao_responsavel_escolaridade_Pós graduação completo',
#'descricao_responsavel_financeiro_Pai',
#'descricao_trabalho_responsavel_Empresa privada',
#'descricao_trabalho_responsavel_Serviço público',
#'pessoa_fisica__sexo_M'          

                                
                                ]
                            ]

# %%
#dividir os dados para treino e teste. default é 25% p teste
Xtrain, Xtest, ytrain, ytest = train_test_split(dados_filtrado, y, random_state=0)

# %%
#teste com parametros e notas
#DECISION TREE
tree_clf = DecisionTreeClassifier() 

param_grid_tree = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 3, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }

#seleciona o melhor modelo de acordo com os parâmetros
grid_search_tree = GridSearchCV(estimator=tree_clf, param_grid=param_grid_tree)
grid_search_tree.fit(Xtrain, ytrain)
print(grid_search_tree.best_params_)
print(grid_search_tree.best_estimator_)

#seleciona o melhor modelo e exibe os 5 melhores
report(grid_search_tree.cv_results_, 5)

model_tree = grid_search_tree.best_estimator_
ypred_tree = model_tree.predict(Xtest)

#porcentagem de predicao correta
n_correct = sum(ypred_tree == ytest)    
print(n_correct / len(ypred_tree)) 

#evaluating
mat = confusion_matrix(ytest, ypred_tree)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

#evaluating
print(precision_score(ytest, ypred_tree))
print(recall_score(ytest, ypred_tree))
print(f1_score(ytest, ypred_tree))

fig = plt.figure()

y_probas_tree = cross_val_predict(model_tree, Xtest, ytest, cv=3, method="predict_proba") 

y_scores_tree = y_probas_tree[:, 1]   # score = proba of positive class 
fpr_tree, tpr_tree, thresholds_tree = roc_curve(ytest, y_scores_tree)

plot_roc_curve(fpr_tree, tpr_tree) 
plt.show()
print(roc_auc_score(ytest, y_scores_tree))

fig = plt.figure()

#PLOTAR DUAS CURVAS ROC (DT e RF)
plt.plot(fpr_tree, tpr_tree, "b:", label="DT") 
plot_roc_curve(fpr_forest, tpr_forest, "Random Forest") 
plt.legend(loc="bottom right") 
plt.show()
