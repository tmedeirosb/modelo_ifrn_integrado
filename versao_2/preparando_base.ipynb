# %%
#import os pacotes utilizados
import numpy as np
import pandas as pd

#exibindo todas as colunas
pd.set_option('display.max_columns', None)

# %%
#import os dataframe do IFRN
df_AcompanhamentoEncaminhamento = pd.read_json('dados/AcompanhamentoEncaminhamento.json')
df_Aluno = pd.read_json('dados/Aluno.json')
df_BeneficioGovernoFederal = pd.read_json("dados/BeneficioGovernoFederal.json")
df_Caracterizacao = pd.read_json("dados/Caracterizacao.json")
df_CompanhiaDomiciliar = pd.read_json("dados/CompanhiaDomiciliar.json")
df_ContribuinteRendaFamiliar = pd.read_json("dados/ContribuinteRendaFamiliar.json")
df_CursoCampus = pd.read_json('dados/CursoCampus.json')
df_CursoFormacaoSuperior = pd.read_json('dados/CursoFormacaoSuperior.json')
df_Disciplina = pd.read_json("dados/Disciplina.json")
df_Encaminhamento = pd.read_json("dados/Encaminhamento.json")
df_EstadoCivil = pd.read_json("dados/EstadoCivil.json")
df_Idioma = pd.read_json("dados/Idioma.json")
df_MatriculaPeriodo = pd.read_json("dados/MatriculaPeriodo.json")
df_MeioTransporte = pd.read_json("dados/MeioTransporte.json")
df_NecessidadeEspecial = pd.read_json("dados/NecessidadeEspecial.json")
df_NivelEscolaridade = pd.read_json("dados/NivelEscolaridade.json")
df_Notas = pd.read_json("dados/Notas.json")
df_Professores = pd.read_json("dados/Professores.json")
df_Raca = pd.read_json("dados/Raca.json")
df_RazaoAfastamentoEducacional = pd.read_json("dados/RazaoAfastamentoEducacional.json")
df_SituacaoDisciplina = pd.read_json("dados/SituacaoDisciplina.json")
df_SituacaoMatricula = pd.read_json("dados/SituacaoMatricula.json")
df_SituacaoMatriculaPeriodo = pd.read_json("dados/SituacaoMatriculaPeriodo.json")
df_SituacaoTrabalho = pd.read_json("dados/SituacaoTrabalho.json")
df_TipoAcessoInternet = pd.read_json("dados/TipoAcessoInternet.json")
df_TipoAreaResidencial = pd.read_json("dados/TipoAreaResidencial.json")
df_TipoEscola = pd.read_json("dados/TipoEscola.json")
df_TipoImovelResidencial = pd.read_json("dados/TipoImovelResidencial.json")
df_TipoServicoSaude = pd.read_json("dados/TipoServicoSaude.json")
df_UnidadeOrganizacional = pd.read_json("dados/UnidadeOrganizacional.json")

# %%
print("df_AcompanhamentoEncaminhamento")
print(df_AcompanhamentoEncaminhamento.head(2))
print("df_Aluno")
print(df_Aluno.head(2))
print("df_BeneficioGovernoFederal")
print(df_BeneficioGovernoFederal.head(2))
print("df_Caracterizacao")
print(df_Caracterizacao.head(2))
print("df_CompanhiaDomiciliar")
print(df_CompanhiaDomiciliar.head(2))
print("df_ContribuinteRendaFamiliar")
print(df_ContribuinteRendaFamiliar.head(2))
print("df_CursoCampus")
print(df_CursoCampus.head(2))
print("df_CursoFormacaoSuperior")
print(df_CursoFormacaoSuperior.head(2))
print("df_Disciplina")
print(df_Disciplina.head(2))
print("df_Encaminhamento")
print(df_Encaminhamento.head(2))
print("df_EstadoCivil")
print(df_EstadoCivil.head(2))
print("df_Idioma")
print(df_Idioma.head(2))
print("df_MatriculaPeriodo")
print(df_MatriculaPeriodo.head(2))
print("df_MeioTransporte")
print(df_MeioTransporte.head(2))
print("df_NecessidadeEspecial")
print(df_NecessidadeEspecial.head(2))
print("df_NivelEscolaridade")
print(df_NivelEscolaridade.head(2))
print("df_Notas")
print(df_Notas.head(2))
print("df_Professores")
print(df_Professores.head(2))
print("df_Raca")
print(df_Raca.head(2))
print("df_RazaoAfastamentoEducacional")
print(df_RazaoAfastamentoEducacional.head(2))
print("df_SituacaoDisciplina")
print(df_SituacaoDisciplina.head(2))
print("df_SituacaoMatricula")
print(df_SituacaoMatricula.head(2))
print("df_SituacaoMatriculaPeriodo")
print(df_SituacaoMatriculaPeriodo.head(2))
print("df_SituacaoTrabalho")
print(df_SituacaoTrabalho.head(2))
print("df_TipoAcessoInternet")
print(df_TipoAcessoInternet.head(2))
print("df_TipoAreaResidencial")
print(df_TipoAreaResidencial.head(2))
print("df_TipoEscola")
print(df_TipoEscola.head(2))
print("df_TipoImovelResidencial")
print(df_TipoImovelResidencial.head(2))
print("df_TipoServicoSaude")
print(df_TipoServicoSaude.head(2))
print("df_UnidadeOrganizacional")
print(df_UnidadeOrganizacional.head(2))
# Out:
# df_AcompanhamentoEncaminhamento
#    acompanhamento__aluno_id        data  encaminhamento_id          id
# 0              507223381477  07/07/2017          946008521  7096627713
# 1              452389189433  07/07/2017          934855993  7099415845
# df_Aluno
#    ano_letivo__ano        cep cidade__estado__nome cidade__nome  \
# 0             2018  59535-000  RIO GRANDE DO NORTE        LAJES
# 1             2018  59170-000  RIO GRANDE DO NORTE         ARÊS
#
#    curso_campus_id            id  periodo_letivo  \
# 0       3282463137  613557159693               1
# 1       3299191929  615294165929               1
#
#   pessoa_fisica__nascimento_data pessoa_fisica__sexo  situacao_id
# 0                     08/07/2002                   M    920915333
# 1                     16/04/2001                   M    920915333
# df_BeneficioGovernoFederal
#                                           descricao         id
# 0  Programa Benefício de Prestação Continuada - BPC  932067861
# 1                            Programa Bolsa Família  926491597
# df_Caracterizacao
# Empty DataFrame
# Columns: []
# Index: []
# df_CompanhiaDomiciliar
#   descricao         id
# 0       Pai  954372917
# 1       Mãe  957161049
# df_ContribuinteRendaFamiliar
#   descricao         id
# 0       Pai  946008521
# 1       Mãe  948796653
# df_CursoCampus
#                          descricao_historico  diretoria__setor__uo_id  \
# 0  Técnico de Nivel Médio em Biocombustíveis                940432257
# 1     Técnico de Nível Médio em Agroecologia                934855993
#
#            id
# 0  1927430985
# 1  1877244609
# df_CursoFormacaoSuperior
#    codigo                    descricao         grau
# 0  345A01  Administração - Bacharelado  Bacharelado
# 1  621A04      Agronomia - Bacharelado  Bacharelado
# df_Disciplina
#    ch_hora_relogio                          descricao_historico           id
# 0              120                       Acionamento Eletrônico  11613401553
# 1               60  Administração de Empresas Cooperativistas I  11195181753
# df_Encaminhamento
#                                         descricao         id
# 0                          Atendimento domiciliar  951584785
# 1  Contato telefônico com os pais ou responsáveis  934855993
# df_EstadoCivil
#      descricao         id
# 0  Solteiro(a)  934855993
# 1    Casado(a)  937644125
# df_Idioma
#   descricao         id  uso_caracterizacao
# 0    Inglês  932067861                True
# 1  Espanhol  934855993                True
# df_MatriculaPeriodo
#        aluno_id  ano_letivo__ano             id  periodo_letivo  situacao_id
# 0  576628351353             2010  1551350934157               1    948796653
# 1  464294513073             2011  1062122988381               1    948796653
# df_MeioTransporte
#            descricao         id
# 0  Transporte locado  965525445
# 1          Bicicleta  943220389
# df_NecessidadeEspecial
#   descricao         id
# 0  Auditiva  940432257
# 1    Física  943220389
# df_NivelEscolaridade
#                      descricao         id
# 0                 Alfabetizado  954372917
# 1  Ensino fundamental completo  957161049
# df_Notas
#    disciplina_id  matricula_periodo_id  media_final  percentual_frequencia  \
# 0     9792751357         1289149424613           95                   98.0
# 1     9795539489         1479082552717           93                   90.0
#
#          professores  situacao_id
# 0  [1510, 1622, 802]    923703465
# 1             [1436]    923703465
# df_Professores
#   codigo_curso_formacao_superior data_ingresso           id  \
# 0                           None    21/03/2016  11529757593
# 1                         142P01    26/06/2014   8939582965
#
#                 regime     titulacao
# 0    40 HORAS SEMANAIS        Mestre
# 1  DEDICACAO EXCLUSIVA  Especialista
# df_Raca
#    codigo_censup  codigo_siape descricao         id  inativo_siape
# 0              3             4     Parda  920915333          False
# 1              2             6     Preta  923703465          False
# df_RazaoAfastamentoEducacional
#                                            descricao         id
# 0                                 Falta de Motivação  940432257
# 1  Baixa condição financeira para se manter na es...  937644125
# df_SituacaoDisciplina
#   descricao         id
# 0  Cursando  920915333
# 1  Aprovado  923703465
# df_SituacaoMatricula
#                     descricao         id
# 0                    Afastado  940432257
# 1  Aguardando Colação de Grau  954372917
# df_SituacaoMatriculaPeriodo
#   descricao         id
# 0  Afastado  932067861
# 1  Aprovado  948796653
# df_SituacaoTrabalho
#               descricao         id
# 0              Autônomo  937644125
# 1  Não está trabalhando  940432257
# df_TipoAcessoInternet
#           descricao         id
# 0       Diariamente  920915333
# 1  A cada dois dias  923703465
# df_TipoAreaResidencial
#   descricao         id
# 0    Urbana  932067861
# 1     Rural  934855993
# df_TipoEscola
#                          descricao         id
# 0        Somente em escola pública  920915333
# 1  A maior parte em escola pública  923703465
# df_TipoImovelResidencial
#                   descricao         id
# 0  Pensionato ou Alojamento  948796653
# 1                     Outro  951584785
# df_TipoServicoSaude
#                    descricao         id
# 0  Plano de saúde particular  920915333
# 1  Plano de saúde da empresa  923703465
# df_UnidadeOrganizacional
#           id sigla
# 0  940432257    AP
# 1  937644125    CA

# %%
#df_Alunos shape: (11311, 10)
print(df_Aluno.shape) 

#relacionando aluno ao seu campus e sua situacao de matricula
dados = pd.merge(df_Aluno, df_CursoCampus, 
                 left_on="curso_campus_id", right_on="id", suffixes=["", "_curso_campus"])
dados = pd.merge(dados, df_UnidadeOrganizacional, 
                 left_on="diretoria__setor__uo_id", right_on="id", suffixes=["", "_unidade_organizacional"])
dados = pd.merge(dados, df_SituacaoMatricula, 
                 left_on="situacao_id", right_on="id", suffixes=["", "_situacao_matricula"])
print(dados.shape)


"""

#relacionando aluno aos dados de caracterizacao social
dados = pd.merge(dados, df_Caracterizacao, 
                 left_on="id", right_on="aluno_id", suffixes=["", "_caracterizacao"])
dados = pd.merge(dados, df_CompanhiaDomiciliar, 
                 left_on="companhia_domiciliar_id", right_on="id", suffixes=["", "_companhia_domiciliar"])
dados = pd.merge(dados, df_EstadoCivil, 
                 left_on="estado_civil_id", right_on="id", suffixes=["", "_estado_civil"])
dados = pd.merge(dados, df_TipoAcessoInternet, how='left', 
                 left_on="frequencia_acesso_internet_id", right_on="id", suffixes=["", "_internet"])
dados = pd.merge(dados, df_NivelEscolaridade, 
                 left_on="mae_nivel_escolaridade_id", right_on="id", suffixes=["", "_mae_escolaridade"])
dados = pd.merge(dados, df_NivelEscolaridade, 
                 left_on="pai_nivel_escolaridade_id", right_on="id", suffixes=["", "_pai_escolaridade"])
dados = pd.merge(dados, df_Raca, 
                 left_on="raca_id", right_on="id", suffixes=["", "_raca"])
dados = pd.merge(dados, df_RazaoAfastamentoEducacional, how='left', 
                 left_on="razao_ausencia_educacional_id", right_on="id", suffixes=["", "_afastamento"])
dados = pd.merge(dados, df_SituacaoTrabalho,
                 left_on="responsavel_financeir_trabalho_situacao_id", right_on="id", suffixes=["", "_trabalho_responsavel"])
dados = pd.merge(dados, df_ContribuinteRendaFamiliar, 
                 left_on="responsavel_financeiro_id", right_on="id", suffixes=["", "_responsavel_financeiro"])
dados = pd.merge(dados, df_NivelEscolaridade, 
                 left_on="responsavel_financeiro_nivel_escolaridade_id", right_on="id", suffixes=["", "_responsavel_escolaridade"])
dados = pd.merge(dados, df_TipoAreaResidencial, 
                 left_on="tipo_area_residencial_id", right_on="id", suffixes=["", "_area_residencial"])
dados = pd.merge(dados, df_TipoImovelResidencial, 
                 left_on="tipo_imovel_residencial_id", right_on="id", suffixes=["", "_imovel"])
dados = pd.merge(dados, df_TipoServicoSaude, how='left', 
                 left_on="tipo_servico_saude_id", right_on="id", suffixes=["", "_saude"])
dados = pd.merge(dados, df_SituacaoTrabalho,  
                 left_on="trabalho_situacao_id", right_on="id", suffixes=["", "_trabalho"])
print(dados.shape)
dados.head(2)
"""


#relacionando aluno a situacao da matricula naquele periodo
dados = pd.merge(dados, df_MatriculaPeriodo, 
                 left_on="id", right_on="aluno_id", suffixes=["", "_matricula_periodo"])
dados = pd.merge(dados, df_SituacaoMatriculaPeriodo, 
                 left_on="situacao_id_matricula_periodo", right_on="id", suffixes=["", "_situacao_matricula_periodo"])
print(dados.shape)
dados.head(2)

#relacionando aluno a nota das disciplinas daquele periodo
dados = pd.merge(dados, df_Notas, 
                 left_on="id_matricula_periodo", right_on="matricula_periodo_id", suffixes=["", "_notas"])
dados = pd.merge(dados, df_Disciplina, 
                 left_on="disciplina_id", right_on="id", suffixes=["", "_disciplina"])
print(dados.shape)
dados.head(2)

dados = dados[['id', 'ano_letivo__ano', 'cep', 'pessoa_fisica__nascimento_data', 
               #'cidade__nome', 'cidade__estado__nome', 
               'pessoa_fisica__sexo', 'descricao_historico', 'sigla',
               'descricao', 
               'ano_letivo__ano_matricula_periodo', 'descricao_situacao_matricula_periodo',
               #'data', 'descricao_encaminhamento',
               'media_final', 'percentual_frequencia', 
               'descricao_historico_disciplina',
               #'professores', #FUTURAMENTE SERA UTILIZADO
               #'aluno_exclusivo_rede_publica', 
               #'descricao_companhia_domiciliar', 'descricao_estado_civil',
               #'ficou_tempo_sem_estudar', 'descricao_internet', 
               #'local_acesso_internet', 'descricao_mae_escolaridade', 
               #'nome_escola_ensino_fundamental', 'nome_escola_ensino_medio', 
               #'descricao_pai_escolaridade', 'possui_conhecimento_informatica',
               #'possui_necessidade_especial', 'qtd_filhos', 'qtd_pessoas_domicilio', 
               #'quantidade_computadores', 'quantidade_netbooks', 'quantidade_notebooks',
               #'quantidade_smartphones', 'descricao_raca', 'descricao_afastamento', 
               #'renda_bruta_familiar', 'descricao_trabalho_responsavel', 'descricao_responsavel_financeiro', 
               #'descricao_responsavel_escolaridade', 'tempo_sem_estudar',
               #'descricao_area_residencial', 'descricao_imovel', 'descricao_saude',               
               #'descricao_trabalho'
              ]]

print(dados.shape)
dados.head(2)
# Out:
# (11311, 10)
# (11311, 17)
# (24463, 24)
# (191156, 33)
# (191156, 13)
#              id  ano_letivo__ano        cep pessoa_fisica__nascimento_data  \
# 0  600087694001             2017  59178-000                     18/06/2000
# 1  542847344041             2017  59290-000                     10/08/2001
#
#   pessoa_fisica__sexo                       descricao_historico sigla  \
# 0                   M  Técnico de Nível Médio em Eletromecânica  CANG
# 1                   F       Técnico de Nível Médio em Logística   SGA
#
#      descricao  ano_letivo__ano_matricula_periodo  \
# 0  Matriculado                               2017
# 1  Matriculado                               2017
#
#   descricao_situacao_matricula_periodo  media_final  percentual_frequencia  \
# 0                          Matriculado           77                    NaN
# 1                          Matriculado            0                   95.0
#
#   descricao_historico_disciplina
# 0                    Arte I(30H)
# 1                    Arte I(30H)

# %% [markdown]
# # Filtrando os dados por disciplina

# %%
dados_filtrado = dados[(dados.descricao_historico_disciplina.str.startswith('Língua Portuguesa')) | 
              (dados.descricao_historico_disciplina.str.startswith('Matemática I')) ]
print(dados_filtrado.shape)
dados_filtrado
# Out:
# (27935, 13)
#                   id  ano_letivo__ano        cep  \
# 8018    600087694001             2017  59178-000
# 8019    451059250469             2015  59080-310
# 8020    542847344041             2017  59290-000
# 8021    458238690369             2015  59900-000
# 8022    546845525329             2017  59500-000
# 8023    500902686233             2016  59500-000
# 8024    548950564989             2017  59504-000
# 8025    545964475617             2017  59668-000
# 8026    501538380329             2016  59598-000
# 8027    548861344765             2017  59504-000
# 8028    546856677857             2017  59598-000
# 8029    545936594297             2017  59500-000
# 8030    546112246613             2017  59596-000
# 8031    546934745553             2017  59504-000
# 8032    546876194781             2017  59504-000
# 8033    548939412461             2017  59598-000
# 8034    545917077373             2017  59668-000
# 8035    556985961413             2017  59500-000
# 8036    548510040133             2017  59504-000
# 8037    546937533685             2017  59500-000
# 8038    546937533685             2017  59500-000
# 8039    500729822049             2016  59500-000
# 8040    546940321817             2017  59500-000
# 8041    547985871317             2017  59500-000
# 8042    546134551669             2017  59598-000
# 8043    548981234441             2017  59598-000
# 8044    548981234441             2017  59598-000
# 8045    501134101189             2016  59598-000
# 8046    548903166745             2017  59500-000
# 8047    548989598837             2017  59596-000
# ...              ...              ...        ...
# 171520  573631109453             2017  59196-000
# 171521  469644938381             2015  59500-000
# 171522  539680026089             2016  59062-195
# 171523  469081735717             2015  59152-820
# 171524  606023627029             2017
# 171525  477415462265             2015  59149-340
# 171526  457421767693             2015  59110-450
# 171527  507162042573             2015       -
# 171528  457773072325             2015  59106-125
# 171529  539640992241             2016  59157-410
# 171530  457577903085             2015  59122-475
# 171531  457577903085             2015  59122-475
# 171532  552299111521             2016  59020-250
# 171533  517536681745             2016  59010-500
# 171534  517511588557             2016  59158-224
# 171535  469474862329             2015  59160-400
# 190742  464294513073             2015  59120-480
# 190743  464325182525             2015  59110-090
# 190744  464294513073             2015  59120-480
# 190753  464294513073             2015  59120-480
# 190775  576628351353             2017  59668-000
# 190776  576628351353             2017  59668-000
# 190786  464325182525             2015  59110-090
# 190787  464294513073             2015  59120-480
# 190788  467166289033             2015  59139-000
# 190872  469204413525             2015  59162-000
# 190990  576628351353             2017  59668-000
# 190991  576628351353             2017  59668-000
# 190999  576628351353             2017  59668-000
# 191010  467166289033             2015  59139-000
#
#        pessoa_fisica__nascimento_data pessoa_fisica__sexo  \
# 8018                       18/06/2000                   M
# 8019                       17/04/1999                   M
# 8020                       10/08/2001                   F
# 8021                       31/01/1999                   F
# 8022                       25/10/2000                   F
# 8023                       04/01/2001                   M
# 8024                       04/08/2001                   F
# 8025                       08/06/2001                   M
# 8026                       25/12/2000                   M
# 8027                       24/09/2001                   F
# 8028                       27/04/2000                   M
# 8029                       16/07/2001                   F
# 8030                       27/06/2001                   M
# 8031                       19/03/2002                   F
# 8032                       31/03/2001                   M
# 8033                       12/02/2002                   F
# 8034                       10/04/2000                   M
# 8035                       28/09/1998                   M
# 8036                       28/12/2001                   M
# 8037                       04/01/2001                   M
# 8038                       04/01/2001                   M
# 8039                       05/01/2001                   F
# 8040                       15/02/2002                   M
# 8041                       18/04/2001                   F
# 8042                       16/09/2001                   F
# 8043                       19/03/2002                   F
# 8044                       19/03/2002                   F
# 8045                       15/01/2000                   F
# 8046                       31/07/2001                   F
# 8047                       14/04/2002                   M
# ...                               ...                 ...
# 171520                     25/03/1998                   F
# 171521                     29/04/1998                   F
# 171522                     09/10/1998                   F
# 171523                     04/12/1998                   F
# 171524                     26/02/1998                   F
# 171525                     02/02/2000                   M
# 171526                     02/12/1996                   M
# 171527                     19/02/1998                   M
# 171528                     24/05/1996                   F
# 171529                     29/05/1998                   M
# 171530                     28/12/1996                   M
# 171531                     28/12/1996                   M
# 171532                     20/08/2000                   M
# 171533                     05/12/1999                   F
# 171534                     10/04/2000                   M
# 171535                     12/06/1997                   F
# 190742                     25/06/1995                   F
# 190743                     28/05/1996                   M
# 190744                     25/06/1995                   F
# 190753                     25/06/1995                   F
# 190775                     06/04/1994                   M
# 190776                     06/04/1994                   M
# 190786                     28/05/1996                   M
# 190787                     25/06/1995                   F
# 190788                     24/05/1995                   M
# 190872                     23/09/1999                   M
# 190990                     06/04/1994                   M
# 190991                     06/04/1994                   M
# 190999                     06/04/1994                   M
# 191010                     24/05/1995                   M
#
#                                       descricao_historico sigla  \
# 8018             Técnico de Nível Médio em Eletromecânica  CANG
# 8019                  Técnico de Nível Médio em Logística   SGA
# 8020                  Técnico de Nível Médio em Logística   SGA
# 8021                 Técnico de Nível Médio em Apicultura    PF
# 8022        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8023        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8024        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8025        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8026        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8027        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8028        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8029        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8030        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8031        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8032        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8033        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8034        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8035        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8036        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8037        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8038        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8039        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8040        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8041        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8042        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8043        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8044        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8045        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8046        Técnico de Nível Médio em Recursos Pesqueiros    MC
# 8047        Técnico de Nível Médio em Recursos Pesqueiros    MC
# ...                                                   ...   ...
# 171520            Técnico de Nível Médio em Administração  CNAT
# 171521                  Técnico de Nível Médio em Química    MC
# 171522  Técnico de Nível Médio em Manutenção e Suporte...  CNAT
# 171523            Técnico de Nível Médio em Administração  CNAT
# 171524            Técnico de Nível Médio em Administração  CNAT
# 171525            Técnico de Nível Médio em Administração  CNAT
# 171526              Técnico de Nível Médio em Edificações  CNAT
# 171527              Técnico de Nível Médio em Edificações  CNAT
# 171528            Técnico de Nível Médio em Administração  CNAT
# 171529              Técnico de Nível Médio em Edificações  CNAT
# 171530              Técnico de Nível Médio em Edificações  CNAT
# 171531              Técnico de Nível Médio em Edificações  CNAT
# 171532  Técnico de Nível Médio em Informática para Int...  CNAT
# 171533  Técnico de Nível Médio em Informática para Int...  CNAT
# 171534            Técnico de Nível Médio em Administração  CNAT
# 171535  Técnico de Nível Médio em Manutenção e Suporte...  CNAT
# 190742              Técnico de Nível Médio em Edificações  CNAT
# 190743  Técnico de Nível Médio em Informática para Int...    ZN
# 190744              Técnico de Nível Médio em Edificações  CNAT
# 190753              Técnico de Nível Médio em Edificações  CNAT
# 190775      Técnico de Nível Médio em Recursos Pesqueiros    MC
# 190776      Técnico de Nível Médio em Recursos Pesqueiros    MC
# 190786  Técnico de Nível Médio em Informática para Int...    ZN
# 190787              Técnico de Nível Médio em Edificações  CNAT
# 190788  Técnico de Nível Médio em Informática para Int...    ZN
# 190872                Técnico de Nível Médio em Mineração  CNAT
# 190990      Técnico de Nível Médio em Recursos Pesqueiros    MC
# 190991      Técnico de Nível Médio em Recursos Pesqueiros    MC
# 190999      Técnico de Nível Médio em Recursos Pesqueiros    MC
# 191010  Técnico de Nível Médio em Informática para Int...    ZN
#
#                        descricao  ano_letivo__ano_matricula_periodo  \
# 8018                 Matriculado                               2017
# 8019                 Matriculado                               2017
# 8020                 Matriculado                               2017
# 8021                 Matriculado                               2017
# 8022                 Matriculado                               2017
# 8023                 Matriculado                               2017
# 8024                 Matriculado                               2017
# 8025                 Matriculado                               2017
# 8026                 Matriculado                               2017
# 8027                 Matriculado                               2017
# 8028                 Matriculado                               2017
# 8029                 Matriculado                               2017
# 8030                 Matriculado                               2017
# 8031                 Matriculado                               2017
# 8032                 Matriculado                               2017
# 8033                 Matriculado                               2017
# 8034                 Matriculado                               2017
# 8035                 Matriculado                               2017
# 8036                 Matriculado                               2017
# 8037                 Matriculado                               2017
# 8038                 Matriculado                               2017
# 8039                 Matriculado                               2017
# 8040                 Matriculado                               2017
# 8041                 Matriculado                               2017
# 8042                 Matriculado                               2017
# 8043                 Matriculado                               2017
# 8044                 Matriculado                               2017
# 8045                 Matriculado                               2017
# 8046                 Matriculado                               2017
# 8047                 Matriculado                               2017
# ...                          ...                                ...
# 171520               Matriculado                               2017
# 171521                 Cancelado                               2015
# 171522  Cancelamento Compulsório                               2016
# 171523               Matriculado                               2017
# 171524               Matriculado                               2017
# 171525               Matriculado                               2017
# 171526                    Evasão                               2016
# 171527                    Evasão                               2016
# 171528                    Evasão                               2015
# 171529  Trancado Voluntariamente                               2017
# 171530  Trancado Voluntariamente                               2016
# 171531  Trancado Voluntariamente                               2017
# 171532  Cancelamento Compulsório                               2017
# 171533  Cancelamento Compulsório                               2017
# 171534  Cancelamento Compulsório                               2017
# 171535  Cancelamento Compulsório                               2016
# 190742                    Evasão                               2012
# 190743                    Evasão                               2012
# 190744                    Evasão                               2012
# 190753                    Evasão                               2013
# 190775                    Evasão                               2011
# 190776                    Evasão                               2011
# 190786                    Evasão                               2011
# 190787                    Evasão                               2011
# 190788                    Evasão                               2011
# 190872               Matriculado                               2017
# 190990                    Evasão                               2010
# 190991                    Evasão                               2010
# 190999                    Evasão                               2012
# 191010                    Evasão                               2011
#
#        descricao_situacao_matricula_periodo  media_final  \
# 8018                            Matriculado           87
# 8019                            Matriculado            0
# 8020                            Matriculado            0
# 8021                            Matriculado            0
# 8022                            Matriculado            0
# 8023                            Matriculado            0
# 8024                            Matriculado            0
# 8025                            Matriculado            0
# 8026                            Matriculado            0
# 8027                            Matriculado            0
# 8028                            Matriculado            0
# 8029                            Matriculado            0
# 8030                            Matriculado            0
# 8031                            Matriculado            0
# 8032                            Matriculado            0
# 8033                            Matriculado            0
# 8034                            Matriculado            0
# 8035                            Matriculado            0
# 8036                            Matriculado            0
# 8037                            Matriculado            0
# 8038                            Matriculado            0
# 8039                            Matriculado            0
# 8040                            Matriculado            0
# 8041                            Matriculado            0
# 8042                            Matriculado            0
# 8043                            Matriculado            0
# 8044                            Matriculado            0
# 8045                            Matriculado            0
# 8046                            Matriculado            0
# 8047                            Matriculado            0
# ...                                     ...          ...
# 171520                            Reprovado           72
# 171521                            Reprovado           25
# 171522                            Reprovado            0
# 171523                           Rep. Falta           30
# 171524                           Rep. Falta            0
# 171525                           Rep. Falta           65
# 171526                           Rep. Falta            0
# 171527                           Rep. Falta           28
# 171528                           Rep. Falta            0
# 171529             Trancado Voluntariamente            0
# 171530             Trancado Voluntariamente           36
# 171531             Trancado Voluntariamente            0
# 171532             Cancelamento Compulsório            0
# 171533             Cancelamento Compulsório            0
# 171534             Cancelamento Compulsório            0
# 171535             Cancelamento Compulsório            0
# 190742                          Dependência           67
# 190743                            Reprovado           63
# 190744                          Dependência           71
# 190753                          Dependência           84
# 190775                          Dependência           60
# 190776                          Dependência           61
# 190786                          Dependência           61
# 190787                             Aprovado           62
# 190788                             Aprovado           60
# 190872                             Aprovado           71
# 190990                             Aprovado           65
# 190991                             Aprovado           60
# 190999                             Aprovado           60
# 191010                             Aprovado           66
#
#         percentual_frequencia          descricao_historico_disciplina
# 8018                      NaN                      Matemática I(120H)
# 8019                     94.0                      Matemática I(120H)
# 8020                     97.0                      Matemática I(120H)
# 8021                     91.0                      Matemática I(120H)
# 8022                    100.0                      Matemática I(120H)
# 8023                    100.0                      Matemática I(120H)
# 8024                    100.0                      Matemática I(120H)
# 8025                    100.0                      Matemática I(120H)
# 8026                    100.0                      Matemática I(120H)
# 8027                    100.0                      Matemática I(120H)
# 8028                    100.0                      Matemática I(120H)
# 8029                    100.0                      Matemática I(120H)
# 8030                    100.0                      Matemática I(120H)
# 8031                    100.0                      Matemática I(120H)
# 8032                    100.0                      Matemática I(120H)
# 8033                    100.0                      Matemática I(120H)
# 8034                    100.0                      Matemática I(120H)
# 8035                    100.0                      Matemática I(120H)
# 8036                    100.0                      Matemática I(120H)
# 8037                    100.0                      Matemática I(120H)
# 8038                    100.0                      Matemática I(120H)
# 8039                    100.0                      Matemática I(120H)
# 8040                    100.0                      Matemática I(120H)
# 8041                    100.0                      Matemática I(120H)
# 8042                    100.0                      Matemática I(120H)
# 8043                    100.0                      Matemática I(120H)
# 8044                    100.0                      Matemática I(120H)
# 8045                     97.0                      Matemática I(120H)
# 8046                    100.0                      Matemática I(120H)
# 8047                    100.0                      Matemática I(120H)
# ...                       ...                                     ...
# 171520                  100.0  Língua Portuguesa e Literatura IV(60H)
# 171521                   69.0  Língua Portuguesa e Literatura IV(60H)
# 171522                   85.0  Língua Portuguesa e Literatura IV(60H)
# 171523                   42.0  Língua Portuguesa e Literatura IV(60H)
# 171524                   57.0  Língua Portuguesa e Literatura IV(60H)
# 171525                   76.0  Língua Portuguesa e Literatura IV(60H)
# 171526                    3.0  Língua Portuguesa e Literatura IV(60H)
# 171527                   35.0  Língua Portuguesa e Literatura IV(60H)
# 171528                   29.0  Língua Portuguesa e Literatura IV(60H)
# 171529                   73.0  Língua Portuguesa e Literatura IV(60H)
# 171530                   80.0  Língua Portuguesa e Literatura IV(60H)
# 171531                  100.0  Língua Portuguesa e Literatura IV(60H)
# 171532                   49.0  Língua Portuguesa e Literatura IV(60H)
# 171533                   60.0  Língua Portuguesa e Literatura IV(60H)
# 171534                   81.0  Língua Portuguesa e Literatura IV(60H)
# 171535                   98.0  Língua Portuguesa e Literatura IV(60H)
# 190742                   83.0               Língua Portuguesa II(90H)
# 190743                   95.0               Língua Portuguesa II(90H)
# 190744                   99.0                      Matemática II(90H)
# 190753                  100.0                     Matemática III(90H)
# 190775                   92.0                    Língua Portuguesa II
# 190776                   94.0                           Matemática II
# 190786                   89.0                      Matemática I(120H)
# 190787                   93.0                      Matemática I(120H)
# 190788                   97.0                      Matemática I(120H)
# 190872                   94.0       Língua Portuguesa e Literatura IV
# 190990                   99.0                     Língua Portuguesa I
# 190991                   98.0                            Matemática I
# 190999                   98.0                          Matemática III
# 191010                   97.0               Língua Portuguesa I(160H)
#
# [27935 rows x 13 columns]

# %%
#exibindo consistencias dos dados
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline

#msno.matrix(dados)
msno.matrix(dados_filtrado)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
dados_filtrado['qnt_pc'] = dados_filtrado.quantidade_computadores + dados_filtrado.quantidade_netbooks + dados_filtrado.quantidade_notebooks
df1 = dados_filtrado.drop(['cidade__estado__nome', 'cidade__nome', 
                           'descricao_internet', 'descricao_afastamento', 
                           'local_acesso_internet', 'nome_escola_ensino_medio', 
                           'tempo_sem_estudar', 'descricao_saude', 
                           'quantidade_computadores', 'quantidade_netbooks', 
                           'quantidade_notebooks', 'ficou_tempo_sem_estudar', 
                           'aluno_exclusivo_rede_publica', #apareceu alunos de colégio particular com valor True 
                           'descricao_estado_civil', #alunos adolescentes. provavelmente todos solteiros
                           'possui_conhecimento_informatica', #não apresentou informação
                           'possui_necessidade_especial', #havia True em alunos aparentemente normais
                           'qtd_filhos', #alunos adolescentes
                           'quantidade_smartphones', #muitos NaN
                           'descricao_trabalho', #alunos adolescentes
                           ], axis=1)
df1.columns
print(df1.shape)
df1

# %%
msno.matrix(df1)
dados_filtrado = df1

# %%
#dados_filtrado.to_csv("dados/dados_flat.csv", encoding='utf-8')
#dados_filtrado.to_json("dados/dados_flat.json")
dados = dados_filtrado

# %% [markdown]
# # Definindo a classe de evasão

# %%
#visualizando media das disciplinas por campus
dados.groupby(['sigla', 'descricao_historico_disciplina'])['media_final'].aggregate([np.mean]).unstack()
# Out:
#                                               mean                            \
# descricao_historico_disciplina Língua Portuguesa I Língua Portuguesa I(160H)
# sigla
# AP                                             NaN                       NaN
# CA                                             NaN                       NaN
# CAL                                            NaN                       NaN
# CANG                                           NaN                       NaN
# CM                                             NaN                       NaN
# CN                                             NaN                       NaN
# CNAT                                           NaN                       NaN
# IP                                             NaN                       NaN
# JC                                             NaN                       NaN
# LAJ                                            NaN                       NaN
# MC                                            65.0                       NaN
# MO                                             NaN                       NaN
# NC                                             NaN                       NaN
# PAAS                                           NaN                       NaN
# PAR                                            NaN                       NaN
# PF                                             NaN                       NaN
# SC                                             NaN                       NaN
# SGA                                            NaN                       NaN
# SPP                                            NaN                       NaN
# ZN                                             NaN                      66.0
#
#                                                                                \
# descricao_historico_disciplina Língua Portuguesa II Língua Portuguesa II(90H)
# sigla
# AP                                              NaN                       NaN
# CA                                              NaN                       NaN
# CAL                                             NaN                       NaN
# CANG                                            NaN                       NaN
# CM                                              NaN                       NaN
# CN                                              NaN                       NaN
# CNAT                                            NaN                      67.0
# IP                                              NaN                       NaN
# JC                                              NaN                       NaN
# LAJ                                             NaN                       NaN
# MC                                             60.0                       NaN
# MO                                              NaN                       NaN
# NC                                              NaN                       NaN
# PAAS                                            NaN                       NaN
# PAR                                             NaN                       NaN
# PF                                              NaN                       NaN
# SC                                              NaN                       NaN
# SGA                                             NaN                       NaN
# SPP                                             NaN                       NaN
# ZN                                              NaN                      63.0
#
#                                                                       \
# descricao_historico_disciplina Língua Portuguesa e Literatura I(90H)
# sigla
# AP                                                         60.479290
# CA                                                         67.944345
# CAL                                                        69.237624
# CANG                                                       56.079812
# CM                                                         56.247911
# CN                                                         73.693712
# CNAT                                                       71.237500
# IP                                                         68.341365
# JC                                                         48.771588
# LAJ                                                        57.706371
# MC                                                         42.843882
# MO                                                         74.296530
# NC                                                         67.974194
# PAAS                                                       74.590909
# PAR                                                        65.556225
# PF                                                         74.962667
# SC                                                         67.938462
# SGA                                                        60.142857
# SPP                                                        64.051392
# ZN                                                         70.370526
#
#                                                                        \
# descricao_historico_disciplina Língua Portuguesa e Literatura II(90H)
# sigla
# AP                                                          67.849558
# CA                                                          72.508000
# CAL                                                         60.130435
# CANG                                                        63.468750
# CM                                                          67.737226
# CN                                                          79.596296
# CNAT                                                        67.657178
# IP                                                          71.788991
# JC                                                          67.894737
# LAJ                                                         67.751678
# MC                                                          66.571429
# MO                                                          75.068702
# NC                                                          60.604478
# PAAS                                                        77.813333
# PAR                                                         68.835526
# PF                                                          75.433824
# SC                                                          69.584000
# SGA                                                         74.121739
# SPP                                                         67.878924
# ZN                                                          69.230769
#
#                                                                         \
# descricao_historico_disciplina Língua Portuguesa e Literatura III(90H)
# sigla
# AP                                                           31.500000
# CA                                                           72.793939
# CAL                                                           5.666667
# CANG                                                         30.000000
# CM                                                           36.833333
# CN                                                           84.018692
# CNAT                                                         75.565359
# IP                                                                 NaN
# JC                                                            0.666667
# LAJ                                                          81.673469
# MC                                                           17.600000
# MO                                                           57.428571
# NC                                                           19.000000
# PAAS                                                         47.000000
# PAR                                                          66.879032
# PF                                                           18.000000
# SC                                                           72.416667
# SGA                                                          48.666667
# SPP                                                          69.512195
# ZN                                                           76.893617
#
#                                                                   \
# descricao_historico_disciplina Língua Portuguesa e Literatura IV
# sigla
# AP                                                           NaN
# CA                                                           NaN
# CAL                                                          NaN
# CANG                                                         NaN
# CM                                                           NaN
# CN                                                           NaN
# CNAT                                                        71.0
# IP                                                           NaN
# JC                                                           NaN
# LAJ                                                          NaN
# MC                                                           NaN
# MO                                                           NaN
# NC                                                           NaN
# PAAS                                                         NaN
# PAR                                                          NaN
# PF                                                           NaN
# SC                                                           NaN
# SGA                                                          NaN
# SPP                                                          NaN
# ZN                                                           NaN
#
#                                                                        \
# descricao_historico_disciplina Língua Portuguesa e Literatura IV(60H)
# sigla
# AP                                                                NaN
# CA                                                          74.000000
# CAL                                                               NaN
# CANG                                                        90.000000
# CM                                                                NaN
# CN                                                                NaN
# CNAT                                                        55.883721
# IP                                                                NaN
# JC                                                                NaN
# LAJ                                                               NaN
# MC                                                          25.000000
# MO                                                          71.000000
# NC                                                                NaN
# PAAS                                                              NaN
# PAR                                                         70.200000
# PF                                                                NaN
# SC                                                                NaN
# SGA                                                               NaN
# SPP                                                         82.000000
# ZN                                                          67.500000
#
#                                                                               \
# descricao_historico_disciplina Matemática I Matemática I(120H) Matemática II
# sigla
# AP                                      NaN          53.935211           NaN
# CA                                      NaN          60.747557           NaN
# CAL                                     NaN          51.977578           NaN
# CANG                                    NaN          58.445455           NaN
# CM                                      NaN          47.386534           NaN
# CN                                      NaN          58.670711           NaN
# CNAT                                    NaN          57.839112           NaN
# IP                                      NaN          51.258065           NaN
# JC                                      NaN          42.048346           NaN
# LAJ                                     NaN          55.042135           NaN
# MC                                     60.0          32.877395          61.0
# MO                                      NaN          62.773134           NaN
# NC                                      NaN          46.226415           NaN
# PAAS                                    NaN          62.789157           NaN
# PAR                                     NaN          59.557093           NaN
# PF                                      NaN          64.412935           NaN
# SC                                      NaN          55.748571           NaN
# SGA                                     NaN          57.761566           NaN
# SPP                                     NaN          42.372308           NaN
# ZN                                      NaN          50.068404           NaN
#
#                                                                        \
# descricao_historico_disciplina Matemática II(120H) Matemática II(90H)
# sigla
# AP                                             NaN          65.681416
# CA                                             NaN          67.170455
# CAL                                            NaN          46.434783
# CANG                                           NaN          53.803030
# CM                                             NaN          65.119403
# CN                                             NaN          69.854015
# CNAT                                           NaN          62.169451
# IP                                             NaN          52.932773
# JC                                             NaN          61.822917
# LAJ                                            NaN          66.113333
# MC                                             NaN          53.795699
# MO                                             NaN          68.694656
# NC                                             NaN          39.561290
# PAAS                                           NaN          76.480000
# PAR                                            NaN          59.328446
# PF                                             NaN          75.794118
# SC                                             NaN          58.505576
# SGA                                      72.264706          65.743902
# SPP                                            NaN          40.992366
# ZN                                             NaN          62.613546
#
#
# descricao_historico_disciplina Matemática III Matemática III(90H)
# sigla
# AP                                        NaN           32.000000
# CA                                        NaN           71.242424
# CAL                                       NaN            5.000000
# CANG                                      NaN           43.500000
# CM                                        NaN           44.000000
# CN                                        NaN           71.588785
# CNAT                                      NaN           64.529221
# IP                                        NaN                 NaN
# JC                                        NaN            0.666667
# LAJ                                       NaN           75.551020
# MC                                       60.0           13.600000
# MO                                        NaN           39.333333
# NC                                        NaN           20.800000
# PAAS                                      NaN            0.000000
# PAR                                       NaN           67.120968
# PF                                        NaN           20.000000
# SC                                        NaN           63.726190
# SGA                                       NaN           47.666667
# SPP                                       NaN           52.662651
# ZN                                        NaN           65.808511

# %%
#filtrando os dados a partir das disciplinas que possuam notas presentes em todos os campus
df = dados.loc[dados['descricao_historico_disciplina'].isin(['Língua Portuguesa e Literatura I(90H)',
                                                        'Língua Portuguesa e Literatura II(90H)', 
                                                        'Matemática I(120H)', 'Matemática II(90H)'])]

dados = df

# %%
#visualizando media das disciplinas por campus 
dados.groupby(['sigla', 'descricao_historico_disciplina'])['media_final'].aggregate([np.mean]).unstack()
# Out:
#                                                                 mean  \
# descricao_historico_disciplina Língua Portuguesa e Literatura I(90H)
# sigla
# AP                                                         60.479290
# CA                                                         67.944345
# CAL                                                        69.237624
# CANG                                                       56.079812
# CM                                                         56.247911
# CN                                                         73.693712
# CNAT                                                       71.237500
# IP                                                         68.341365
# JC                                                         48.771588
# LAJ                                                        57.706371
# MC                                                         42.843882
# MO                                                         74.296530
# NC                                                         67.974194
# PAAS                                                       74.590909
# PAR                                                        65.556225
# PF                                                         74.962667
# SC                                                         67.938462
# SGA                                                        60.142857
# SPP                                                        64.051392
# ZN                                                         70.370526
#
#                                                                        \
# descricao_historico_disciplina Língua Portuguesa e Literatura II(90H)
# sigla
# AP                                                          67.849558
# CA                                                          72.508000
# CAL                                                         60.130435
# CANG                                                        63.468750
# CM                                                          67.737226
# CN                                                          79.596296
# CNAT                                                        67.657178
# IP                                                          71.788991
# JC                                                          67.894737
# LAJ                                                         67.751678
# MC                                                          66.571429
# MO                                                          75.068702
# NC                                                          60.604478
# PAAS                                                        77.813333
# PAR                                                         68.835526
# PF                                                          75.433824
# SC                                                          69.584000
# SGA                                                         74.121739
# SPP                                                         67.878924
# ZN                                                          69.230769
#
#
# descricao_historico_disciplina Matemática I(120H) Matemática II(90H)
# sigla
# AP                                      53.935211          65.681416
# CA                                      60.747557          67.170455
# CAL                                     51.977578          46.434783
# CANG                                    58.445455          53.803030
# CM                                      47.386534          65.119403
# CN                                      58.670711          69.854015
# CNAT                                    57.839112          62.169451
# IP                                      51.258065          52.932773
# JC                                      42.048346          61.822917
# LAJ                                     55.042135          66.113333
# MC                                      32.877395          53.795699
# MO                                      62.773134          68.694656
# NC                                      46.226415          39.561290
# PAAS                                    62.789157          76.480000
# PAR                                     59.557093          59.328446
# PF                                      64.412935          75.794118
# SC                                      55.748571          58.505576
# SGA                                     57.761566          65.743902
# SPP                                     42.372308          40.992366
# ZN                                      50.068404          62.613546

# %%
#visualizando a disciplina por status de matricula
dados.groupby(['descricao_historico_disciplina', 'descricao'])['media_final'].aggregate([np.mean, np.size]).unstack()
# Out:
#                                              mean                           \
# descricao                               Cancelado Cancelamento Compulsório
# descricao_historico_disciplina
# Língua Portuguesa e Literatura I(90H)   34.682997                16.129032
# Língua Portuguesa e Literatura II(90H)  33.641791                 5.500000
# Matemática I(120H)                      22.556931                10.645161
# Matemática II(90H)                      27.930556                39.500000
#
#                                                                           \
# descricao                               Concluído     Evasão Matriculado
# descricao_historico_disciplina
# Língua Portuguesa e Literatura I(90H)   73.380952  29.873206   69.526272
# Língua Portuguesa e Literatura II(90H)  81.285714  30.682540   72.566133
# Matemática I(120H)                      74.047619  19.814655   57.752394
# Matemática II(90H)                      76.380952  24.923077   63.602165
#
#                                                                         \
# descricao                              Matrícula Vínculo Institucional
# descricao_historico_disciplina
# Língua Portuguesa e Literatura I(90H)                             11.0
# Língua Portuguesa e Literatura II(90H)                             NaN
# Matemática I(120H)                                                18.0
# Matemática II(90H)                                                 NaN
#
#                                                                             \
# descricao                                Trancado Trancado Voluntariamente
# descricao_historico_disciplina
# Língua Portuguesa e Literatura I(90H)   59.444444                65.575758
# Língua Portuguesa e Literatura II(90H)  39.142857                37.275862
# Matemática I(120H)                      34.615385                45.272727
# Matemática II(90H)                      13.111111                25.166667
#
#                                                             \
# descricao                              Transferido Externo
# descricao_historico_disciplina
# Língua Portuguesa e Literatura I(90H)            36.742268
# Língua Portuguesa e Literatura II(90H)           21.739130
# Matemática I(120H)                               25.174312
# Matemática II(90H)                               17.166667
#
#                                                                 size  \
# descricao                              Transferido Interno Cancelado
# descricao_historico_disciplina
# Língua Portuguesa e Literatura I(90H)            61.205882     347.0
# Língua Portuguesa e Literatura II(90H)           37.111111      67.0
# Matemática I(120H)                               46.263804     404.0
# Matemática II(90H)                               28.613333      72.0
#
#                                                                            \
# descricao                              Cancelamento Compulsório Concluído
# descricao_historico_disciplina
# Língua Portuguesa e Literatura I(90H)                      31.0      21.0
# Língua Portuguesa e Literatura II(90H)                      2.0      21.0
# Matemática I(120H)                                         31.0      21.0
# Matemática II(90H)                                          2.0      21.0
#
#                                                            \
# descricao                              Evasão Matriculado
# descricao_historico_disciplina
# Língua Portuguesa e Literatura I(90H)   418.0      7270.0
# Língua Portuguesa e Literatura II(90H)   63.0      3561.0
# Matemática I(120H)                      464.0      8251.0
# Matemática II(90H)                       65.0      3695.0
#
#                                                                         \
# descricao                              Matrícula Vínculo Institucional
# descricao_historico_disciplina
# Língua Portuguesa e Literatura I(90H)                              1.0
# Língua Portuguesa e Literatura II(90H)                             NaN
# Matemática I(120H)                                                 1.0
# Matemática II(90H)                                                 NaN
#
#                                                                           \
# descricao                              Trancado Trancado Voluntariamente
# descricao_historico_disciplina
# Língua Portuguesa e Literatura I(90H)       9.0                     33.0
# Língua Portuguesa e Literatura II(90H)      7.0                     29.0
# Matemática I(120H)                         13.0                     44.0
# Matemática II(90H)                          9.0                     30.0
#
#
# descricao                              Transferido Externo Transferido Interno
# descricao_historico_disciplina
# Língua Portuguesa e Literatura I(90H)                 97.0               136.0
# Língua Portuguesa e Literatura II(90H)                23.0                72.0
# Matemática I(120H)                                   109.0               163.0
# Matemática II(90H)                                    24.0                75.0

# %%
#visualizando a disciplina por status de matricula e campus
dados.groupby(['descricao_historico_disciplina', 'descricao', 'sigla'])['media_final'].aggregate([np.size]).unstack()
# Out:
#                                                                          size  \
# sigla                                                                      AP
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                         14.0
#                                        Cancelamento Compulsório           3.0
#                                        Concluído                          NaN
#                                        Evasão                            11.0
#                                        Matriculado                      296.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                8.0
#                                        Transferido Interno                6.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          3.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                      106.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                3.0
# Matemática I(120H)                     Cancelado                         13.0
#                                        Cancelamento Compulsório           3.0
#                                        Concluído                          NaN
#                                        Evasão                            11.0
#                                        Matriculado                      313.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                9.0
#                                        Transferido Interno                6.0
# Matemática II(90H)                     Cancelado                          3.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                      106.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                3.0
#
#                                                                                \
# sigla                                                                      CA
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                         58.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            10.0
#                                        Matriculado                      481.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                5.0
#                                        Transferido Interno                3.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          8.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                      237.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                4.0
# Matemática I(120H)                     Cancelado                         61.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            11.0
#                                        Matriculado                      534.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                5.0
#                                        Transferido Interno                3.0
# Matemática II(90H)                     Cancelado                          9.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                      251.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                3.0
#
#                                                                                \
# sigla                                                                     CAL
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                          8.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             9.0
#                                        Matriculado                      172.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           4.0
#                                        Transferido Externo                2.0
#                                        Transferido Interno                7.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          1.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             3.0
#                                        Matriculado                       59.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           3.0
#                                        Transferido Externo                1.0
#                                        Transferido Interno                2.0
# Matemática I(120H)                     Cancelado                          9.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            11.0
#                                        Matriculado                      189.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           5.0
#                                        Transferido Externo                2.0
#                                        Transferido Interno                7.0
# Matemática II(90H)                     Cancelado                          1.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             3.0
#                                        Matriculado                       58.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           4.0
#                                        Transferido Externo                1.0
#                                        Transferido Interno                2.0
#
#                                                                                \
# sigla                                                                    CANG
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                          5.0
#                                        Cancelamento Compulsório           1.0
#                                        Concluído                          1.0
#                                        Evasão                             5.0
#                                        Matriculado                      195.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                6.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          NaN
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          1.0
#                                        Evasão                             NaN
#                                        Matriculado                       62.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                1.0
# Matemática I(120H)                     Cancelado                          6.0
#                                        Cancelamento Compulsório           1.0
#                                        Concluído                          1.0
#                                        Evasão                             5.0
#                                        Matriculado                      200.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                7.0
# Matemática II(90H)                     Cancelado                          NaN
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          1.0
#                                        Evasão                             NaN
#                                        Matriculado                       64.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                1.0
#
#                                                                                \
# sigla                                                                      CM
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                         28.0
#                                        Cancelamento Compulsório           1.0
#                                        Concluído                          NaN
#                                        Evasão                            17.0
#                                        Matriculado                      302.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           3.0
#                                        Transferido Externo                1.0
#                                        Transferido Interno                7.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          7.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             NaN
#                                        Matriculado                      125.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                1.0
#                                        Transferido Interno                4.0
# Matemática I(120H)                     Cancelado                         31.0
#                                        Cancelamento Compulsório           1.0
#                                        Concluído                          NaN
#                                        Evasão                            19.0
#                                        Matriculado                      335.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           3.0
#                                        Transferido Externo                3.0
#                                        Transferido Interno                9.0
# Matemática II(90H)                     Cancelado                          6.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             NaN
#                                        Matriculado                      123.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                1.0
#                                        Transferido Interno                4.0
#
#                                                                                \
# sigla                                                                      CN
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                          5.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            10.0
#                                        Matriculado                      466.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           1.0
#                                        Trancado Voluntariamente           2.0
#                                        Transferido Externo                4.0
#                                        Transferido Interno                5.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          1.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             NaN
#                                        Matriculado                      266.0
#                                        Trancado                           1.0
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo                1.0
#                                        Transferido Interno                NaN
# Matemática I(120H)                     Cancelado                          5.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            10.0
#                                        Matriculado                      547.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           1.0
#                                        Trancado Voluntariamente           3.0
#                                        Transferido Externo                5.0
#                                        Transferido Interno                6.0
# Matemática II(90H)                     Cancelado                          1.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             NaN
#                                        Matriculado                      268.0
#                                        Trancado                           2.0
#                                        Trancado Voluntariamente           2.0
#                                        Transferido Externo                1.0
#                                        Transferido Interno                NaN
#
#                                                                                 \
# sigla                                                                     CNAT
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                          46.0
#                                        Cancelamento Compulsório            3.0
#                                        Concluído                          12.0
#                                        Evasão                             45.0
#                                        Matriculado                      1138.0
#                                        Matrícula Vínculo Institucional     NaN
#                                        Trancado                            1.0
#                                        Trancado Voluntariamente            4.0
#                                        Transferido Externo                17.0
#                                        Transferido Interno                14.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          13.0
#                                        Cancelamento Compulsório            1.0
#                                        Concluído                          12.0
#                                        Evasão                             16.0
#                                        Matriculado                       739.0
#                                        Trancado                            1.0
#                                        Trancado Voluntariamente            5.0
#                                        Transferido Externo                 8.0
#                                        Transferido Interno                13.0
# Matemática I(120H)                     Cancelado                          56.0
#                                        Cancelamento Compulsório            3.0
#                                        Concluído                          12.0
#                                        Evasão                             52.0
#                                        Matriculado                      1276.0
#                                        Matrícula Vínculo Institucional     NaN
#                                        Trancado                            2.0
#                                        Trancado Voluntariamente            4.0
#                                        Transferido Externo                18.0
#                                        Transferido Interno                19.0
# Matemática II(90H)                     Cancelado                          16.0
#                                        Cancelamento Compulsório            1.0
#                                        Concluído                          12.0
#                                        Evasão                             17.0
#                                        Matriculado                       766.0
#                                        Trancado                            1.0
#                                        Trancado Voluntariamente            3.0
#                                        Transferido Externo                 9.0
#                                        Transferido Interno                13.0
#
#                                                                                \
# sigla                                                                      IP
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                          8.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            21.0
#                                        Matriculado                      218.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                2.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          4.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             4.0
#                                        Matriculado                      100.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                1.0
# Matemática I(120H)                     Cancelado                         10.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            25.0
#                                        Matriculado                      271.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                4.0
# Matemática II(90H)                     Cancelado                          5.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             4.0
#                                        Matriculado                      109.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                1.0
#
#                                                                                \
# sigla                                                                      JC
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                         30.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            45.0
#                                        Matriculado                      264.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                6.0
#                                        Transferido Interno               14.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          2.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                       84.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                2.0
#                                        Transferido Interno                6.0
# Matemática I(120H)                     Cancelado                         35.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            47.0
#                                        Matriculado                      292.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                6.0
#                                        Transferido Interno               13.0
# Matemática II(90H)                     Cancelado                          2.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                       85.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                2.0
#                                        Transferido Interno                6.0
#
#                                                                                \
# sigla                                                                     LAJ
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                          7.0
#                                        Cancelamento Compulsório           6.0
#                                        Concluído                          NaN
#                                        Evasão                            29.0
#                                        Matriculado                      311.0
#                                        Matrícula Vínculo Institucional    1.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo                3.0
#                                        Transferido Interno                3.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          NaN
#                                        Cancelamento Compulsório           1.0
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                      143.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo                2.0
#                                        Transferido Interno                1.0
# Matemática I(120H)                     Cancelado                          8.0
#                                        Cancelamento Compulsório           5.0
#                                        Concluído                          NaN
#                                        Evasão                            28.0
#                                        Matriculado                      308.0
#                                        Matrícula Vínculo Institucional    1.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo                3.0
#                                        Transferido Interno                2.0
# Matemática II(90H)                     Cancelado                          NaN
#                                        Cancelamento Compulsório           1.0
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                      144.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo                2.0
#                                        Transferido Interno                1.0
#
#                                                                                \
# sigla                                                                      MC
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                         15.0
#                                        Cancelamento Compulsório           5.0
#                                        Concluído                          NaN
#                                        Evasão                            54.0
#                                        Matriculado                      366.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo               26.0
#                                        Transferido Interno                7.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          4.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             2.0
#                                        Matriculado                       79.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo                2.0
#                                        Transferido Interno                3.0
# Matemática I(120H)                     Cancelado                         16.0
#                                        Cancelamento Compulsório           6.0
#                                        Concluído                          NaN
#                                        Evasão                            57.0
#                                        Matriculado                      408.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo               26.0
#                                        Transferido Interno                8.0
# Matemática II(90H)                     Cancelado                          4.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             2.0
#                                        Matriculado                       81.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo                2.0
#                                        Transferido Interno                3.0
#
#                                                                                \
# sigla                                                                      MO
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                          2.0
#                                        Cancelamento Compulsório           2.0
#                                        Concluído                          NaN
#                                        Evasão                            13.0
#                                        Matriculado                      292.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           2.0
#                                        Transferido Externo                2.0
#                                        Transferido Interno                4.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          NaN
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                      125.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           2.0
#                                        Transferido Externo                1.0
#                                        Transferido Interno                2.0
# Matemática I(120H)                     Cancelado                          2.0
#                                        Cancelamento Compulsório           2.0
#                                        Concluído                          NaN
#                                        Evasão                            14.0
#                                        Matriculado                      309.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           2.0
#                                        Transferido Externo                2.0
#                                        Transferido Interno                4.0
# Matemática II(90H)                     Cancelado                          NaN
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                      125.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           2.0
#                                        Transferido Externo                1.0
#                                        Transferido Interno                2.0
#
#                                                                                \
# sigla                                                                      NC
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                         24.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            31.0
#                                        Matriculado                      243.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           4.0
#                                        Transferido Externo                1.0
#                                        Transferido Interno                7.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          6.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             9.0
#                                        Matriculado                      110.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           4.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno                5.0
# Matemática I(120H)                     Cancelado                         32.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            35.0
#                                        Matriculado                      289.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           7.0
#                                        Transferido Externo                1.0
#                                        Transferido Interno                7.0
# Matemática II(90H)                     Cancelado                          6.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             9.0
#                                        Matriculado                      129.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           4.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno                7.0
#
#                                                                                \
# sigla                                                                    PAAS
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                         10.0
#                                        Cancelamento Compulsório           4.0
#                                        Concluído                          NaN
#                                        Evasão                             8.0
#                                        Matriculado                      275.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                2.0
#                                        Transferido Interno                9.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          NaN
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                      147.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                2.0
# Matemática I(120H)                     Cancelado                         11.0
#                                        Cancelamento Compulsório           4.0
#                                        Concluído                          NaN
#                                        Evasão                            12.0
#                                        Matriculado                      293.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                2.0
#                                        Transferido Interno               10.0
# Matemática II(90H)                     Cancelado                          NaN
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             1.0
#                                        Matriculado                      147.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                NaN
#                                        Transferido Interno                2.0
#
#                                                                                \
# sigla                                                                     PAR
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                          6.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          5.0
#                                        Evasão                            11.0
#                                        Matriculado                      464.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           1.0
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                3.0
#                                        Transferido Interno                8.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          2.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          5.0
#                                        Evasão                             3.0
# ...
#                                        Matriculado                      344.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                3.0
#                                        Transferido Interno                3.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          3.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             2.0
#                                        Matriculado                      129.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                2.0
#                                        Transferido Interno                NaN
# Matemática I(120H)                     Cancelado                         17.0
#                                        Cancelamento Compulsório           3.0
#                                        Concluído                          NaN
#                                        Evasão                             8.0
#                                        Matriculado                      368.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                3.0
#                                        Transferido Interno                3.0
# Matemática II(90H)                     Cancelado                          3.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             2.0
#                                        Matriculado                      129.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                2.0
#                                        Transferido Interno                NaN
#
#                                                                                \
# sigla                                                                      SC
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                         22.0
#                                        Cancelamento Compulsório           3.0
#                                        Concluído                          NaN
#                                        Evasão                            30.0
#                                        Matriculado                      385.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           2.0
#                                        Trancado Voluntariamente           6.0
#                                        Transferido Externo                1.0
#                                        Transferido Interno                6.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          5.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             5.0
#                                        Matriculado                      232.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           5.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno                3.0
# Matemática I(120H)                     Cancelado                         25.0
#                                        Cancelamento Compulsório           3.0
#                                        Concluído                          NaN
#                                        Evasão                            32.0
#                                        Matriculado                      447.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           2.0
#                                        Trancado Voluntariamente           8.0
#                                        Transferido Externo                1.0
#                                        Transferido Interno                7.0
# Matemática II(90H)                     Cancelado                          6.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             5.0
#                                        Matriculado                      248.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           6.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno                4.0
#
#                                                                                \
# sigla                                                                     SGA
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                          6.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            14.0
#                                        Matriculado                      248.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno                4.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          NaN
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             2.0
#                                        Matriculado                      109.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno                3.0
# Matemática I(120H)                     Cancelado                          6.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                            16.0
#                                        Matriculado                      254.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno                4.0
# Matemática II(90H)                     Cancelado                          NaN
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          NaN
#                                        Evasão                             2.0
#                                        Matriculado                       76.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           1.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno                3.0
#
#                                                                                \
# sigla                                                                     SPP
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                         24.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          1.0
#                                        Evasão                            29.0
#                                        Matriculado                      384.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           4.0
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo               13.0
#                                        Transferido Interno               12.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          3.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          1.0
#                                        Evasão                             4.0
#                                        Matriculado                      202.0
#                                        Trancado                           4.0
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                2.0
#                                        Transferido Interno                7.0
# Matemática I(120H)                     Cancelado                         31.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          1.0
#                                        Evasão                            31.0
#                                        Matriculado                      543.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           6.0
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo               19.0
#                                        Transferido Interno               19.0
# Matemática II(90H)                     Cancelado                          3.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          1.0
#                                        Evasão                             4.0
#                                        Matriculado                      239.0
#                                        Trancado                           5.0
#                                        Trancado Voluntariamente           NaN
#                                        Transferido Externo                2.0
#                                        Transferido Interno                8.0
#
#
# sigla                                                                      ZN
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado                         14.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          2.0
#                                        Evasão                            19.0
#                                        Matriculado                      426.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           5.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno                9.0
# Língua Portuguesa e Literatura II(90H) Cancelado                          5.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          2.0
#                                        Evasão                             7.0
#                                        Matriculado                      219.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           6.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno                8.0
# Matemática I(120H)                     Cancelado                         23.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          2.0
#                                        Evasão                            27.0
#                                        Matriculado                      540.0
#                                        Matrícula Vínculo Institucional    NaN
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           9.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno               13.0
# Matemática II(90H)                     Cancelado                          5.0
#                                        Cancelamento Compulsório           NaN
#                                        Concluído                          2.0
#                                        Evasão                             8.0
#                                        Matriculado                      222.0
#                                        Trancado                           NaN
#                                        Trancado Voluntariamente           6.0
#                                        Transferido Externo                NaN
#                                        Transferido Interno                8.0

# %%
#visualizando a qnt de evadidos, cancelados e matriculados por disciplina e campus
df = dados.loc[dados['descricao'].isin(['Evasão',
                                        'Cancelado', 
                                        'Matriculado'])]

df.groupby(['descricao_historico_disciplina', 'descricao', 'sigla'])['media_final'].aggregate([np.size]).unstack()
# Out:
#                                                      size                \
# sigla                                                  AP     CA    CAL
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado     14.0   58.0    8.0
#                                        Evasão        11.0   10.0    9.0
#                                        Matriculado  296.0  481.0  172.0
# Língua Portuguesa e Literatura II(90H) Cancelado      3.0    8.0    1.0
#                                        Evasão         1.0    1.0    3.0
#                                        Matriculado  106.0  237.0   59.0
# Matemática I(120H)                     Cancelado     13.0   61.0    9.0
#                                        Evasão        11.0   11.0   11.0
#                                        Matriculado  313.0  534.0  189.0
# Matemática II(90H)                     Cancelado      3.0    9.0    1.0
#                                        Evasão         1.0    1.0    3.0
#                                        Matriculado  106.0  251.0   58.0
#
#                                                                          \
# sigla                                                CANG     CM     CN
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado      5.0   28.0    5.0
#                                        Evasão         5.0   17.0   10.0
#                                        Matriculado  195.0  302.0  466.0
# Língua Portuguesa e Literatura II(90H) Cancelado      NaN    7.0    1.0
#                                        Evasão         NaN    NaN    NaN
#                                        Matriculado   62.0  125.0  266.0
# Matemática I(120H)                     Cancelado      6.0   31.0    5.0
#                                        Evasão         5.0   19.0   10.0
#                                        Matriculado  200.0  335.0  547.0
# Matemática II(90H)                     Cancelado      NaN    6.0    1.0
#                                        Evasão         NaN    NaN    NaN
#                                        Matriculado   64.0  123.0  268.0
#
#                                                                           \
# sigla                                                 CNAT     IP     JC
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado      46.0    8.0   30.0
#                                        Evasão         45.0   21.0   45.0
#                                        Matriculado  1138.0  218.0  264.0
# Língua Portuguesa e Literatura II(90H) Cancelado      13.0    4.0    2.0
#                                        Evasão         16.0    4.0    1.0
#                                        Matriculado   739.0  100.0   84.0
# Matemática I(120H)                     Cancelado      56.0   10.0   35.0
#                                        Evasão         52.0   25.0   47.0
#                                        Matriculado  1276.0  271.0  292.0
# Matemática II(90H)                     Cancelado      16.0    5.0    2.0
#                                        Evasão         17.0    4.0    1.0
#                                        Matriculado   766.0  109.0   85.0
#
#                                                                          \
# sigla                                                 LAJ     MC     MO
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado      7.0   15.0    2.0
#                                        Evasão        29.0   54.0   13.0
#                                        Matriculado  311.0  366.0  292.0
# Língua Portuguesa e Literatura II(90H) Cancelado      NaN    4.0    NaN
#                                        Evasão         1.0    2.0    1.0
#                                        Matriculado  143.0   79.0  125.0
# Matemática I(120H)                     Cancelado      8.0   16.0    2.0
#                                        Evasão        28.0   57.0   14.0
#                                        Matriculado  308.0  408.0  309.0
# Matemática II(90H)                     Cancelado      NaN    4.0    NaN
#                                        Evasão         1.0    2.0    1.0
#                                        Matriculado  144.0   81.0  125.0
#
#                                                                          \
# sigla                                                  NC   PAAS    PAR
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado     24.0   10.0    6.0
#                                        Evasão        31.0    8.0   11.0
#                                        Matriculado  243.0  275.0  464.0
# Língua Portuguesa e Literatura II(90H) Cancelado      6.0    NaN    2.0
#                                        Evasão         9.0    1.0    3.0
#                                        Matriculado  110.0  147.0  288.0
# Matemática I(120H)                     Cancelado     32.0   11.0    7.0
#                                        Evasão        35.0   12.0   13.0
#                                        Matriculado  289.0  293.0  535.0
# Matemática II(90H)                     Cancelado      6.0    NaN    2.0
#                                        Evasão         9.0    1.0    3.0
#                                        Matriculado  129.0  147.0  325.0
#
#                                                                          \
# sigla                                                  PF     SC    SGA
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado     15.0   22.0    6.0
#                                        Evasão         7.0   30.0   14.0
#                                        Matriculado  344.0  385.0  248.0
# Língua Portuguesa e Literatura II(90H) Cancelado      3.0    5.0    NaN
#                                        Evasão         2.0    5.0    2.0
#                                        Matriculado  129.0  232.0  109.0
# Matemática I(120H)                     Cancelado     17.0   25.0    6.0
#                                        Evasão         8.0   32.0   16.0
#                                        Matriculado  368.0  447.0  254.0
# Matemática II(90H)                     Cancelado      3.0    6.0    NaN
#                                        Evasão         2.0    5.0    2.0
#                                        Matriculado  129.0  248.0   76.0
#
#
# sigla                                                 SPP     ZN
# descricao_historico_disciplina         descricao
# Língua Portuguesa e Literatura I(90H)  Cancelado     24.0   14.0
#                                        Evasão        29.0   19.0
#                                        Matriculado  384.0  426.0
# Língua Portuguesa e Literatura II(90H) Cancelado      3.0    5.0
#                                        Evasão         4.0    7.0
#                                        Matriculado  202.0  219.0
# Matemática I(120H)                     Cancelado     31.0   23.0
#                                        Evasão        31.0   27.0
#                                        Matriculado  543.0  540.0
# Matemática II(90H)                     Cancelado      3.0    5.0
#                                        Evasão         4.0    8.0
#                                        Matriculado  239.0  222.0

# %%
#removendo as duplicadas
df[~df['id'].duplicated()].groupby(['descricao', 'sigla', 'ano_letivo__ano'])['id'].aggregate([np.size]).unstack()
# Out:
#                     size
# ano_letivo__ano     2015   2016   2017
# descricao   sigla
# Cancelado   AP       3.0    6.0    1.0
#             CA      20.0   14.0   11.0
#             CAL      2.0    3.0    2.0
#             CANG     1.0    2.0    2.0
#             CM      11.0    5.0    3.0
#             CN       2.0    2.0    1.0
#             CNAT    14.0   26.0    6.0
#             IP       2.0    5.0    1.0
#             JC       9.0    8.0    NaN
#             LAJ      4.0    2.0    NaN
#             MC       6.0    5.0    1.0
#             MO       NaN    2.0    NaN
#             NC       6.0   10.0    4.0
#             PAAS     6.0    3.0    NaN
#             PAR      2.0    2.0    NaN
#             PF       4.0    7.0    2.0
#             SC       7.0    5.0   10.0
#             SGA      1.0    2.0    2.0
#             SPP      9.0    6.0    4.0
#             ZN       7.0    5.0    1.0
# Evasão      AP       6.0    4.0    NaN
#             CA       6.0    3.0    NaN
#             CAL      4.0    4.0    NaN
#             CANG     4.0    NaN    NaN
#             CM       8.0    8.0    NaN
#             CN       3.0    6.0    NaN
#             CNAT    25.0   14.0    NaN
#             IP      15.0    3.0    NaN
#             JC      20.0    7.0    NaN
#             LAJ     13.0   10.0    NaN
#             MC      22.0   19.0    NaN
#             MO      10.0    1.0    NaN
#             NC      13.0    9.0    2.0
#             PAAS     8.0    NaN    NaN
#             PAR      7.0    2.0    NaN
#             PF       5.0    1.0    NaN
#             SC      21.0    8.0    NaN
#             SGA     11.0    1.0    NaN
#             SPP     20.0    7.0    NaN
#             ZN      14.0    5.0    NaN
# Matriculado AP     131.0  135.0    NaN
#             CA     199.0  146.0  115.0
#             CAL     59.0  105.0    5.0
#             CANG    70.0  117.0    1.0
#             CM     130.0  136.0   26.0
#             CN     137.0  154.0  161.0
#             CNAT   383.0  392.0  343.0
#             IP     103.0  114.0    1.0
#             JC     114.0  106.0    3.0
#             LAJ     58.0  110.0  106.0
#             MC     104.0  141.0   62.0
#             MO     134.0  146.0    6.0
#             NC     113.0  125.0    4.0
#             PAAS    61.0  101.0  107.0
#             PAR    145.0  140.0  149.0
#             PF     132.0  210.0    NaN
#             SC     107.0  127.0  142.0
#             SGA     92.0  141.0    2.0
#             SPP    111.0  119.0  139.0
#             ZN     119.0  136.0  148.0

# %%
#agrupando os alunos cancelados, evadidos, transferidos interno e externo como evasão para o mec
#-1 valor sentinela, 0 evasão, 1 matriculado
dados['classe'] = np.ones(dados.shape[0])*-1

dados.loc[dados['descricao'].isin(['Evasão',
                                   'Cancelado', 
                                   'Cancelamento Compulsório', 
                                   #'Transferido Externo', #PARA O MEC É CONSIDERADO EVASAO MAS NAO SERA CONSIDERADO NO MODELO
                                   #'Transferido Interno'  #PARA O MEC É CONSIDERADO EVASAO MAS NAO SERA CONSIDERADO NO MODELO
                                  ]), 'classe'] = 0

dados.loc[dados['descricao'].isin(['Concluído',
                                   #'Intercâmbio', #PARA O MEC NÃO É EVASAO MAS NAO SERA CONSIDERADO NO MODELO
                                   'Matriculado', 
                                   #'Trancado', #PARA O MEC NÃO É EVASAO MAS NAO SERA CONSIDERADO NO MODELO
                                   #'Trancado Voluntariamente', #PARA O MEC NÃO É EVASAO MAS NAO SERA CONSIDERADO NO MODELO
                                   'Matrícula Vínculo Institucional']), 'classe'] = 1
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
#verificando balanceamento das classes
print(dados.groupby('classe').count()['id'])

print(dados.shape)
# Out:
# classe
# -1.0      873
#  0.0     1966
#  1.0    22863
# Name: id, dtype: int64
# (25702, 14)

# %%
#removendo as instancias de classe -1
df = dados[dados.classe != -1]

print(df.groupby('classe').count()['id'])
print(df.shape)

dados = df
# Out:
# classe
# 0.0     1966
# 1.0    22863
# Name: id, dtype: int64
# (24829, 14)

# %% [markdown]
# # Transformando as notas em colunas

# %%
print(dados.id.nunique())
print(dados.shape)
# Out:
# 7607
# (24829, 14)

# %%
#definindo funcoes
import re
def clean_string(string):
    cleanString = re.sub('\W+','', string)
    cleanString = re.sub(r'[^a-zA-Z0-9 ]',r'',cleanString)

    return cleanString

# %%
#criar novos campos de acordo com as disciplinas
for index1, group1 in dados.groupby(['descricao_historico_disciplina']):        

    dados[ clean_string(index1) ] = np.ones(dados.shape[0])*-1    
    #print(cleanString)
    
dados.head(2)
# Out:
#                 id  ano_letivo__ano        cep pessoa_fisica__nascimento_data  \
# 8018  600087694001             2017  59178-000                     18/06/2000
# 8019  451059250469             2015  59080-310                     17/04/1999
#
#      pessoa_fisica__sexo                       descricao_historico sigla  \
# 8018                   M  Técnico de Nível Médio em Eletromecânica  CANG
# 8019                   M       Técnico de Nível Médio em Logística   SGA
#
#         descricao  ano_letivo__ano_matricula_periodo  \
# 8018  Matriculado                               2017
# 8019  Matriculado                               2017
#
#      descricao_situacao_matricula_periodo  media_final  percentual_frequencia  \
# 8018                          Matriculado           87                    NaN
# 8019                          Matriculado            0                   94.0
#
#      descricao_historico_disciplina  classe  LnguaPortuguesaeLiteraturaI90H  \
# 8018             Matemática I(120H)     1.0                            -1.0
# 8019             Matemática I(120H)     1.0                            -1.0
#
#       LnguaPortuguesaeLiteraturaII90H  MatemticaI120H  MatemticaII90H
# 8018                             -1.0            -1.0            -1.0
# 8019                             -1.0            -1.0            -1.0

# %%
cont = 1

#loop sobre cada aluno preencher os atributos notas
for index1, group1 in dados.groupby(['id', 'descricao_historico_disciplina']):    
    #id do aluno
    id_aluno = index1[0]
    
    #nome da coluna relacionada a disciplina
    col_disc = clean_string(index1[1])    
    
    #nota relacionada a uma disciplina e um aluno
    nota = dados[(dados.id == id_aluno) & (dados.descricao_historico_disciplina == index1[1])]['media_final'].values 
    
    #para os casos do aluno ter ficado em recuperação só pegar apenas o primeiro registro
    #DEPOIS VERIFICAR OS CASOS QUE FICOU ASSIM
    nota = nota[0]
    
    #atribuindo nota a um aluno de uma disciplina
    dados.loc[dados.id == id_aluno, col_disc] = nota
    
    #print(dados.loc[dados.id == id_aluno, ['id', 'descricao_historico_disciplina', 'media_final', col_disc]])

    #if cont > 10:
    #    break
    #cont = cont + 1


    
#removendo duplicadas
X = dados.drop_duplicates('id')

#removendo atributos já expressos em outras colunas
X = X.drop(['media_final', 'descricao_historico_disciplina'], axis=1)

print(X.shape)
X.head(2)
# Out:
# (7607, 16)
#                 id  ano_letivo__ano        cep pessoa_fisica__nascimento_data  \
# 8018  600087694001             2017  59178-000                     18/06/2000
# 8019  451059250469             2015  59080-310                     17/04/1999
#
#      pessoa_fisica__sexo                       descricao_historico sigla  \
# 8018                   M  Técnico de Nível Médio em Eletromecânica  CANG
# 8019                   M       Técnico de Nível Médio em Logística   SGA
#
#         descricao  ano_letivo__ano_matricula_periodo  \
# 8018  Matriculado                               2017
# 8019  Matriculado                               2017
#
#      descricao_situacao_matricula_periodo  percentual_frequencia  classe  \
# 8018                          Matriculado                    NaN     1.0
# 8019                          Matriculado                   94.0     1.0
#
#       LnguaPortuguesaeLiteraturaI90H  LnguaPortuguesaeLiteraturaII90H  \
# 8018                            -1.0                             -1.0
# 8019                            64.0                             61.0
#
#       MatemticaI120H  MatemticaII90H
# 8018            87.0            67.0
# 8019             0.0            -1.0

# %%
#removendo alunos que não possuam todas as notas do primeiro ano
df = X[X.LnguaPortuguesaeLiteraturaI90H != -1]
print(df.shape)

df = df[df.MatemticaI120H != -1]
print(df.shape)

#df = df[df.LnguaPortuguesaeLiteraturaII90H != -1]
#print(df.shape)

#df = df[df.MatemticaII90H != -1]
#print(df.shape)

dados.head(1)

#dados = df
# Out:
# (7599, 16)
# (7587, 16)
#                 id  ano_letivo__ano        cep pessoa_fisica__nascimento_data  \
# 8018  600087694001             2017  59178-000                     18/06/2000
#
#      pessoa_fisica__sexo                       descricao_historico sigla  \
# 8018                   M  Técnico de Nível Médio em Eletromecânica  CANG
#
#         descricao  ano_letivo__ano_matricula_periodo  \
# 8018  Matriculado                               2017
#
#      descricao_situacao_matricula_periodo  media_final  percentual_frequencia  \
# 8018                          Matriculado           87                    NaN
#
#      descricao_historico_disciplina  classe  LnguaPortuguesaeLiteraturaI90H  \
# 8018             Matemática I(120H)     1.0                            -1.0
#
#       LnguaPortuguesaeLiteraturaII90H  MatemticaI120H  MatemticaII90H
# 8018                             -1.0            87.0            67.0

# %%
#removendo o valor sentinela de -1 e atribuindo o NaN
df.loc[df.LnguaPortuguesaeLiteraturaII90H == -1, 'LnguaPortuguesaeLiteraturaII90H'] = np.NaN
df.loc[df.MatemticaII90H == -1, 'MatemticaII90H'] = np.NaN

# %%
df[['LnguaPortuguesaeLiteraturaII90H','MatemticaII90H', 'LnguaPortuguesaeLiteraturaI90H', 'MatemticaI120H']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb0aacbcc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb0bd1d9b38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb0bd1f7d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb0bcfad6d8>]], dtype=object)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#salvando os dados
dados = df
#dados.to_json("dados/dados_flat_sem_social.json")

# %%
dados.head(2)
# Out:
#                 id  ano_letivo__ano        cep pessoa_fisica__nascimento_data  \
# 8019  451059250469             2015  59080-310                     17/04/1999
# 8020  542847344041             2017  59290-000                     10/08/2001
#
#      pessoa_fisica__sexo                  descricao_historico sigla  \
# 8019                   M  Técnico de Nível Médio em Logística   SGA
# 8020                   F  Técnico de Nível Médio em Logística   SGA
#
#         descricao  ano_letivo__ano_matricula_periodo  \
# 8019  Matriculado                               2017
# 8020  Matriculado                               2017
#
#      descricao_situacao_matricula_periodo  percentual_frequencia  classe  \
# 8019                          Matriculado                   94.0     1.0
# 8020                          Matriculado                   97.0     1.0
#
#       LnguaPortuguesaeLiteraturaI90H  LnguaPortuguesaeLiteraturaII90H  \
# 8019                            64.0                             61.0
# 8020                             0.0                              NaN
#
#       MatemticaI120H  MatemticaII90H
# 8019             0.0             NaN
# 8020             0.0             NaN
